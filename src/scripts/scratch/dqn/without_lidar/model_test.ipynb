# %%
import random
import pickle

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
# Out:
# 2023-08-03 08:10:47.740092: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-03 08:10:48.282242: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Create a class for the environment
class Env():
    def __init__(self, grid_size=21, max_steps=500):
        self.grid_size = grid_size
        self.max_steps = max_steps
        
        self.obstacles = np.array([[3, 0], [3, 1], [3, 2], [3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9],
             [8, 9], [8, 10], [8, 11], [8, 12], [8, 13], [8, 14], [8, 15], [8, 16], [8, 17], [8, 18], [8, 19], [8, 20],
             [14, 0], [14, 1], [14, 2], [14, 3], [14, 4], [14, 5], [14, 6], [14, 7], [14, 8], [14, 9]])
        # self.rewards = np.zeros((grid_size, grid_size))
        self.reset()
        self.reset_goal()

    def check(self, test, array):
        return any(np.array_equal(x, test) for x in array)

    def reset(self):
        self.pos = np.random.randint(0, self.grid_size, size=2)
        while self.check(self.pos, self.obstacles):
            self.pos = np.random.randint(0, self.grid_size, size=2)
        self.steps = 0
        self.done = False
        return self.pos
    
    def reset_goal(self):
        self.goal = np.random.randint(0, self.grid_size, size=2)
        while self.check(self.goal, self.obstacles) or np.array_equal(self.pos, self.goal):
            self.goal = np.random.randint(0, self.grid_size, size=2)
        print('Goal:', self.goal)
        # for i in range(self.grid_size):
        #     for j in range(self.grid_size):
        #         self.rewards[i, j] = -self.euclidean_distance_from_goal(np.array([i, j]))
        # self.rewards[self.goal[0], self.goal[1]] = 100
        return self.goal
    
    # def step(self, action):
    #     self.steps += 1
    #     if action == 0 and self.pos[0] < self.grid_size - 1: # right
    #         self.pos[0] += 1
    #     elif action == 1 and self.pos[0] > 0: # left
    #         self.pos[0] -= 1
    #     elif action == 2 and self.pos[1] > 0: # down
    #         self.pos[1] -= 1
    #     elif action == 3 and self.pos[1] < self.grid_size - 1: # up
    #         self.pos[1] += 1
    #     else:
    #         pass
    #         # raise ValueError('Invalid action')
    #     if np.array_equal(self.pos, self.goal):
    #         self.done = True
    #         reward = 0
    #         # reward = 100
    #     elif self.steps >= self.max_steps:
    #         self.done = True
    #         reward = self.rewards[self.pos[0], self.pos[1]]
    #     else:
    #         reward = self.rewards[self.pos[0], self.pos[1]]
    #     return self.pos, reward, self.done

    def step(self, action): # As per the paper
        self.steps += 1
        prev_pos = self.pos.copy()
        if action == 0 and self.pos[0] < self.grid_size - 1 and not (self.check(self.pos + np.array([1, 0]), self.obstacles)): # right
            self.pos[0] += 1
        elif action == 1 and self.pos[0] > 0 and not (self.check(self.pos - np.array([1, 0]), self.obstacles)): # left
            self.pos[0] -= 1
        elif action == 2 and self.pos[1] > 0 and not (self.check(self.pos - np.array([0, 1]), self.obstacles)): # down
            self.pos[1] -= 1
        elif action == 3 and self.pos[1] < self.grid_size - 1 and not (self.check(self.pos + np.array([0, 1]), self.obstacles)): # up
            self.pos[1] += 1
        else:
            reward = -150
            self.done = False
            return self.pos, reward, self.done, True # TODO: The episode is not terminated.
        if np.array_equal(self.pos, self.goal):
            self.done = True
            reward = 500
        elif self.steps >= self.max_steps:
            self.done = True
            reward = 0
        else:
            if self.euclidean_distance_from_goal(self.pos) < self.euclidean_distance_from_goal(prev_pos):
                reward = 10
            else:
                reward = -10
        return self.pos, reward, self.done, False
        

    def euclidean_distance_from_goal(self, pos):
        dist = np.sqrt(np.sum((pos - self.goal) ** 2))
        return dist

# %%
# Create an agent class
class Agent():
    def __init__(self, env, model, target_model):
        self.env = env
        self.model = model
        self.target_model = target_model
        self.target_model.set_weights(self.model.get_weights())
        self.gamma = 0.7
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.0003
        self.batch_size = 64
        self.memory = deque(maxlen=1000)
        

    def add_to_memory(self, state, goal, action, reward, next_state, done):
        self.memory.append((state, goal, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(0, 4)
        else:
            # Pre-process the input
            inputt = np.concatenate((state, self.env.goal))
            inputt = tf.convert_to_tensor(inputt)
            inputt = tf.expand_dims(inputt, 0)

            return np.argmax(self.model.predict(inputt, verbose=0)[0]) # TODO: check the predict output

    def predict(self, inputt):

        return np.argmax(self.model.predict(inputt, verbose=0)[0])

    def replay(self):
        batch = random.sample(self.memory, self.batch_size)
        for state, goal, action, reward, next_state, done in batch:
            
            target = reward

            if not done:
                # Pre-process the next state input
                input_next = np.concatenate((next_state, goal))
                input_next = tf.convert_to_tensor(input_next)
                input_next = tf.expand_dims(input_next, 0)

                target += self.gamma * np.amax(self.target_model.predict(input_next, verbose=0)[0])

            # Pre-process the current state input
            inputt = np.concatenate((state, goal))
            inputt = tf.convert_to_tensor(inputt)
            inputt = tf.expand_dims(inputt, 0)

            cur_q_value = self.model.predict(inputt, verbose=0) # Q-value of current state
            cur_q_value[0][action] = target # TODO: check the predict output
            
            self.model.fit(inputt, cur_q_value, epochs=1, verbose=0)

# %%
# Initialize the agent

try:
    model = tf.keras.models.load_model('models/ql_fed_dqn.h5')
    print("Loaded model from disk")
    agent = Agent(Env(), model=model, target_model=model)
except:
    print("Creating new model")
    agent = Agent(Env(), model=create_model(input_shape=(4,), num_actions=4), target_model=create_model(input_shape=(4,), num_actions=4))
# Out:
# Loaded model from disk
# Goal: [0 8]
# 2023-08-03 08:10:55.014701: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2023-08-03 08:10:55.014741: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: pradeep-Victus-by-HP-Laptop-16-e0xxx
# 2023-08-03 08:10:55.014746: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: pradeep-Victus-by-HP-Laptop-16-e0xxx
# 2023-08-03 08:10:55.014853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 535.54.3
# 2023-08-03 08:10:55.014876: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  535.54.03  Release Build  (dvs-builder@U16-I2-C03-15-1)  Tue Jun  6 22:31:30 UTC 2023
# GCC version:  gcc version 9.4.0 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# "

# %%
# Test the agent
success = 0
crash = 0
no_tests = 1000
for i in range(no_tests):
    state = agent.env.reset()
    goal = agent.env.reset_goal()
    print('Goal:', goal)
    for step in range(100):
        print('State:', state)
        inputt = np.concatenate((state, goal))
        inputt = tf.convert_to_tensor(inputt)
        inputt = tf.expand_dims(inputt, 0)
        action = agent.predict(inputt)
        next_state, reward, done, terminate = agent.env.step(action)
        state = next_state
        if done:
            print('State:', state)
            print('Steps: ', step+1)
            if np.array_equal(agent.env.goal, agent.env.pos):
                print('Reached the goal!')
                success += 1
            break
        elif terminate:
            print('State:', state)
            print('Steps: ', step+1)
            print('Terminated!')
            crash += 1
            break

print('Success rate:', success/no_tests)
print('Crash rate:', crash/no_tests)
print('Oscillate rate:', (no_tests - success - crash)/no_tests)
# Out:
# Goal: [ 1 18]
# Goal: [ 1 18]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# State: [11  8]
# State: [10  8]
# Goal: [ 5 15]
# Goal: [ 5 15]
# State: [ 4 14]
# State: [ 5 14]
# State: [ 5 15]
# Steps:  2
# Reached the goal!
# Goal: [20  3]
# Goal: [20  3]
# State: [11 16]
# State: [12 16]
# State: [13 16]
# State: [13 17]
# State: [13 18]
# State: [13 19]
# State: [13 20]
# State: [13 20]
# Steps:  7
# Terminated!
# Goal: [4 5]
# Goal: [4 5]
# State: [ 9 17]
# State: [ 9 18]
# State: [ 9 19]
# State: [ 9 20]
# State: [ 9 20]
# Steps:  4
# Terminated!
# Goal: [20  6]
# Goal: [20  6]
# State: [15  5]
# State: [16  5]
# State: [16  6]
# State: [17  6]
# State: [18  6]
# State: [19  6]
# State: [20  6]
# Steps:  6
# Reached the goal!
# Goal: [10  4]
# Goal: [10  4]
# State: [17 14]
# State: [17 15]
# State: [17 16]
# State: [17 17]
# State: [17 18]
# State: [17 19]
# State: [17 20]
# State: [17 20]
# Steps:  7
# Terminated!
# Goal: [ 1 19]
# Goal: [ 1 19]
# State: [ 9 13]
# State: [ 9 12]
# State: [ 9 11]
# State: [ 9 10]
# State: [9 9]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# Goal: [4 9]
# Goal: [4 9]
# State: [17 13]
# State: [17 14]
# State: [17 15]
# State: [17 16]
# State: [17 17]
# State: [17 18]
# State: [17 19]
# State: [17 20]
# State: [17 20]
# Steps:  8
# Terminated!
# Goal: [17 16]
# Goal: [17 16]
# State: [ 1 14]
# State: [ 0 14]
# State: [ 0 15]
# State: [ 0 16]
# State: [ 0 16]
# Steps:  4
# Terminated!
# Goal: [20 18]
# Goal: [20 18]
# State: [19  4]
# State: [19  5]
# State: [19  6]
# State: [19  7]
# State: [19  8]
# State: [19  9]
# State: [19 10]
# State: [19 11]
# State: [19 12]
# State: [19 13]
# State: [19 14]
# State: [19 15]
# State: [19 16]
# State: [19 17]
# State: [19 18]
# State: [20 18]
# Steps:  15
# Reached the goal!
# Goal: [ 3 15]
# Goal: [ 3 15]
# State: [17  3]
# State: [17  4]
# State: [17  5]
# State: [17  6]
# State: [17  7]
# State: [16  7]
# State: [15  7]
# State: [15  8]
# State: [15  9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [10  9]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 3 12]
# State: [ 3 13]
# State: [ 3 14]
# State: [ 3 15]
# Steps:  30
# Reached the goal!
# Goal: [12  4]
# Goal: [12  4]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 3 19]
# Goal: [ 1 18]
# Goal: [ 1 18]
# State: [2 4]
# State: [2 5]
# State: [2 6]
# State: [2 7]
# State: [2 8]
# State: [2 9]
# State: [ 2 10]
# State: [ 2 11]
# State: [ 2 12]
# State: [ 2 13]
# State: [ 2 14]
# State: [ 2 15]
# State: [ 2 16]
# State: [ 1 16]
# State: [ 1 17]
# State: [ 1 18]
# Steps:  15
# Reached the goal!
# Goal: [ 3 20]
# Goal: [ 3 20]
# State: [1 3]
# State: [1 4]
# State: [0 4]
# State: [0 4]
# Steps:  3
# Terminated!
# Goal: [ 2 13]
# Goal: [ 2 13]
# State: [10  2]
# State: [10  3]
# State: [10  4]
# State: [10  5]
# State: [10  6]
# State: [10  7]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 2 11]
# State: [ 2 12]
# State: [ 2 13]
# Steps:  19
# Reached the goal!
# Goal: [13 18]
# Goal: [13 18]
# State: [ 3 14]
# State: [ 4 14]
# State: [ 5 14]
# State: [ 6 14]
# State: [ 7 14]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# Goal: [17 14]
# Goal: [17 14]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 3 12]
# State: [ 4 12]
# Goal: [15 12]
# Goal: [15 12]
# State: [ 9 20]
# State: [ 9 20]
# Steps:  1
# Terminated!
# Goal: [20  6]
# Goal: [20  6]
# State: [20  8]
# State: [20  7]
# State: [20  6]
# Steps:  2
# Reached the goal!
# Goal: [16 19]
# Goal: [16 19]
# State: [6 1]
# State: [6 2]
# State: [6 3]
# State: [6 4]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [6 8]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [11  9]
# State: [12  9]
# State: [12 10]
# State: [12 11]
# State: [12 12]
# State: [13 12]
# State: [13 13]
# State: [14 13]
# State: [14 14]
# State: [15 14]
# State: [15 15]
# State: [15 16]
# State: [15 17]
# State: [15 18]
# State: [15 19]
# State: [16 19]
# Steps:  28
# Reached the goal!
# Goal: [7 8]
# Goal: [7 8]
# State: [17  7]
# State: [16  7]
# State: [16  8]
# State: [15  8]
# State: [15  9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [11  8]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# Steps:  15
# Reached the goal!
# Goal: [10  0]
# Goal: [10  0]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [10  9]
# State: [10  8]
# State: [10  7]
# State: [10  6]
# State: [10  5]
# State: [10  4]
# State: [10  3]
# State: [10  2]
# State: [10  1]
# State: [10  0]
# Steps:  12
# Reached the goal!
# Goal: [9 5]
# Goal: [9 5]
# State: [ 3 12]
# State: [ 4 12]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 5 10]
# State: [5 9]
# State: [6 9]
# State: [6 8]
# State: [7 8]
# State: [7 7]
# State: [7 6]
# State: [8 6]
# State: [8 5]
# State: [9 5]
# Steps:  13
# Reached the goal!
# Goal: [10 11]
# Goal: [10 11]
# State: [19 20]
# State: [19 20]
# Steps:  1
# Terminated!
# Goal: [13  0]
# Goal: [13  0]
# State: [7 0]
# State: [8 0]
# State: [9 0]
# State: [10  0]
# State: [11  0]
# State: [12  0]
# State: [13  0]
# Steps:  6
# Reached the goal!
# Goal: [8 7]
# Goal: [8 7]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [7 7]
# State: [8 7]
# Steps:  4
# Reached the goal!
# Goal: [14 11]
# Goal: [14 11]
# State: [11 14]
# State: [11 13]
# State: [11 12]
# State: [12 12]
# State: [12 11]
# State: [13 11]
# State: [14 11]
# Steps:  6
# Reached the goal!
# Goal: [13 15]
# Goal: [13 15]
# State: [6 0]
# State: [6 1]
# State: [6 2]
# State: [6 3]
# State: [6 4]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [6 8]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [12 12]
# State: [12 13]
# State: [12 14]
# State: [12 15]
# State: [13 15]
# Steps:  22
# Reached the goal!
# Goal: [ 1 17]
# Goal: [ 1 17]
# State: [18  2]
# State: [17  2]
# State: [16  2]
# State: [15  2]
# State: [15  3]
# State: [15  4]
# State: [15  5]
# State: [15  6]
# State: [15  7]
# State: [15  8]
# State: [15  9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [11  8]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# Goal: [9 3]
# Goal: [9 3]
# State: [9 6]
# State: [9 5]
# State: [9 4]
# State: [9 3]
# Steps:  3
# Reached the goal!
# Goal: [ 7 10]
# Goal: [ 7 10]
# State: [8 4]
# State: [8 5]
# State: [8 6]
# State: [8 7]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [ 7 10]
# Steps:  7
# Reached the goal!
# Goal: [1 9]
# Goal: [1 9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [10  9]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [5 8]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# Goal: [18  3]
# Goal: [18  3]
# State: [ 0 10]
# State: [ 0 11]
# State: [ 0 12]
# State: [ 0 13]
# State: [ 0 14]
# State: [ 0 15]
# State: [ 0 16]
# State: [ 0 17]
# State: [ 0 18]
# State: [ 0 19]
# State: [ 0 20]
# State: [ 0 20]
# Steps:  11
# Terminated!
# Goal: [1 8]
# Goal: [1 8]
# State: [20 15]
# State: [20 16]
# State: [20 17]
# State: [20 18]
# State: [20 19]
# State: [20 20]
# State: [20 20]
# Steps:  6
# Terminated!
# Goal: [7 3]
# Goal: [7 3]
# State: [ 9 18]
# State: [ 9 19]
# State: [ 9 20]
# State: [ 9 20]
# Steps:  3
# Terminated!
# Goal: [ 7 17]
# Goal: [ 7 17]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# State: [9 8]
# State: [9 9]
# Goal: [6 4]
# Goal: [6 4]
# State: [ 6 11]
# State: [ 6 10]
# State: [6 9]
# State: [6 8]
# State: [6 7]
# State: [6 6]
# State: [6 5]
# State: [6 4]
# Steps:  7
# Reached the goal!
# Goal: [20 15]
# Goal: [20 15]
# State: [14 13]
# State: [15 13]
# State: [15 14]
# State: [15 15]
# State: [16 15]
# State: [17 15]
# State: [18 15]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# State: [19 14]
# State: [19 15]
# Goal: [ 9 18]
# Goal: [ 9 18]
# State: [10  1]
# State: [9 1]
# State: [9 2]
# State: [9 3]
# State: [9 4]
# State: [9 5]
# State: [9 6]
# State: [9 7]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# State: [ 9 10]
# State: [10 10]
# Goal: [20 16]
# Goal: [20 16]
# State: [18 17]
# State: [18 16]
# State: [19 16]
# State: [20 16]
# Steps:  3
# Reached the goal!
# Goal: [11 18]
# Goal: [11 18]
# State: [16  5]
# State: [16  6]
# State: [16  7]
# State: [16  8]
# State: [16  9]
# State: [16 10]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [11 13]
# State: [11 14]
# State: [11 15]
# State: [11 16]
# State: [11 17]
# State: [11 18]
# Steps:  18
# Reached the goal!
# Goal: [17  0]
# Goal: [17  0]
# State: [16 12]
# State: [16 11]
# State: [16 10]
# State: [17 10]
# State: [17  9]
# State: [17  8]
# State: [17  7]
# State: [17  6]
# State: [17  5]
# State: [17  4]
# State: [17  3]
# State: [17  2]
# State: [17  1]
# State: [17  0]
# Steps:  13
# Reached the goal!
# Goal: [11 20]
# Goal: [11 20]
# State: [8 7]
# State: [8 8]
# State: [9 8]
# State: [10  8]
# State: [10  9]
# State: [11  9]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [11 13]
# State: [11 14]
# State: [11 15]
# State: [11 16]
# State: [11 17]
# State: [11 18]
# State: [11 19]
# State: [11 20]
# Steps:  16
# Reached the goal!
# Goal: [15  7]
# Goal: [15  7]
# State: [20 16]
# State: [20 17]
# State: [20 18]
# State: [20 19]
# State: [20 20]
# State: [20 20]
# Steps:  5
# Terminated!
# Goal: [ 1 20]
# Goal: [ 1 20]
# State: [15 20]
# State: [15 20]
# Steps:  1
# Terminated!
# Goal: [9 2]
# Goal: [9 2]
# State: [10  0]
# State: [10  1]
# State: [10  2]
# State: [9 2]
# Steps:  3
# Reached the goal!
# Goal: [12 19]
# Goal: [12 19]
# State: [12  3]
# State: [11  3]
# State: [10  3]
# State: [9 3]
# State: [9 4]
# State: [9 5]
# State: [9 6]
# State: [9 7]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [10 11]
# State: [11 11]
# State: [11 12]
# State: [12 12]
# State: [12 13]
# State: [12 14]
# State: [12 15]
# State: [12 16]
# State: [12 17]
# State: [12 18]
# State: [12 19]
# Steps:  22
# Reached the goal!
# Goal: [ 9 18]
# Goal: [ 9 18]
# State: [ 7 17]
# State: [ 7 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# State: [ 6 18]
# State: [ 5 18]
# Goal: [12 18]
# Goal: [12 18]
# State: [7 0]
# State: [7 1]
# State: [7 2]
# State: [7 3]
# State: [7 4]
# State: [7 5]
# State: [7 6]
# State: [7 7]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [10 11]
# State: [11 11]
# State: [11 12]
# State: [12 12]
# State: [12 13]
# State: [12 14]
# State: [12 15]
# State: [12 16]
# State: [12 17]
# State: [12 18]
# Steps:  23
# Reached the goal!
# Goal: [ 1 11]
# Goal: [ 1 11]
# State: [10  1]
# State: [9 1]
# State: [9 2]
# State: [9 3]
# State: [9 4]
# State: [9 5]
# State: [9 6]
# State: [9 7]
# State: [8 7]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 2 11]
# State: [ 1 11]
# Steps:  19
# Reached the goal!
# Goal: [12 16]
# Goal: [12 16]
# State: [15 12]
# State: [14 12]
# State: [13 12]
# State: [12 12]
# State: [12 13]
# State: [12 14]
# State: [12 15]
# State: [12 16]
# Steps:  7
# Reached the goal!
# Goal: [ 1 19]
# Goal: [ 1 19]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [12 10]
# Goal: [ 9 15]
# Goal: [ 9 15]
# State: [17 20]
# State: [17 20]
# Steps:  1
# Terminated!
# Goal: [12 13]
# Goal: [12 13]
# State: [ 4 12]
# State: [ 5 12]
# State: [ 6 12]
# State: [ 7 12]
# State: [ 7 11]
# State: [ 7 10]
# State: [7 9]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [11 13]
# State: [12 13]
# Steps:  17
# Reached the goal!
# Goal: [10  1]
# Goal: [10  1]
# State: [10 19]
# State: [10 20]
# State: [10 20]
# Steps:  2
# Terminated!
# Goal: [5 8]
# Goal: [5 8]
# State: [20 18]
# State: [20 19]
# State: [20 20]
# State: [20 20]
# Steps:  3
# Terminated!
# Goal: [20 18]
# Goal: [20 18]
# State: [ 1 16]
# State: [ 0 16]
# State: [ 0 16]
# Steps:  2
# Terminated!
# Goal: [ 7 16]
# Goal: [ 7 16]
# State: [12 17]
# State: [12 18]
# State: [12 19]
# State: [12 20]
# State: [12 20]
# Steps:  4
# Terminated!
# Goal: [11 17]
# Goal: [11 17]
# State: [11  2]
# State: [10  2]
# State: [9 2]
# State: [9 3]
# State: [9 4]
# State: [9 5]
# State: [9 6]
# State: [9 7]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [10 11]
# State: [11 11]
# State: [11 12]
# State: [11 13]
# State: [11 14]
# State: [11 15]
# State: [11 16]
# State: [11 17]
# Steps:  19
# Reached the goal!
# Goal: [12 15]
# Goal: [12 15]
# State: [ 4 13]
# State: [ 5 13]
# State: [ 6 13]
# State: [ 7 13]
# State: [ 7 14]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 6 15]
# State: [ 7 15]
# Goal: [ 1 10]
# Goal: [ 1 10]
# State: [14 11]
# State: [13 11]
# State: [12 11]
# State: [11 11]
# State: [11 10]
# State: [11  9]
# State: [10  9]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [5 8]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 1 10]
# Steps:  18
# Reached the goal!
# Goal: [10  4]
# Goal: [10  4]
# State: [4 5]
# State: [5 5]
# State: [6 5]
# State: [7 5]
# State: [8 5]
# State: [9 5]
# State: [9 4]
# State: [10  4]
# Steps:  7
# Reached the goal!
# Goal: [0 5]
# Goal: [0 5]
# State: [14 12]
# State: [14 11]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 10]
# State: [ 4 11]
# Goal: [2 5]
# Goal: [2 5]
# State: [17  9]
# State: [17 10]
# State: [16 10]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [9 9]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# Goal: [16  8]
# Goal: [16  8]
# State: [16  7]
# State: [16  8]
# Steps:  1
# Reached the goal!
# Goal: [12  2]
# Goal: [12  2]
# State: [4 7]
# State: [5 7]
# State: [6 7]
# State: [7 7]
# State: [8 7]
# State: [9 7]
# State: [10  7]
# State: [11  7]
# State: [11  6]
# State: [11  5]
# State: [11  4]
# State: [11  3]
# State: [11  2]
# State: [12  2]
# Steps:  13
# Reached the goal!
# Goal: [ 9 10]
# Goal: [ 9 10]
# State: [ 9 18]
# State: [ 9 17]
# State: [ 9 16]
# State: [ 9 15]
# State: [ 9 14]
# State: [ 9 13]
# State: [ 9 12]
# State: [ 9 11]
# State: [ 9 10]
# Steps:  8
# Reached the goal!
# Goal: [1 5]
# Goal: [1 5]
# State: [16 10]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [9 9]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# State: [ 4 10]
# State: [4 9]
# Goal: [ 1 14]
# Goal: [ 1 14]
# State: [6 8]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 2 11]
# State: [ 2 12]
# State: [ 2 13]
# State: [ 2 14]
# State: [ 1 14]
# Steps:  11
# Reached the goal!
# Goal: [7 5]
# Goal: [7 5]
# State: [8 8]
# State: [8 7]
# State: [8 6]
# State: [8 5]
# State: [7 5]
# Steps:  4
# Reached the goal!
# Goal: [20  5]
# Goal: [20  5]
# State: [11  3]
# State: [11  4]
# State: [11  5]
# State: [11  6]
# State: [11  7]
# State: [11  8]
# State: [11  9]
# State: [12  9]
# State: [12 10]
# State: [13 10]
# State: [14 10]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# Goal: [15  9]
# Goal: [15  9]
# State: [ 2 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 5 11]
# State: [ 6 11]
# State: [ 6 10]
# State: [6 9]
# State: [6 8]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [10  8]
# State: [10  9]
# State: [11  9]
# State: [12  9]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# State: [13 10]
# State: [13  9]
# Goal: [14 19]
# Goal: [14 19]
# State: [ 1 19]
# State: [ 0 19]
# State: [ 0 19]
# Steps:  2
# Terminated!
# Goal: [16  5]
# Goal: [16  5]
# State: [ 6 11]
# State: [ 6 10]
# State: [6 9]
# State: [6 8]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [10  8]
# State: [11  8]
# State: [12  8]
# State: [12  9]
# State: [12 10]
# State: [13 10]
# State: [14 10]
# State: [15 10]
# State: [15  9]
# State: [15  8]
# State: [15  7]
# State: [15  6]
# State: [15  5]
# State: [16  5]
# Steps:  20
# Reached the goal!
# Goal: [ 4 14]
# Goal: [ 4 14]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [6 8]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [ 4 10]
# State: [ 4 11]
# State: [ 4 12]
# State: [ 4 13]
# State: [ 4 14]
# Steps:  11
# Reached the goal!
# Goal: [ 3 19]
# Goal: [ 3 19]
# State: [20  8]
# State: [20  9]
# State: [19  9]
# State: [19 10]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# State: [18 10]
# State: [18 11]
# Goal: [18 11]
# Goal: [18 11]
# State: [19  8]
# State: [19  9]
# State: [18  9]
# State: [18 10]
# State: [18 11]
# Steps:  4
# Reached the goal!
# Goal: [20  3]
# Goal: [20  3]
# State: [17  9]
# State: [18  9]
# State: [18  8]
# State: [19  8]
# State: [19  7]
# State: [19  6]
# State: [19  5]
# State: [19  4]
# State: [19  3]
# State: [20  3]
# Steps:  9
# Reached the goal!
# Goal: [ 6 13]
# Goal: [ 6 13]
# State: [ 9 16]
# State: [ 9 15]
# State: [ 9 14]
# State: [ 9 13]
# State: [ 9 12]
# State: [ 9 11]
# State: [ 9 10]
# State: [9 9]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [6 9]
# State: [ 6 10]
# State: [ 6 11]
# State: [ 6 12]
# State: [ 6 13]
# Steps:  16
# Reached the goal!
# Goal: [16  7]
# Goal: [16  7]
# State: [14 11]
# State: [14 10]
# State: [15 10]
# State: [15  9]
# State: [15  8]
# State: [15  7]
# State: [16  7]
# Steps:  6
# Reached the goal!
# Goal: [0 3]
# Goal: [0 3]
# State: [17 19]
# State: [17 20]
# State: [17 20]
# Steps:  2
# Terminated!
# Goal: [18  4]
# Goal: [18  4]
# State: [19  8]
# State: [18  8]
# State: [18  7]
# State: [18  6]
# State: [18  5]
# State: [18  4]
# Steps:  5
# Reached the goal!
# Goal: [ 6 11]
# Goal: [ 6 11]
# State: [20  9]
# State: [19  9]
# State: [18  9]
# State: [17  9]
# State: [16  9]
# State: [15  9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [9 9]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [7 9]
# State: [6 9]
# State: [ 6 10]
# State: [ 6 11]
# Steps:  20
# Reached the goal!
# Goal: [ 9 16]
# Goal: [ 9 16]
# State: [20 19]
# State: [20 20]
# State: [20 20]
# Steps:  2
# Terminated!
# Goal: [14 20]
# Goal: [14 20]
# State: [14 11]
# State: [14 12]
# State: [14 13]
# State: [14 14]
# State: [14 15]
# State: [14 16]
# State: [14 17]
# State: [14 18]
# State: [14 19]
# State: [14 20]
# Steps:  9
# Reached the goal!
# Goal: [10 12]
# Goal: [10 12]
# State: [8 6]
# State: [8 7]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [10 11]
# State: [10 12]
# Steps:  8
# Reached the goal!
# Goal: [9 7]
# Goal: [9 7]
# State: [17 11]
# State: [16 11]
# State: [15 11]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [11  8]
# State: [10  8]
# State: [10  7]
# State: [9 7]
# Steps:  12
# Reached the goal!
# Goal: [5 5]
# Goal: [5 5]
# State: [16  9]
# State: [15  9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [9 9]
# State: [9 8]
# State: [9 7]
# State: [8 7]
# State: [8 6]
# State: [7 6]
# State: [7 5]
# State: [6 5]
# State: [5 5]
# Steps:  17
# Reached the goal!
# Goal: [ 7 17]
# Goal: [ 7 17]
# State: [ 0 16]
# State: [ 1 16]
# State: [ 2 16]
# State: [ 3 16]
# State: [ 4 16]
# State: [ 5 16]
# State: [ 6 16]
# State: [ 7 16]
# State: [ 7 17]
# Steps:  8
# Reached the goal!
# Goal: [17  4]
# Goal: [17  4]
# State: [11 17]
# State: [11 18]
# State: [11 19]
# State: [11 20]
# State: [11 20]
# Steps:  4
# Terminated!
# Goal: [20 17]
# Goal: [20 17]
# State: [12  8]
# State: [12  9]
# State: [12 10]
# State: [12 11]
# State: [13 11]
# State: [13 12]
# State: [14 12]
# State: [14 13]
# State: [15 13]
# State: [15 14]
# State: [16 14]
# State: [16 15]
# State: [16 16]
# State: [16 17]
# State: [17 17]
# State: [18 17]
# State: [19 17]
# State: [20 17]
# Steps:  17
# Reached the goal!
# Goal: [15 17]
# Goal: [15 17]
# State: [14 18]
# State: [14 17]
# State: [15 17]
# Steps:  2
# Reached the goal!
# Goal: [12 14]
# Goal: [12 14]
# State: [6 7]
# State: [6 8]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [11 13]
# State: [11 14]
# State: [12 14]
# Steps:  13
# Reached the goal!
# Goal: [18  0]
# Goal: [18  0]
# State: [17  8]
# State: [18  8]
# State: [18  7]
# State: [18  6]
# State: [18  5]
# State: [18  4]
# State: [18  3]
# State: [18  2]
# State: [18  1]
# State: [18  0]
# Steps:  9
# Reached the goal!
# Goal: [ 7 15]
# Goal: [ 7 15]
# State: [ 0 11]
# State: [ 1 11]
# State: [ 2 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 5 11]
# State: [ 6 11]
# State: [ 7 11]
# State: [ 7 12]
# State: [ 7 13]
# State: [ 7 14]
# State: [ 7 15]
# Steps:  11
# Reached the goal!
# Goal: [11 15]
# Goal: [11 15]
# State: [ 4 20]
# State: [ 4 20]
# Steps:  1
# Terminated!
# Goal: [20  8]
# Goal: [20  8]
# State: [12  5]
# State: [12  6]
# State: [12  7]
# State: [12  8]
# State: [12  9]
# State: [12 10]
# State: [13 10]
# State: [14 10]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# State: [15 10]
# State: [15 11]
# Goal: [19 16]
# Goal: [19 16]
# State: [17 15]
# State: [17 16]
# State: [18 16]
# State: [19 16]
# Steps:  3
# Reached the goal!
# Goal: [18 18]
# Goal: [18 18]
# State: [20  8]
# State: [19  8]
# State: [18  8]
# State: [18  9]
# State: [18 10]
# State: [18 11]
# State: [18 12]
# State: [18 13]
# State: [18 14]
# State: [18 15]
# State: [18 16]
# State: [18 17]
# State: [18 18]
# Steps:  12
# Reached the goal!
# Goal: [19  2]
# Goal: [19  2]
# State: [ 4 19]
# State: [ 4 20]
# State: [ 4 20]
# Steps:  2
# Terminated!
# Goal: [15 16]
# Goal: [15 16]
# State: [17 15]
# State: [16 15]
# State: [15 15]
# State: [15 16]
# Steps:  3
# Reached the goal!
# Goal: [13 20]
# Goal: [13 20]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# Goal: [18  4]
# Goal: [18  4]
# State: [16  6]
# State: [17  6]
# State: [17  5]
# State: [17  4]
# State: [18  4]
# Steps:  4
# Reached the goal!
# Goal: [6 6]
# Goal: [6 6]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# State: [19 12]
# State: [19 11]
# ...
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [9 9]
# State: [9 8]
# State: [9 7]
# State: [8 7]
# State: [8 6]
# State: [8 5]
# State: [8 4]
# State: [8 3]
# State: [8 2]
# State: [8 1]
# State: [8 0]
# Steps:  29
# Reached the goal!
# Goal: [13  0]
# Goal: [13  0]
# State: [19  1]
# State: [18  1]
# State: [17  1]
# State: [16  1]
# State: [15  1]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# State: [16  0]
# State: [15  0]
# Goal: [1 3]
# Goal: [1 3]
# State: [0 9]
# State: [1 9]
# State: [1 8]
# State: [1 7]
# State: [1 6]
# State: [1 5]
# State: [1 4]
# State: [1 3]
# Steps:  7
# Reached the goal!
# Goal: [ 4 18]
# Goal: [ 4 18]
# State: [19  3]
# State: [19  4]
# State: [19  5]
# State: [19  6]
# State: [19  7]
# State: [19  8]
# State: [18  8]
# State: [18  9]
# State: [17  9]
# State: [16  9]
# State: [16 10]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [11  8]
# State: [10  8]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# State: [8 8]
# State: [7 8]
# Goal: [16 16]
# Goal: [16 16]
# State: [10 10]
# State: [11 10]
# State: [12 10]
# State: [12 11]
# State: [12 12]
# State: [13 12]
# State: [13 13]
# State: [14 13]
# State: [14 14]
# State: [15 14]
# State: [15 15]
# State: [15 16]
# State: [16 16]
# Steps:  12
# Reached the goal!
# Goal: [11 13]
# Goal: [11 13]
# State: [ 0 15]
# State: [ 1 15]
# State: [ 2 15]
# State: [ 3 15]
# State: [ 4 15]
# State: [ 5 15]
# State: [ 6 15]
# State: [ 7 15]
# State: [ 7 14]
# State: [ 7 13]
# State: [ 7 12]
# State: [ 7 11]
# State: [ 7 10]
# State: [7 9]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [11 13]
# Steps:  23
# Reached the goal!
# Goal: [19  5]
# Goal: [19  5]
# State: [0 3]
# State: [0 4]
# State: [0 5]
# State: [1 5]
# State: [1 6]
# State: [2 6]
# State: [2 7]
# State: [2 8]
# State: [2 9]
# State: [ 2 10]
# State: [ 2 11]
# State: [ 2 12]
# State: [ 2 13]
# State: [ 2 14]
# State: [ 2 15]
# State: [ 2 16]
# State: [ 2 17]
# State: [ 2 18]
# State: [ 2 19]
# State: [ 2 20]
# State: [ 2 20]
# Steps:  20
# Terminated!
# Goal: [13 14]
# Goal: [13 14]
# State: [6 0]
# State: [6 1]
# State: [6 2]
# State: [6 3]
# State: [6 4]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [6 8]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [12 12]
# State: [12 13]
# State: [12 14]
# State: [13 14]
# Steps:  21
# Reached the goal!
# Goal: [12 16]
# Goal: [12 16]
# State: [7 7]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [11 10]
# State: [11 11]
# State: [11 12]
# State: [12 12]
# State: [12 13]
# State: [12 14]
# State: [12 15]
# State: [12 16]
# Steps:  14
# Reached the goal!
# Goal: [12  7]
# Goal: [12  7]
# State: [18 17]
# State: [18 18]
# State: [18 19]
# State: [18 20]
# State: [18 20]
# Steps:  4
# Terminated!
# Goal: [4 6]
# Goal: [4 6]
# State: [ 3 13]
# State: [ 4 13]
# State: [ 4 12]
# State: [ 4 11]
# State: [ 4 10]
# State: [4 9]
# State: [4 8]
# State: [4 7]
# State: [4 6]
# Steps:  8
# Reached the goal!
# Goal: [19 18]
# Goal: [19 18]
# State: [20 10]
# State: [19 10]
# State: [19 11]
# State: [19 12]
# State: [19 13]
# State: [19 14]
# State: [19 15]
# State: [19 16]
# State: [19 17]
# State: [19 18]
# Steps:  9
# Reached the goal!
# Goal: [15  6]
# Goal: [15  6]
# State: [2 3]
# State: [2 4]
# State: [2 5]
# State: [2 6]
# State: [2 7]
# State: [2 8]
# State: [2 9]
# State: [ 2 10]
# State: [ 2 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# State: [ 4 11]
# State: [ 3 11]
# Goal: [8 1]
# Goal: [8 1]
# State: [20 11]
# State: [19 11]
# State: [18 11]
# State: [18 10]
# State: [17 10]
# State: [16 10]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [10 10]
# State: [10  9]
# State: [10  8]
# State: [10  7]
# State: [9 7]
# State: [9 6]
# State: [8 6]
# State: [8 5]
# State: [8 4]
# State: [8 3]
# State: [8 2]
# State: [8 1]
# Steps:  22
# Reached the goal!
# Goal: [ 9 11]
# Goal: [ 9 11]
# State: [ 7 12]
# State: [ 7 11]
# State: [ 7 10]
# State: [7 9]
# State: [7 8]
# State: [8 8]
# State: [9 8]
# State: [9 9]
# State: [ 9 10]
# State: [ 9 11]
# Steps:  9
# Reached the goal!
# Goal: [10  8]
# Goal: [10  8]
# State: [13 11]
# State: [13 10]
# State: [12 10]
# State: [12  9]
# State: [12  8]
# State: [11  8]
# State: [10  8]
# Steps:  6
# Reached the goal!
# Goal: [20  0]
# Goal: [20  0]
# State: [12  8]
# State: [12  9]
# State: [12 10]
# State: [13 10]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# State: [14 10]
# State: [14 11]
# Goal: [17 17]
# Goal: [17 17]
# State: [15 16]
# State: [16 16]
# State: [16 17]
# State: [17 17]
# Steps:  3
# Reached the goal!
# Goal: [10  6]
# Goal: [10  6]
# State: [15  3]
# State: [15  4]
# State: [15  5]
# State: [15  6]
# State: [15  7]
# State: [15  8]
# State: [15  9]
# State: [15 10]
# State: [14 10]
# State: [13 10]
# State: [12 10]
# State: [11 10]
# State: [11  9]
# State: [11  8]
# State: [11  7]
# State: [10  7]
# State: [10  6]
# Steps:  16
# Reached the goal!
# Goal: [10  6]
# Goal: [10  6]
# State: [9 7]
# State: [9 6]
# State: [10  6]
# Steps:  2
# Reached the goal!
# Goal: [12 18]
# Goal: [12 18]
# State: [18 11]
# State: [18 12]
# State: [18 13]
# State: [18 14]
# State: [17 14]
# State: [16 14]
# State: [15 14]
# State: [14 14]
# State: [13 14]
# State: [12 14]
# State: [12 15]
# State: [12 16]
# State: [12 17]
# State: [12 18]
# Steps:  13
# Reached the goal!
# Goal: [ 9 12]
# Goal: [ 9 12]
# State: [0 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# State: [2 2]
# State: [1 2]
# Goal: [7 8]
# Goal: [7 8]
# State: [9 6]
# State: [9 7]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# Steps:  4
# Reached the goal!
# Goal: [6 6]
# Goal: [6 6]
# State: [12 17]
# State: [12 18]
# State: [12 19]
# State: [12 20]
# State: [12 20]
# Steps:  4
# Terminated!
# Goal: [13 16]
# Goal: [13 16]
# State: [0 2]
# State: [1 2]
# State: [1 3]
# State: [1 4]
# State: [1 5]
# State: [1 6]
# State: [1 7]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# State: [2 8]
# State: [1 8]
# Goal: [18  0]
# Goal: [18  0]
# State: [10 12]
# State: [10 13]
# State: [10 14]
# State: [10 15]
# State: [10 16]
# State: [11 16]
# State: [11 17]
# State: [11 18]
# State: [11 19]
# State: [12 19]
# State: [12 20]
# State: [12 20]
# Steps:  11
# Terminated!
# Goal: [ 1 17]
# Goal: [ 1 17]
# State: [20 17]
# State: [20 18]
# State: [20 19]
# State: [20 20]
# State: [20 20]
# Steps:  4
# Terminated!
# Goal: [19 16]
# Goal: [19 16]
# State: [1 3]
# State: [1 4]
# State: [1 5]
# State: [1 6]
# State: [1 7]
# State: [1 8]
# State: [2 8]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# State: [1 9]
# State: [2 9]
# Goal: [ 4 16]
# Goal: [ 4 16]
# State: [17 16]
# State: [17 17]
# State: [17 18]
# State: [17 19]
# State: [17 20]
# State: [17 20]
# Steps:  5
# Terminated!
# Goal: [13 14]
# Goal: [13 14]
# State: [ 2 19]
# State: [ 2 20]
# State: [ 2 20]
# Steps:  2
# Terminated!
# Goal: [19  8]
# Goal: [19  8]
# State: [20  5]
# State: [20  6]
# State: [20  7]
# State: [20  8]
# State: [19  8]
# Steps:  4
# Reached the goal!
# Goal: [20  1]
# Goal: [20  1]
# State: [10 18]
# State: [11 18]
# State: [12 18]
# State: [12 19]
# State: [12 20]
# State: [12 20]
# Steps:  5
# Terminated!
# Goal: [10 11]
# Goal: [10 11]
# State: [9 9]
# State: [10  9]
# State: [10 10]
# State: [10 11]
# Steps:  3
# Reached the goal!
# Goal: [0 1]
# Goal: [0 1]
# State: [17 16]
# State: [17 17]
# State: [17 18]
# State: [17 19]
# State: [17 20]
# State: [17 20]
# Steps:  5
# Terminated!
# Goal: [5 7]
# Goal: [5 7]
# State: [ 2 19]
# State: [ 3 19]
# State: [ 4 19]
# State: [ 5 19]
# State: [ 6 19]
# State: [ 6 20]
# State: [ 6 20]
# Steps:  6
# Terminated!
# Goal: [10 17]
# Goal: [10 17]
# State: [11  8]
# State: [10  8]
# State: [10  9]
# State: [10 10]
# State: [10 11]
# State: [10 12]
# State: [10 13]
# State: [10 14]
# State: [10 15]
# State: [10 16]
# State: [10 17]
# Steps:  10
# Reached the goal!
# Goal: [20 16]
# Goal: [20 16]
# State: [11 18]
# State: [11 17]
# State: [11 16]
# State: [12 16]
# State: [13 16]
# State: [14 16]
# State: [15 16]
# State: [16 16]
# State: [17 16]
# State: [18 16]
# State: [19 16]
# State: [20 16]
# Steps:  11
# Reached the goal!
# Success rate: 0.543
# Crash rate: 0.226
# Oscillate rate: 0.231
