# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
# Out:
# 2023-07-19 15:29:53.977175: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-19 15:29:54.404726: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-19 15:29:54.406690: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 15:29:56.424435: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Define the Q-Network model
def create_q_network(input_shape, action_space):
    model = Sequential(
        [
            tf.keras.Input(shape=input_shape),
            Dense(32, activation='relu'),
            Dense(32, activation='relu'),
            Dense(action_space, activation='linear')
        ]
    )
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
    return model

# %%
class ENV():
    def __init__(self):
        self.steps = 0
        self.env_col = 11
        self.env_row = 11
        self.state = (5, 5)
        self.action_space = 4
        self.reward = 0
        self.done = False
        self.goal = [(1, 1),(4,5)]

    def reset(self,i):
        self.goal_x = self.goal[i-1]
        self.state = np.random.randint(0, min(self.env_col, self.env_row), size=2)
        self.reward = 0
        self.done = False
        self.steps = 0
        return self.state, self.goal_x
    
    def step(self, action):
        self.steps += 1
        if action == 0: # up
            self.state = (self.state[0], self.state[1] + 1)
        elif action == 1: # down
            self.state = (self.state[0], self.state[1] - 1)
        elif action == 2: # left
            self.state = (self.state[0] - 1, self.state[1])
        elif action == 3: # right
            self.state = (self.state[0] + 1, self.state[1])
        else:
            raise ValueError("Invalid action")
        if self.state == self.goal_x:
            self.reward = 100
            self.done = True
        elif self.state[0] < 0 or self.state[0] >= self.env_col or self.state[1] < 0 or self.state[1] >= self.env_row:
            self.reward = -100
            self.done = True
        elif self.steps >= 50:
            self.reward = -100
            self.done = True
        else:
            self.reward = -1
        return self.state, self.reward, self.done

# %%
#Define the DQN agent
class DQNAgent:
    def __init__(self, state_shape, action_space):
        self.state_shape = state_shape
        self.action_space = action_space
        self.memory = []
        self.gamma = 0.95  # Discount factor
        self.epsilon = 0.9  # Exploration rate
        self.epsilon_decay = 0.995  # Decay rate for exploration rate
        self.epsilon_min = 0.01  # Minimum exploration rate
        self.model = create_q_network(state_shape, action_space)
    
    def clear_buffer(self):
        self.memory = []

    def remember(self, state,input, goal, action, reward, next_state, done):
        self.memory.append((state, input, goal,  action, reward, next_state, done))

    def act(self, input):
        if np.random.rand() < self.epsilon:
            return np.random.choice(self.action_space)
        # print("state in action: ",state)

        input = np.reshape(input, 4)
        input = tf.convert_to_tensor(input)
        input = tf.expand_dims(input, 0)
        
        print("Predicting")
        q_values = self.model.predict(input, verbose=0)
        return np.argmax(q_values[0])

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        # Debug
        # print(self.memory)
        # batch = np.random.choice(self.memory, batch_size, replace=False)
        batch_ch = np.random.choice(len(self.memory), batch_size, replace=False)
        batch = [self.memory[i] for i in batch_ch]
        for state, input, goal, action, reward, next_state, done in batch:
            state = np.reshape(state, 2)
            next_state = np.reshape(next_state, 2)
            target = reward
            input_2 = []
            input_2.append(next_state)
            input_2.append(goal)
            input_2 = np.reshape(input_2, 4)
            print("printing input_2: ",input_2)
            if not done:
                # print(next_state.shape)
                input_2 = tf.convert_to_tensor(input_2)
                input_2 = tf.expand_dims(input_2, 0)
                target = reward + self.gamma * np.amax(self.model.predict(input_2)[0])
            # print(state.shape)
            input = tf.convert_to_tensor(input)
            input = tf.expand_dims(input, 0)
            print("Predicting")
            target_f = self.model.predict(input, verbose=0)
            target_f[0][action] = target
            # print(state[0], state[1])
            print("Fitting model")
            self.model.fit(input, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Initialize the environment and agent
state_shape = (4,)  # Example state shape, adjust according to your actual state representation # Only x and y coordinates
action_space = 4  # Example action space size, adjust according to your actual actions # 4 actions: up, down, left, right
agent = DQNAgent(state_shape, action_space)
env = ENV()

# %%
#Training loop
num_episodes = 20  # Set the number of training episodes
batch_size = 32  # Set the batch size for replay
total_reward = []
i=0
for episode in range(num_episodes):
    print("Episode: ", episode)
    if episode%10 == 0:
        agent.clear_buffer()
        env = ENV()
        i+=1
    input = []
    print("IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!")
    state, goal = env.reset(i)
    input.append(state)
    input.append(goal)
    # print("prinintg concat: ", input)

    input = np.reshape(input, 4)
    print("printing input ", input)
    state = np.reshape(state, 2)
    goal = np.reshape(goal, 2)
    # print("prininting state and goal ", state, goal)
    done = False
    episode_reward = 0
    # if episode%10 == 0 and episode != 0 :
    #     agent.model.save("model_dqn_diff_start_diff_goal_{}.h5".format(episode))
    while not done:
        action = agent.act(input)
        next_state, reward, done = env.step(action)
        next_state = np.reshape(next_state, 2)
        print("printing GOAL: ", goal)
        agent.remember(state, input ,goal, action, reward, next_state, done)
        state = next_state
        episode_reward += reward
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
    total_reward.append(episode_reward)
# Out:
# Episode:  0
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [ 8 10  1  1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# Episode:  1
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [9 2 1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# Episode:  2
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [ 1 10  1  1]
# printing GOAL:  [1 1]
# Episode:  3
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [6 1 1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# Predicting
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# Predicting
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# Predicting
# printing GOAL:  [1 1]
# Predicting
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing GOAL:  [1 1]
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 58ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 47ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 45ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 51ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# Predicting
# printing GOAL:  [1 1]
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 10  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# Episode:  4
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [5 4 1 1]
# printing GOAL:  [1 1]
# printing input_2:  [ 7 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [ 7 10  1  1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [ 7 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 10  1  1]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# Predicting
# printing GOAL:  [1 1]
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 10  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  7  1  1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# Predicting
# printing GOAL:  [1 1]
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 10  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 40ms/step
# Predicting
# Fitting model
# printing input_2:  [10  3  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [11  3  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [5 3 1 1]
# 1/1 [==============================] - 0s 41ms/step
# Predicting
# Fitting model
# printing input_2:  [8 8 1 1]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [8 9 1 1]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [6 2 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [ 7 10  1  1]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [6 3 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  6  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  1  1]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [10  8  1  1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 10  1  1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [10  5  1  1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [7 8 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 1 1]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 48ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 1 1]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [9 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [7 9 1 1]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing GOAL:  [1 1]
# printing input_2:  [ 9 11  1  1]
# Predicting
# Fitting model
# printing input_2:  [5 4 1 1]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 27ms/step
# Predicting
# Fitting model
# printing input_2:  [9 3 1 1]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [9 5 1 1]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [6 4 1 1]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# ...
# Predicting
# Fitting model
# printing input_2:  [1 2 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [1 8 4 5]
# 1/1 [==============================] - 0s 153ms/step
# Predicting
# Fitting model
# printing input_2:  [1 5 4 5]
# 1/1 [==============================] - 0s 56ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 10  4  5]
# 1/1 [==============================] - 0s 60ms/step
# Predicting
# Fitting model
# printing input_2:  [1 3 4 5]
# 1/1 [==============================] - 0s 70ms/step
# Predicting
# Fitting model
# printing input_2:  [3 8 4 5]
# 1/1 [==============================] - 0s 44ms/step
# Predicting
# Fitting model
# printing input_2:  [2 3 4 5]
# 1/1 [==============================] - 0s 55ms/step
# Predicting
# Fitting model
# printing input_2:  [1 1 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [8 6 4 5]
# 1/1 [==============================] - 0s 47ms/step
# Predicting
# Fitting model
# printing input_2:  [1 6 4 5]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [7 4 4 5]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [5 1 4 5]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [2 7 4 5]
# 1/1 [==============================] - 0s 41ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 4 5]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [0 4 4 5]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [2 2 4 5]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [2 2 4 5]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 11  4  5]
# Predicting
# Fitting model
# printing input_2:  [1 3 4 5]
# 1/1 [==============================] - 0s 63ms/step
# Predicting
# Fitting model
# Predicting
# printing GOAL:  [4 5]
# printing input_2:  [9 8 4 5]
# 1/1 [==============================] - 0s 62ms/step
# Predicting
# Fitting model
# printing input_2:  [ 5 -1  4  5]
# Predicting
# Fitting model
# printing input_2:  [7 4 4 5]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [1 4 4 5]
# 1/1 [==============================] - 0s 51ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 4 5]
# 1/1 [==============================] - 0s 45ms/step
# Predicting
# Fitting model
# printing input_2:  [3 1 4 5]
# 1/1 [==============================] - 0s 68ms/step
# Predicting
# Fitting model
# printing input_2:  [5 1 4 5]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  4  5]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [9 7 4 5]
# 1/1 [==============================] - 0s 51ms/step
# Predicting
# Fitting model
# printing input_2:  [7 3 4 5]
# 1/1 [==============================] - 0s 52ms/step
# Predicting
# Fitting model
# printing input_2:  [2 9 4 5]
# 1/1 [==============================] - 0s 58ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 11  4  5]
# Predicting
# Fitting model
# printing input_2:  [2 5 4 5]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [1 1 4 5]
# 1/1 [==============================] - 0s 55ms/step
# Predicting
# Fitting model
# printing input_2:  [1 6 4 5]
# 1/1 [==============================] - 0s 52ms/step
# Predicting
# Fitting model
# printing input_2:  [2 8 4 5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [5 1 4 5]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [3 8 4 5]
# 1/1 [==============================] - 0s 41ms/step
# Predicting
# Fitting model
# printing input_2:  [1 3 4 5]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [7 1 4 5]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [8 5 4 5]
# 1/1 [==============================] - 0s 85ms/step
# Predicting
# Fitting model
# printing input_2:  [4 1 4 5]
# 1/1 [==============================] - 0s 67ms/step
# Predicting
# Fitting model
# printing input_2:  [-1  5  4  5]
# Predicting
# Fitting model
# printing input_2:  [5 1 4 5]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 4 5]
# 1/1 [==============================] - 0s 45ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [-1 10  4  5]
# Predicting
# Fitting model
# printing input_2:  [1 2 4 5]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [2 5 4 5]
# 1/1 [==============================] - 0s 82ms/step
# Predicting
# Fitting model
# printing input_2:  [1 4 4 5]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [2 1 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# Episode:  17
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [10  9  4  5]
# printing GOAL:  [4 5]
# printing input_2:  [1 4 4 5]
# 1/1 [==============================] - 0s 50ms/step
# Predicting
# Fitting model
# printing input_2:  [2 3 4 5]
# 1/1 [==============================] - 0s 59ms/step
# Predicting
# Fitting model
# printing input_2:  [4 1 4 5]
# 1/1 [==============================] - 0s 88ms/step
# Predicting
# Fitting model
# printing input_2:  [8 6 4 5]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [2 1 4 5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 4 5]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 10  4  5]
# 1/1 [==============================] - 0s 52ms/step
# Predicting
# Fitting model
# printing input_2:  [8 4 4 5]
# 1/1 [==============================] - 0s 70ms/step
# Predicting
# Fitting model
# printing input_2:  [2 5 4 5]
# 1/1 [==============================] - 0s 65ms/step
# Predicting
# Fitting model
# printing input_2:  [2 4 4 5]
# 1/1 [==============================] - 0s 44ms/step
# Predicting
# Fitting model
# printing input_2:  [5 1 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [2 2 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [1 3 4 5]
# 1/1 [==============================] - 0s 66ms/step
# Predicting
# Fitting model
# printing input_2:  [0 9 4 5]
# 1/1 [==============================] - 0s 61ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 47ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 4 5]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [0 8 4 5]
# 1/1 [==============================] - 0s 58ms/step
# Predicting
# Fitting model
# printing input_2:  [6 1 4 5]
# 1/1 [==============================] - 0s 62ms/step
# Predicting
# Fitting model
# printing input_2:  [ 0 10  4  5]
# 1/1 [==============================] - 0s 41ms/step
# Predicting
# Fitting model
# printing input_2:  [0 4 4 5]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [ 9 10  4  5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [1 8 4 5]
# 1/1 [==============================] - 0s 47ms/step
# Predicting
# Fitting model
# printing input_2:  [2 4 4 5]
# 1/1 [==============================] - 0s 86ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  4  5]
# Predicting
# Fitting model
# printing input_2:  [3 1 4 5]
# 1/1 [==============================] - 0s 53ms/step
# Predicting
# Fitting model
# printing input_2:  [7 3 4 5]
# 1/1 [==============================] - 0s 44ms/step
# Predicting
# Fitting model
# printing input_2:  [9 7 4 5]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [4 1 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 4 5]
# 1/1 [==============================] - 0s 66ms/step
# Predicting
# Fitting model
# printing input_2:  [1 2 4 5]
# 1/1 [==============================] - 0s 83ms/step
# Predicting
# Fitting model
# printing input_2:  [2 8 4 5]
# 1/1 [==============================] - 0s 51ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 4 5]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# Episode:  18
# IM RESETTING BOTH GOAL AND START POINT !!!!!!!!!!!!!!!!!
# printing input  [5 4 4 5]
# printing GOAL:  [4 5]
# printing input_2:  [4 1 4 5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [2 8 4 5]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 45ms/step
# Predicting
# Fitting model
# printing input_2:  [9 7 4 5]
# 1/1 [==============================] - 0s 61ms/step
# Predicting
# Fitting model
# printing input_2:  [2 2 4 5]
# 1/1 [==============================] - 0s 56ms/step
# Predicting
# Fitting model
# printing input_2:  [1 8 4 5]
# 1/1 [==============================] - 0s 50ms/step
# Predicting
# Fitting model
# printing input_2:  [9 7 4 5]
# 1/1 [==============================] - 0s 50ms/step
# Predicting
# Fitting model
# printing input_2:  [9 6 4 5]
# 1/1 [==============================] - 0s 40ms/step
# Predicting
# Fitting model
# printing input_2:  [2 2 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [1 5 4 5]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [1 1 4 5]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  4  5]
# Predicting
# Fitting model
# printing input_2:  [8 8 4 5]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [3 7 4 5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [ 5 -1  4  5]
# Predicting
# Fitting model
# printing input_2:  [2 9 4 5]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [7 3 4 5]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [1 5 4 5]
# 1/1 [==============================] - 0s 35ms/step
# Predicting
# Fitting model
# printing input_2:  [2 5 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [1 4 4 5]
# 1/1 [==============================] - 0s 64ms/step
# Predicting
# Fitting model
# printing input_2:  [4 1 4 5]
# 1/1 [==============================] - 0s 63ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 33ms/step
# Predicting
# Fitting model
# printing input_2:  [6 1 4 5]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [0 4 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 4 5]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [9 8 4 5]
# 1/1 [==============================] - 0s 26ms/step
# Predicting
# Fitting model
# printing input_2:  [1 4 4 5]
# 1/1 [==============================] - 0s 64ms/step
# Predicting
# Fitting model
# printing input_2:  [11  9  4  5]
# Predicting
# Fitting model
# printing input_2:  [-1  5  4  5]
# Predicting
# Fitting model
# printing input_2:  [8 4 4 5]
# 1/1 [==============================] - 0s 28ms/step
# Predicting
# Fitting model
# printing input_2:  [9 9 4 5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [ 0 -1  4  5]
# Predicting
# Fitting model
# printing GOAL:  [4 5]
# printing input_2:  [9 6 4 5]
# 1/1 [==============================] - 0s 25ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 11  4  5]
# Predicting
# Fitting model
# printing input_2:  [2 4 4 5]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [7 3 4 5]
# 1/1 [==============================] - 0s 39ms/step
# Predicting
# Fitting model
# printing input_2:  [0 4 4 5]
# 1/1 [==============================] - 0s 32ms/step
# Predicting
# Fitting model
# printing input_2:  [ 0 -1  4  5]
# Predicting
# Fitting model
# printing input_2:  [1 4 4 5]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [5 1 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 4 5]
# 1/1 [==============================] - 0s 45ms/step
# Predicting
# Fitting model
# printing input_2:  [1 2 4 5]
# 1/1 [==============================] - 0s 38ms/step
# Predicting
# Fitting model
# printing input_2:  [6 1 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [11  9  4  5]
# Predicting
# Fitting model
# printing input_2:  [9 9 4 5]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [5 2 4 5]
# 1/1 [==============================] - 0s 37ms/step
# Predicting
# Fitting model
# printing input_2:  [1 3 4 5]
# 1/1 [==============================] - 0s 58ms/step
# Predicting
# Fitting model
# printing input_2:  [1 8 4 5]
# 1/1 [==============================] - 0s 54ms/step
# Predicting
# Fitting model
# printing input_2:  [1 5 4 5]
# 1/1 [==============================] - 0s 48ms/step
# Predicting
# Fitting model
# printing input_2:  [8 6 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [ 8 11  4  5]
# Predicting
# Fitting model
# printing input_2:  [7 4 4 5]
# 1/1 [==============================] - 0s 31ms/step
# Predicting
# Fitting model
# printing input_2:  [7 1 4 5]
# 1/1 [==============================] - 0s 40ms/step
# Predicting
# Fitting model
# printing input_2:  [2 5 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# printing input_2:  [-1  5  4  5]
# Predicting
# Fitting model
# printing input_2:  [ 1 10  4  5]
# 1/1 [==============================] - 0s 24ms/step
# Predicting
# Fitting model
# printing input_2:  [ 5 -1  4  5]
# Predicting
# Fitting model
# printing input_2:  [ 9 10  4  5]
# 1/1 [==============================] - 0s 29ms/step
# Predicting
# Fitting model
# printing input_2:  [7 2 4 5]
# 1/1 [==============================] - 0s 30ms/step
# Predicting
# Fitting model
# printing input_2:  [2 6 4 5]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [ 1 10  4  5]
# 1/1 [==============================] - 0s 42ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 54ms/step
# Predicting
# Fitting model
# printing input_2:  [2 7 4 5]
# 1/1 [==============================] - 0s 34ms/step
# Predicting
# Fitting model
# printing input_2:  [4 1 4 5]
# 1/1 [==============================] - 0s 43ms/step
# Predicting
# Fitting model
# Predicting
# printing GOAL:  [4 5]
# printing input_2:  [2 9 4 5]
# 1/1 [==============================] - 0s 36ms/step
# Predicting
# Fitting model
# printing input_2:  [1 9 4 5]
# 1/1 [==============================] - 0s 46ms/step
# Predicting
# Fitting model
# printing input_2:  [1 5 4 5]
# 1/1 [==============================] - 0s 259ms/step
# Predicting
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
agent.model.save("one_model_all_1.h5")

# %% [markdown]
# TESTING THE MODEL

# %%
#Define the DQN agent for TESTING
class DQNAgent_test:
    def __init__(self, state_shape, action_space):
        self.state_shape = state_shape
        self.action_space = action_space
        self.memory = []
        self.gamma = 0.95  # Discount factor
        self.epsilon = 0.9  # Exploration rate
        self.epsilon_decay = 0.995  # Decay rate for exploration rate
        self.epsilon_min = 0.01  # Minimum exploration rate
        self.model = load_model('one_model_all_2_grid_4_4.h5')

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.choice(self.action_space)
        # print("state in action: ",state)
        state = np.reshape(state, self.state_shape)
        print("prinintg rereshaped state: ", state)
        state = tf.convert_to_tensor(state)
        state = tf.expand_dims(state, 0)
        print("Predicting")
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        # Debug
        # print(self.memory)
        # batch = np.random.choice(self.memory, batch_size, replace=False)
        batch_ch = np.random.choice(len(self.memory), batch_size, replace=False)
        batch = [self.memory[i] for i in batch_ch]
        for state, action, reward, next_state, done in batch:
            state = np.reshape(state, self.state_shape)
            next_state = np.reshape(next_state, self.state_shape)
            target = reward
            if not done:
                # print(next_state.shape)
                next_state = tf.convert_to_tensor(next_state)
                next_state = tf.expand_dims(next_state, 0)
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
            # print(state.shape)
            state = tf.convert_to_tensor(state)
            state = tf.expand_dims(state, 0)
            print("Predicting")
            target_f = self.model.predict(state)
            target_f[0][action] = target
            # print(state[0], state[1])
            print("Fitting model")
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
class ENV_test():
    def __init__(self):
        self.steps = 0
        self.env_col = 4
        self.env_row = 4
        self.state = (1, 2)
        self.action_space = 4
        self.reward = 0
        self.done = False
        self.goal = (1,1)

    def reset(self):
        self.goal_x = self.goal
        self.state = np.random.randint(0, min(self.env_col, self.env_row), size=2)
        self.reward = 0
        self.done = False
        self.steps = 0
        return self.state, self.goal_x
    
    def step(self, action):
        self.steps += 1
        if action == 0: # up
            self.state = (self.state[0], self.state[1] + 1)
        elif action == 1: # down
            self.state = (self.state[0], self.state[1] - 1)
        elif action == 2: # left
            self.state = (self.state[0] - 1, self.state[1])
        elif action == 3: # right
            self.state = (self.state[0] + 1, self.state[1])
        else:
            raise ValueError("Invalid action")
        if self.state == self.goal_x:
            self.reward = 100
            self.done = True
        elif self.state[0] < 0 or self.state[0] >= self.env_col or self.state[1] < 0 or self.state[1] >= self.env_row:
            self.reward = -100
            self.done = True
        elif self.steps >= 50:
            self.reward = -100
            self.done = True
        else:
            self.reward = -1
        return self.state, self.reward, self.done

# %%
# Initialize the environment and agent
state_shape = (4,)  # Example state shape, adjust according to your actual state representation # Only x and y coordinates
action_space = 4  # Example action space size, adjust according to your actual actions # 4 actions: up, down, left, right
agent = DQNAgent_test(4, action_space)
env = ENV_test()

# %%
# Use the trained agent to control the agent in the environment
state, goal = env.reset()
print("goal: ", goal)
print("state: ", state)
# model = load_model('model_dqn_diff_start_diff_goal_30.h5')
done = False

while not done:
    input = []
    input.append(state)
    input.append(goal)
    # print("prinintg concat: ", input)
    input = np.reshape(input, 4)
    action = agent.act(input)
    next_state, _, done = env.step(action)
    next_state = np.reshape(next_state, 2)
    input_2 = []
    input_2.append(next_state)
    input_2.append(goal)
    input_2 = np.reshape(input_2, 4)
    # Take action with the agent in the environment
    state = next_state
    print(state)
# Out:
# goal:  (1, 1)
# state:  [5 4]
# [5 3]
# prinintg rereshaped state:  [5 3 1 1]
# Predicting
# 1/1 [==============================] - 0s 20ms/step
# [6 3]
# [5 3]
# [5 4]
# [6 4]
# [6 5]
# [7 5]
# [7 4]
# [6 4]
# [6 5]
# [7 5]
# [7 6]
# [6 6]
# [5 6]
# [5 5]
# [4 5]
# [4 4]
# [5 4]
# [4 4]
# [3 4]
# [2 4]
# prinintg rereshaped state:  [2 4 1 1]
# Predicting
# 1/1 [==============================] - 0s 23ms/step
# [3 4]
# [4 4]
# [3 4]
# [3 5]
# [3 6]
# [4 6]
# [4 7]
# [5 7]
# prinintg rereshaped state:  [5 7 1 1]
# Predicting
# 1/1 [==============================] - 0s 30ms/step
# [6 7]
# [7 7]
# [8 7]
# [8 8]
# [7 8]
# [7 7]
# [6 7]
# [6 6]
# [6 5]
# [5 5]
# prinintg rereshaped state:  [5 5 1 1]
# Predicting
# 1/1 [==============================] - 0s 40ms/step
# [6 5]
# [6 6]
# [6 5]
# [5 5]
# [5 6]
# [6 6]
# [7 6]
# [8 6]
# [9 6]
# [9 7]
# [10  7]

# %% [markdown]
# PLOTTING THE MODEL

# %%
import matplotlib.pyplot as plt
plt.plot(total_reward)
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.show()
