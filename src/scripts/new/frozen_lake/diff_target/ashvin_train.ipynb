# %% [markdown]
# ### Deep Q Network for navigating through a grid world with different goal locations
# #### Reward system 1: Negative of euclidean distance to goal - Did not converge for 250 episodes
# #### Reward system 2: As per the paper - "Autonomous Navigation of an AMR using Deep Reinforcement Learning in a Warehouse Environment" (Episode terminates if the bot hits the bounds)
#
# ##### Final model name: doublenet_dqn_diff_start_diff_goal_300ep_pt2.h5

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
# Out:
# 2023-07-23 20:39:33.527451: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-23 20:39:34.210113: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-23 20:39:34.213546: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-23 20:39:36.358135: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# print gpu info
print(tf.config.list_physical_devices('GPU'))

# %%
# Create a neural network model
def create_model(input_shape, num_actions):
    model = Sequential([
        Input(shape=input_shape),
        Dense(16, activation='relu'),
        Dense(32, activation='relu'),
        Dense(num_actions, activation='linear')
    ])
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.0008))
    return model

# %%
# Create a class for the environment
class Env():
    def __init__(self, grid_size=11, max_steps=500):
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.goal = np.random.randint(0, grid_size, size=2) # random goal
        print('Goal:', self.goal)

        self.rewards = np.zeros((grid_size, grid_size))
        self.reset()

    def reset(self):
        self.pos = np.random.randint(0, self.grid_size, size=2)
        self.steps = 0
        self.done = False
        return self.pos
    
    def reset_goal(self):
        self.goal = np.random.randint(0, self.grid_size, size=2)
        print('Goal:', self.goal)
        for i in range(self.grid_size):
            for j in range(self.grid_size):
                self.rewards[i, j] = -self.euclidean_distance_from_goal(np.array([i, j]))
        self.rewards[self.goal[0], self.goal[1]] = 100
        return self.goal
    

    def step(self, action): # As per the paper
        self.steps += 1
        prev_pos = self.pos.copy()
        if action == 0 and self.pos[0] < self.grid_size - 1: # right
            self.pos[0] += 1
        elif action == 1 and self.pos[0] > 0: # left
            self.pos[0] -= 1
        elif action == 2 and self.pos[1] > 0: # down
            self.pos[1] -= 1
        elif action == 3 and self.pos[1] < self.grid_size - 1: # up
            self.pos[1] += 1
        else:
            reward = -150
            self.done = True
            return self.pos, reward, self.done, True # TODO: The episode is not terminated.
        if np.array_equal(self.pos, self.goal):
            self.done = True
            reward = 500
        elif self.steps >= self.max_steps:
            self.done = True
            reward = self.rewards[self.pos[0], self.pos[1]]
        else:
            if self.euclidean_distance_from_goal(self.pos) < self.euclidean_distance_from_goal(prev_pos):
                reward = 10
            else:
                reward = -10
        return self.pos, reward, self.done, False
        

    def euclidean_distance_from_goal(self, pos):
        dist = np.sqrt(np.sum((pos - self.goal) ** 2))
        return dist

# %%
# Create an agent class
class Agent():
    def __init__(self, env, model, target_model):
        self.env = env
        self.model = model
        self.target_model = target_model
        self.target_model.set_weights(self.model.get_weights())
        self.gamma = 0.7
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.01
        self.batch_size = 64
        self.memory = deque(maxlen=10000)
        

    def add_to_memory(self, state, goal, action, reward, next_state, done):
        self.memory.append((state, goal, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(0, 4)
        else:
            # Pre-process the input
            inputt = np.concatenate((state, self.env.goal))
            inputt = tf.convert_to_tensor(inputt)
            inputt = tf.expand_dims(inputt, 0)

            return np.argmax(self.model.predict(inputt, verbose=0)[0]) # TODO: check the predict output

    def predict(self, inputt):

        return np.argmax(self.model.predict(inputt, verbose=0)[0])

    def replay(self):
        batch = random.sample(self.memory, self.batch_size)
        for state, goal, action, reward, next_state, done in batch:
            
            target = reward

            if not done:
                # Pre-process the next state input
                input_next = np.concatenate((next_state, goal))
                input_next = tf.convert_to_tensor(input_next)
                input_next = tf.expand_dims(input_next, 0)

                target += self.gamma * np.amax(self.target_model.predict(input_next, verbose=0)[0])

            # Pre-process the current state input
            inputt = np.concatenate((state, goal))
            inputt = tf.convert_to_tensor(inputt)
            inputt = tf.expand_dims(inputt, 0)

            cur_q_value = self.model.predict(inputt, verbose=0) # Q-value of current state
            cur_q_value[0][action] = target # TODO: check the predict output
            
            self.model.fit(inputt, cur_q_value, epochs=1, verbose=0)

# %%
# Initialize the agent

try:
    model = tf.keras.models.load_model('ashvin_train.h5')
    print("Loaded model from disk")
    agent = Agent(Env(), model=model, target_model=model)
except:
    print("Creating new model")
    agent = Agent(Env(), model=create_model(input_shape=(4,), num_actions=4), target_model=create_model(input_shape=(4,), num_actions=4))
# Out:
# Loaded model from disk
# Goal: [7 0]

# %%
# Train the agent

num_episodes = 300
reward_lst = []


for episode in range(num_episodes):
    state = agent.env.reset()   
    for step in range(agent.env.max_steps):
        action = agent.act(state)
        next_state, reward, done, terminate = agent.env.step(action)
        agent.add_to_memory(state, agent.env.goal, action, reward, next_state, done)
        state = next_state
        if done:
            if np.array_equal(agent.env.goal, agent.env.pos): # Reached the goal
                agent.env.reset_goal()
            if (agent.env.steps >= agent.env.max_steps) or terminate:
                print('Episode: {}/{}, steps: {}, e: {:.2}'.format(episode, num_episodes, step+1, agent.epsilon))
                break
    if len(agent.memory) > agent.batch_size:
        agent.replay()
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon = (1 - agent.epsilon_min) * np.exp(-agent.epsilon_decay*episode) + agent.epsilon_min
    if episode % 5 == 0:
        agent.model.save('ashvin_train.h5')    

    agent.target_model.set_weights(agent.model.get_weights())

    
print('Average reward:', np.mean(reward_lst))
# Out:
# Episode: 0/300, steps: 10, e: 1.0
# Episode: 1/300, steps: 58, e: 1.0
# Episode: 2/300, steps: 14, e: 0.99
# Episode: 3/300, steps: 123, e: 0.98
# Episode: 4/300, steps: 103, e: 0.97
# Episode: 5/300, steps: 9, e: 0.96
# Episode: 6/300, steps: 23, e: 0.95
# Episode: 7/300, steps: 7, e: 0.94
# Episode: 8/300, steps: 5, e: 0.93
# Goal: [4 5]
# Episode: 9/300, steps: 17, e: 0.92
# Goal: [8 6]
# Episode: 10/300, steps: 46, e: 0.91
# Goal: [3 5]
# Episode: 11/300, steps: 12, e: 0.91
# Episode: 12/300, steps: 12, e: 0.9
# Episode: 13/300, steps: 32, e: 0.89
# Goal: [1 6]
# Episode: 14/300, steps: 53, e: 0.88
# Episode: 15/300, steps: 15, e: 0.87
# Episode: 16/300, steps: 40, e: 0.86
# Episode: 17/300, steps: 12, e: 0.85
# Episode: 18/300, steps: 4, e: 0.85
# Goal: [0 3]
# Goal: [7 9]
# Episode: 19/300, steps: 8, e: 0.84
# Goal: [0 6]
# Episode: 20/300, steps: 32, e: 0.83
# Episode: 21/300, steps: 2, e: 0.82
# Episode: 22/300, steps: 1, e: 0.81
# Episode: 23/300, steps: 62, e: 0.8
# Goal: [7 1]
# Episode: 24/300, steps: 3, e: 0.8
# Episode: 25/300, steps: 61, e: 0.79
# Episode: 26/300, steps: 32, e: 0.78
# Episode: 27/300, steps: 6, e: 0.77
# Episode: 28/300, steps: 21, e: 0.77
# Episode: 29/300, steps: 41, e: 0.76
# Episode: 30/300, steps: 15, e: 0.75
# Episode: 31/300, steps: 14, e: 0.74
# Episode: 32/300, steps: 22, e: 0.74
# Episode: 33/300, steps: 1, e: 0.73
# Episode: 34/300, steps: 9, e: 0.72
# Episode: 35/300, steps: 24, e: 0.71
# Episode: 36/300, steps: 56, e: 0.71
# Episode: 37/300, steps: 136, e: 0.7
# Episode: 38/300, steps: 13, e: 0.69
# Episode: 39/300, steps: 45, e: 0.69
# Episode: 40/300, steps: 55, e: 0.68
# Episode: 41/300, steps: 2, e: 0.67
# Goal: [2 8]
# Episode: 42/300, steps: 53, e: 0.67
# Episode: 43/300, steps: 13, e: 0.66
# Goal: [4 8]
# Episode: 44/300, steps: 19, e: 0.65
# Episode: 45/300, steps: 1, e: 0.65
# Episode: 46/300, steps: 16, e: 0.64
# Episode: 47/300, steps: 34, e: 0.63
# Episode: 48/300, steps: 1, e: 0.63
# Episode: 49/300, steps: 42, e: 0.62
# Episode: 50/300, steps: 6, e: 0.62
# Goal: [7 1]
# Episode: 51/300, steps: 64, e: 0.61
# Episode: 52/300, steps: 60, e: 0.6
# Episode: 53/300, steps: 500, e: 0.6
# Goal: [8 9]
# Episode: 54/300, steps: 138, e: 0.59
# Episode: 55/300, steps: 1, e: 0.59
# Episode: 56/300, steps: 2, e: 0.58
# Episode: 57/300, steps: 14, e: 0.58
# Episode: 58/300, steps: 12, e: 0.57
# Episode: 59/300, steps: 51, e: 0.56
# Episode: 60/300, steps: 3, e: 0.56
# Episode: 61/300, steps: 26, e: 0.55
# Goal: [4 2]
# Episode: 62/300, steps: 51, e: 0.55
# Episode: 63/300, steps: 5, e: 0.54
# Episode: 64/300, steps: 14, e: 0.54
# Episode: 65/300, steps: 37, e: 0.53
# Episode: 66/300, steps: 4, e: 0.53
# Goal: [2 5]
# Goal: [7 6]
# Episode: 67/300, steps: 222, e: 0.52
# Episode: 68/300, steps: 54, e: 0.52
# Episode: 69/300, steps: 27, e: 0.51
# Episode: 70/300, steps: 69, e: 0.51
# Goal: [10  4]
# Episode: 71/300, steps: 84, e: 0.5
# Goal: [10  7]
# Episode: 72/300, steps: 33, e: 0.5
# Episode: 73/300, steps: 26, e: 0.49
# Episode: 74/300, steps: 18, e: 0.49
# Goal: [5 5]
# Goal: [7 1]
# Episode: 75/300, steps: 87, e: 0.48
# Episode: 76/300, steps: 19, e: 0.48
# Goal: [10  2]
# Goal: [3 4]
# Episode: 77/300, steps: 26, e: 0.47
# Goal: [9 8]
# Goal: [3 1]
# Goal: [2 3]
# Goal: [ 7 10]
# Episode: 78/300, steps: 100, e: 0.47
# Episode: 79/300, steps: 20, e: 0.46
# Episode: 80/300, steps: 7, e: 0.46
# Goal: [0 5]
# Episode: 81/300, steps: 4, e: 0.45
# Episode: 82/300, steps: 500, e: 0.45
# Goal: [10  7]
# Episode: 83/300, steps: 188, e: 0.45
# Episode: 84/300, steps: 24, e: 0.44
# Goal: [9 5]
# Goal: [10  6]
# Episode: 85/300, steps: 29, e: 0.44
# Goal: [7 4]
# Goal: [3 3]
# Goal: [4 9]
# Episode: 86/300, steps: 55, e: 0.43
# Goal: [1 7]
# Episode: 87/300, steps: 56, e: 0.43
# Episode: 88/300, steps: 5, e: 0.42
# Episode: 89/300, steps: 500, e: 0.42
# Episode: 90/300, steps: 500, e: 0.42
# Goal: [3 1]
# Episode: 91/300, steps: 95, e: 0.41
# Episode: 92/300, steps: 1, e: 0.41
# Goal: [4 4]
# Goal: [3 0]
# Episode: 93/300, steps: 45, e: 0.4
# Goal: [4 7]
# Goal: [4 0]
# Goal: [2 5]
# Goal: [6 6]
# Episode: 94/300, steps: 367, e: 0.4
# Episode: 95/300, steps: 500, e: 0.4
# Goal: [6 8]
# Goal: [1 7]
# Episode: 96/300, steps: 500, e: 0.39
# Goal: [0 3]
# Goal: [0 9]
# Episode: 97/300, steps: 121, e: 0.39
# Episode: 98/300, steps: 177, e: 0.39
# Episode: 99/300, steps: 13, e: 0.38
# Episode: 100/300, steps: 6, e: 0.38
# Episode: 101/300, steps: 11, e: 0.37
# Episode: 102/300, steps: 18, e: 0.37
# Episode: 103/300, steps: 4, e: 0.37
# Episode: 104/300, steps: 3, e: 0.36
# Episode: 105/300, steps: 1, e: 0.36
# Episode: 106/300, steps: 56, e: 0.36
# Episode: 107/300, steps: 34, e: 0.35
# Episode: 108/300, steps: 6, e: 0.35
# Goal: [7 8]
# Episode: 109/300, steps: 19, e: 0.35
# Episode: 110/300, steps: 77, e: 0.34
# Episode: 111/300, steps: 15, e: 0.34
# Goal: [7 1]
# Episode: 112/300, steps: 169, e: 0.34
# Goal: [7 5]
# Goal: [9 8]
# Episode: 113/300, steps: 317, e: 0.33
# Goal: [8 0]
# Episode: 114/300, steps: 81, e: 0.33
# Episode: 115/300, steps: 5, e: 0.33
# Episode: 116/300, steps: 24, e: 0.32
# Episode: 117/300, steps: 23, e: 0.32
# Episode: 118/300, steps: 17, e: 0.32
# Goal: [8 5]
# Episode: 119/300, steps: 14, e: 0.31
# Goal: [1 8]
# Goal: [5 4]
# Episode: 120/300, steps: 500, e: 0.31
# Episode: 121/300, steps: 252, e: 0.31
# Episode: 122/300, steps: 69, e: 0.31
# Episode: 123/300, steps: 334, e: 0.3
# Episode: 124/300, steps: 21, e: 0.3
# Episode: 125/300, steps: 112, e: 0.3
# Episode: 126/300, steps: 36, e: 0.29
# Goal: [5 6]
# Goal: [2 7]
# Goal: [7 9]
# Goal: [3 2]
# Goal: [ 4 10]
# Episode: 127/300, steps: 195, e: 0.29
# Goal: [6 9]
# Goal: [1 3]
# Goal: [10  4]
# Episode: 128/300, steps: 137, e: 0.29
# Episode: 129/300, steps: 2, e: 0.29
# Episode: 130/300, steps: 3, e: 0.28
# Goal: [10  3]
# Episode: 131/300, steps: 4, e: 0.28
# Episode: 132/300, steps: 10, e: 0.28
# Episode: 133/300, steps: 13, e: 0.27
# Episode: 134/300, steps: 26, e: 0.27
# Episode: 135/300, steps: 10, e: 0.27
# Episode: 136/300, steps: 10, e: 0.27
# Goal: [6 0]
# Goal: [6 0]
# Goal: [5 8]
# Goal: [7 7]
# Episode: 137/300, steps: 99, e: 0.26
# Goal: [6 0]
# Goal: [8 5]
# Goal: [10  9]
# Goal: [3 7]
# Episode: 138/300, steps: 53, e: 0.26
# Goal: [10  5]
# Episode: 139/300, steps: 137, e: 0.26
# Goal: [2 7]
# Goal: [10  2]
# Episode: 140/300, steps: 32, e: 0.26
# Goal: [ 1 10]
# Episode: 141/300, steps: 31, e: 0.25
# Episode: 142/300, steps: 17, e: 0.25
# Goal: [4 6]
# Episode: 143/300, steps: 8, e: 0.25
# Goal: [6 8]
# Goal: [10  8]
# Goal: [ 6 10]
# Goal: [2 0]
# Goal: [5 5]
# Goal: [5 4]
# Goal: [10  1]
# Episode: 144/300, steps: 80, e: 0.25
# Episode: 145/300, steps: 3, e: 0.24
# Episode: 146/300, steps: 15, e: 0.24
# Episode: 147/300, steps: 12, e: 0.24
# Episode: 148/300, steps: 29, e: 0.24
# Goal: [1 5]
# Goal: [9 5]
# Goal: [3 1]
# Goal: [4 6]
# Goal: [7 2]
# Goal: [0 1]
# Goal: [5 5]
# Goal: [4 5]
# Goal: [1 8]
# Goal: [6 5]
# Goal: [ 8 10]
# Goal: [ 5 10]
# Goal: [5 6]
# Episode: 149/300, steps: 243, e: 0.24
# Goal: [9 3]
# Episode: 150/300, steps: 52, e: 0.23
# Goal: [0 6]
# Episode: 151/300, steps: 31, e: 0.23
# Episode: 152/300, steps: 9, e: 0.23
# Episode: 153/300, steps: 5, e: 0.23
# Goal: [7 3]
# Goal: [4 0]
# Goal: [10  0]
# Goal: [2 1]
# Episode: 154/300, steps: 48, e: 0.22
# Goal: [7 9]
# Episode: 155/300, steps: 64, e: 0.22
# Goal: [4 4]
# Goal: [7 1]
# Goal: [8 8]
# Goal: [1 0]
# Goal: [5 9]
# Episode: 156/300, steps: 451, e: 0.22
# Goal: [10 10]
# Goal: [5 1]
# Goal: [10  8]
# Goal: [7 0]
# Episode: 157/300, steps: 263, e: 0.22
# Goal: [1 9]
# Goal: [5 2]
# Goal: [6 0]
# Goal: [6 5]
# Goal: [10  6]
# Goal: [3 1]
# Goal: [5 0]
# Goal: [0 4]
# Goal: [ 4 10]
# Episode: 158/300, steps: 108, e: 0.22
# Goal: [6 0]
# Goal: [7 9]
# Goal: [9 8]
# Goal: [3 7]
# Goal: [0 2]
# Goal: [7 3]
# Goal: [5 0]
# Goal: [5 4]
# Goal: [3 9]
# Goal: [6 6]
# Goal: [3 9]
# Goal: [10  5]
# Goal: [5 6]
# Goal: [1 1]
# Goal: [4 7]
# Goal: [4 6]
# Goal: [2 8]
# Goal: [7 4]
# Goal: [ 3 10]
# Goal: [9 5]
# Goal: [ 6 10]
# Goal: [5 2]
# Goal: [8 9]
# Goal: [8 7]
# Goal: [9 4]
# Goal: [5 0]
# Goal: [8 0]
# Goal: [2 7]
# Goal: [5 6]
# Goal: [0 2]
# Goal: [7 0]
# Episode: 159/300, steps: 406, e: 0.21
# Goal: [10  1]
# Episode: 160/300, steps: 16, e: 0.21
# Episode: 161/300, steps: 9, e: 0.21
# Goal: [7 4]
# Goal: [9 8]
# Goal: [3 3]
# Goal: [9 1]
# Goal: [9 3]
# Goal: [1 9]
# Goal: [9 5]
# Goal: [3 7]
# Goal: [10  3]
# Goal: [7 6]
# Goal: [6 5]
# Goal: [1 5]
# Goal: [9 9]
# Goal: [5 6]
# Goal: [3 4]
# Goal: [9 6]
# Goal: [8 6]
# Goal: [9 5]
# Goal: [10  1]
# Goal: [2 6]
# Goal: [3 1]
# Goal: [2 7]
# Goal: [8 6]
# Goal: [1 9]
# Goal: [9 9]
# Goal: [4 8]
# Goal: [9 8]
# Goal: [9 3]
# Goal: [ 4 10]
# Goal: [1 5]
# Goal: [5 4]
# Goal: [0 6]
# Goal: [8 6]
# Goal: [10  4]
# Goal: [0 6]
# Goal: [9 2]
# Goal: [6 2]
# Goal: [9 7]
# Goal: [6 2]
# Goal: [9 6]
# Goal: [4 7]
# Goal: [0 7]
# Episode: 162/300, steps: 500, e: 0.21
# Episode: 163/300, steps: 17, e: 0.21
# Goal: [ 7 10]
# Episode: 164/300, steps: 500, e: 0.2
# Episode: 165/300, steps: 2, e: 0.2
# Episode: 166/300, steps: 23, e: 0.2
# Episode: 167/300, steps: 5, e: 0.2
# Episode: 168/300, steps: 83, e: 0.2
# Episode: 169/300, steps: 8, e: 0.19
# Episode: 170/300, steps: 33, e: 0.19
# Episode: 171/300, steps: 82, e: 0.19
# Episode: 172/300, steps: 18, e: 0.19
# Episode: 173/300, steps: 117, e: 0.19
# Episode: 174/300, steps: 65, e: 0.19
# Episode: 175/300, steps: 76, e: 0.18
# Episode: 176/300, steps: 4, e: 0.18
# Episode: 177/300, steps: 13, e: 0.18
# Goal: [6 8]
# Goal: [9 8]
# Episode: 178/300, steps: 44, e: 0.18
# Episode: 179/300, steps: 1, e: 0.18
# Episode: 180/300, steps: 10, e: 0.18
# Episode: 181/300, steps: 2, e: 0.17
# Episode: 182/300, steps: 10, e: 0.17
# Episode: 183/300, steps: 7, e: 0.17
# Episode: 184/300, steps: 10, e: 0.17
# Episode: 185/300, steps: 6, e: 0.17
# Episode: 186/300, steps: 16, e: 0.17
# Goal: [ 5 10]
# Goal: [10  5]
# Goal: [2 6]
# Goal: [8 8]
# Goal: [7 5]
# Episode: 187/300, steps: 500, e: 0.16
# Goal: [3 1]
# Episode: 188/300, steps: 27, e: 0.16
# Goal: [6 9]
# Episode: 189/300, steps: 41, e: 0.16
# Goal: [3 7]
# Goal: [2 6]
# Episode: 190/300, steps: 500, e: 0.16
# Goal: [ 2 10]
# Goal: [8 8]
# Goal: [ 6 10]
# Goal: [2 6]
# Episode: 191/300, steps: 224, e: 0.16
# Episode: 192/300, steps: 45, e: 0.16
# Episode: 193/300, steps: 80, e: 0.16
# Episode: 194/300, steps: 33, e: 0.15
# Goal: [10  9]
# Episode: 195/300, steps: 500, e: 0.15
# Episode: 196/300, steps: 59, e: 0.15
# Episode: 197/300, steps: 11, e: 0.15
# Episode: 198/300, steps: 188, e: 0.15
# Episode: 199/300, steps: 105, e: 0.15
# Episode: 200/300, steps: 14, e: 0.15
# Episode: 201/300, steps: 7, e: 0.14
# Episode: 202/300, steps: 9, e: 0.14
# Episode: 203/300, steps: 43, e: 0.14
# Episode: 204/300, steps: 15, e: 0.14
# Episode: 205/300, steps: 3, e: 0.14
# Episode: 206/300, steps: 18, e: 0.14
# Episode: 207/300, steps: 5, e: 0.14
# Episode: 208/300, steps: 5, e: 0.13
# Episode: 209/300, steps: 4, e: 0.13
# Episode: 210/300, steps: 8, e: 0.13
# Episode: 211/300, steps: 15, e: 0.13
# Episode: 212/300, steps: 15, e: 0.13
# Goal: [4 0]
# Episode: 213/300, steps: 13, e: 0.13
# Episode: 214/300, steps: 14, e: 0.13
# Episode: 215/300, steps: 7, e: 0.13
# Episode: 216/300, steps: 14, e: 0.13
# Episode: 217/300, steps: 11, e: 0.12
# Episode: 218/300, steps: 14, e: 0.12
# Episode: 219/300, steps: 12, e: 0.12
# Episode: 220/300, steps: 13, e: 0.12
# Episode: 221/300, steps: 9, e: 0.12
# Episode: 222/300, steps: 4, e: 0.12
# Episode: 223/300, steps: 4, e: 0.12
# Episode: 224/300, steps: 4, e: 0.12
# Episode: 225/300, steps: 8, e: 0.12
# Goal: [4 0]
# Episode: 226/300, steps: 1, e: 0.11
# Episode: 227/300, steps: 11, e: 0.11
# Episode: 228/300, steps: 15, e: 0.11
# Episode: 229/300, steps: 10, e: 0.11
# Episode: 230/300, steps: 5, e: 0.11
# Episode: 231/300, steps: 14, e: 0.11
# Episode: 232/300, steps: 7, e: 0.11
# Episode: 233/300, steps: 3, e: 0.11
# Episode: 234/300, steps: 1, e: 0.11
# Episode: 235/300, steps: 6, e: 0.11
# Goal: [8 5]
# Episode: 236/300, steps: 500, e: 0.1
# Episode: 237/300, steps: 34, e: 0.1
# Episode: 238/300, steps: 500, e: 0.1
# Episode: 239/300, steps: 28, e: 0.1
# Episode: 240/300, steps: 372, e: 0.1
# Episode: 241/300, steps: 500, e: 0.1
# Episode: 242/300, steps: 500, e: 0.099
# Goal: [2 3]
# Episode: 243/300, steps: 500, e: 0.098
# Goal: [3 8]
# Episode: 244/300, steps: 27, e: 0.097
# Episode: 245/300, steps: 104, e: 0.096
# Goal: [1 9]
# Episode: 246/300, steps: 16, e: 0.095
# Episode: 247/300, steps: 9, e: 0.095
# Episode: 248/300, steps: 13, e: 0.094
# Episode: 249/300, steps: 12, e: 0.093
# Goal: [9 1]
# Episode: 250/300, steps: 14, e: 0.092
# Episode: 251/300, steps: 1, e: 0.091
# Episode: 252/300, steps: 4, e: 0.09
# Episode: 253/300, steps: 9, e: 0.09
# Episode: 254/300, steps: 5, e: 0.089
# Episode: 255/300, steps: 6, e: 0.088
# Episode: 256/300, steps: 14, e: 0.087
# Goal: [6 9]
# Goal: [10  7]
# Goal: [8 1]
# Episode: 257/300, steps: 197, e: 0.087
# Episode: 258/300, steps: 9, e: 0.086
# Episode: 259/300, steps: 9, e: 0.085
# Episode: 260/300, steps: 10, e: 0.084
# Episode: 261/300, steps: 7, e: 0.084
# Episode: 262/300, steps: 6, e: 0.083
# Episode: 263/300, steps: 6, e: 0.082
# Episode: 264/300, steps: 6, e: 0.081
# Episode: 265/300, steps: 3, e: 0.081
# Goal: [5 6]
# Goal: [0 5]
# Goal: [0 6]
# Goal: [7 8]
# Episode: 266/300, steps: 500, e: 0.08
# Goal: [5 7]
# Goal: [6 1]
# Episode: 267/300, steps: 54, e: 0.079
# Episode: 268/300, steps: 8, e: 0.079
# Goal: [10  8]
# Goal: [6 2]
# Goal: [6 9]
# Goal: [8 1]
# Episode: 269/300, steps: 161, e: 0.078
# Episode: 270/300, steps: 6, e: 0.077
# Goal: [5 3]
# Goal: [2 2]
# Goal: [0 1]
# Goal: [6 8]
# Goal: [ 9 10]
# Episode: 271/300, steps: 116, e: 0.077
# Episode: 272/300, steps: 500, e: 0.076
# Episode: 273/300, steps: 138, e: 0.075
# Episode: 274/300, steps: 198, e: 0.075
# Episode: 275/300, steps: 1, e: 0.074
# Goal: [6 1]
# Episode: 276/300, steps: 32, e: 0.073
# Episode: 277/300, steps: 13, e: 0.073
# Episode: 278/300, steps: 9, e: 0.072
# Episode: 279/300, steps: 10, e: 0.071
# Episode: 280/300, steps: 9, e: 0.071
# Episode: 281/300, steps: 7, e: 0.07
# Episode: 282/300, steps: 20, e: 0.07
# Goal: [8 9]
# Episode: 283/300, steps: 214, e: 0.069
# Episode: 284/300, steps: 373, e: 0.068
# Goal: [6 7]
# Goal: [9 2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       8 state = agent.env.reset()
#       9 for step in range(agent.env.max_steps):
# ---> 10     action = agent.act(state)
#      11     next_state, reward, done, terminate = agent.env.step(action)
#      12     agent.add_to_memory(state, agent.env.goal, action, reward, next_state, done)
#
# Cell In[4], line 28, in Agent.act(self, state)
#      25 inputt = tf.convert_to_tensor(inputt)
#      26 inputt = tf.expand_dims(inputt, 0)
# ---> 28 return np.argmax(self.model.predict(inputt, verbose=0)[0])
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/training.py:2349, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2340     except ValueError:
#    2341         warnings.warn(
#    2342             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2343             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2346             stacklevel=2,
#    2347         )
# -> 2349 data_handler = data_adapter.get_data_handler(
#    2350     x=x,
#    2351     batch_size=batch_size,
#    2352     steps_per_epoch=steps,
#    2353     initial_epoch=0,
#    2354     epochs=1,
#    2355     max_queue_size=max_queue_size,
#    2356     workers=workers,
#    2357     use_multiprocessing=use_multiprocessing,
#    2358     model=self,
#    2359     steps_per_execution=self._steps_per_execution,
#    2360 )
#    2362 # Container that configures and calls `tf.keras.Callback`s.
#    2363 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:1583, in get_data_handler(*args, **kwargs)
#    1581 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1582     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1583 return DataHandler(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:1260, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1257     self._steps_per_execution = steps_per_execution
#    1259 adapter_cls = select_data_adapter(x, y)
# -> 1260 self._adapter = adapter_cls(
#    1261     x,
#    1262     y,
#    1263     batch_size=batch_size,
#    1264     steps=steps_per_epoch,
#    1265     epochs=epochs - initial_epoch,
#    1266     sample_weights=sample_weight,
#    1267     shuffle=shuffle,
#    1268     max_queue_size=max_queue_size,
#    1269     workers=workers,
#    1270     use_multiprocessing=use_multiprocessing,
#    1271     distribution_strategy=tf.distribute.get_strategy(),
#    1272     model=model,
#    1273 )
#    1275 strategy = tf.distribute.get_strategy()
#    1277 self._current_step = 0
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:346, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     343         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     344     return flat_dataset
# --> 346 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     348 dataset = self.slice_inputs(indices_dataset, inputs)
#     350 if shuffle == "batch":
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:2285, in DatasetV2.flat_map(self, map_func, name)
#    2281 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2282 # dataset_ops).
#    2283 # pylint: disable=g-import-not-at-top,protected-access
#    2284 from tensorflow.python.data.ops import flat_map_op
# -> 2285 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/structured_function.py:261, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     254       warnings.warn(
#     255           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     256           "option is set, this option does not apply to tf.data functions. "
#     257           "To force eager execution of tf.data functions, please use "
#     258           "`tf.data.experimental.enable_debug_mode()`.")
#     259     fn_factory = trace_tf_function(defun_kwargs)
# --> 261 self._function = fn_factory()
#     262 # There is no graph to add in eager mode.
#     263 add_to_graph &= not context.executing_eagerly()
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:232, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     223 def get_concrete_function(self, *args, **kwargs):
#     224   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     225
#     226   Args:
#    (...)
#     230       `tf.Tensor` or `tf.TensorSpec`.
#     231   """
# --> 232   concrete_function = self._get_concrete_function_garbage_collected(
#     233       *args, **kwargs)
#     234   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     235   return concrete_function
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:202, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     199   self._function_spec.make_canonicalized_monomorphic_type(args, kwargs)
#     201 with self._lock:
# --> 202   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     203   seen_names = set()
#     204   concrete_function._arg_keywords = []  # pylint: disable=protected-access
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:166, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     163   args = self.input_signature
#     164   kwargs = {}
# --> 166 return self._maybe_define_function(args, kwargs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:396, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     393   args = placeholder_bound_args.args
#     394 kwargs = placeholder_bound_args.kwargs
# --> 396 concrete_function = self._create_concrete_function(
#     397     args, kwargs, func_graph)
#     399 # TODO(b/263520817): Remove access to private attribute.
#     400 graph_capture_container = concrete_function.graph._function_captures  # pylint: disable=protected-access
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:300, in TracingCompiler._create_concrete_function(self, args, kwargs, func_graph)
#     296 else:
#     297   arg_names = base_arg_names
#     299 concrete_function = monomorphic_function.ConcreteFunction(
# --> 300     func_graph_module.func_graph_from_py_func(
#     301         self._name,
#     302         self._python_function,
#     303         args,
#     304         kwargs,
#     305         None,
#     306         func_graph=func_graph,
#     307         autograph=self._autograph,
#     308         autograph_options=self._autograph_options,
#     309         arg_names=arg_names,
#     310         capture_by_value=self._capture_by_value,
#     311         create_placeholders=False),
#     312     self._function_attributes,
#     313     spec=self.function_spec,
#     314     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     315     # scope. This is not the default behavior since it gets used in some
#     316     # places (like Keras) where the FuncGraph lives longer than the
#     317     # ConcreteFunction.
#     318     shared_func_graph=False)
#     319 return concrete_function
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1214, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders, acd_record_initial_resource_uses)
#    1211 else:
#    1212   _, original_func = tf_decorator.unwrap(python_func)
# -> 1214 func_outputs = python_func(*func_args, **func_kwargs)
#    1216 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1217 # TensorArrays and `None`s.
#    1218 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/structured_function.py:238, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     232 @eager_function.defun_with_attributes(
#     233     input_signature=structure.get_flat_tensor_specs(
#     234         self._input_structure),
#     235     autograph=False,
#     236     attributes=defun_kwargs)
#     237 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 238   ret = wrapper_helper(*args)
#     239   ret = structure.to_tensor_list(self._output_structure, ret)
#     240   return [ops.convert_to_tensor(t) for t in ret]
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/structured_function.py:169, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     167 if not _should_unpack(nested_args):
#     168   nested_args = (nested_args,)
# --> 169 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     170 ret = variable_utils.convert_variables_to_tensors(ret)
#     171 if _should_pack(ret):
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:334, in TensorLikeDataAdapter.__init__.<locals>.slice_batch_indices(indices)
#     332 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     333 if self._partial_batch_size:
# --> 334     index_remainder = tf.data.Dataset.from_tensors(
#     335         tf.slice(
#     336             indices, [num_in_full_batch], [self._partial_batch_size]
#     337         )
#     338     )
#     339     flat_dataset = flat_dataset.concatenate(index_remainder)
#     341 if shuffle == "batch":
#     342     # 1024 is a magic constant that has not been properly evaluated
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:745, in DatasetV2.from_tensors(tensors, name)
#     741 # Loaded lazily due to a circular dependency (dataset_ops ->
#     742 # from_tensors_op -> dataset_ops).
#     743 # pylint: disable=g-import-not-at-top,protected-access
#     744 from tensorflow.python.data.ops import from_tensors_op
# --> 745 return from_tensors_op._from_tensors(tensors, name)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/from_tensors_op.py:23, in _from_tensors(tensors, name)
#      22 def _from_tensors(tensors, name):  # pylint: disable=unused-private-name
# ---> 23   return _TensorDataset(tensors, name)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/data/ops/from_tensors_op.py:35, in _TensorDataset.__init__(self, element, name)
#      33 self._tensors = structure.to_tensor_list(self._structure, element)
#      34 self._name = name
# ---> 35 variant_tensor = gen_dataset_ops.tensor_dataset(
#      36     self._tensors,
#      37     output_shapes=structure.get_flat_tensor_shapes(self._structure),
#      38     metadata=self._metadata.SerializeToString())
#      39 super().__init__(variant_tensor)
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:7556, in tensor_dataset(components, output_shapes, metadata, name)
#    7554   metadata = ""
#    7555 metadata = _execute.make_str(metadata, "metadata")
# -> 7556 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    7557       "TensorDataset", components=components, output_shapes=output_shapes,
#    7558                        metadata=metadata, name=name)
#    7559 _result = _outputs[:]
#    7560 if _execute.must_record_gradient():
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py:770, in _apply_op_helper(op_type_name, name, **keywords)
#     768 if fallback:
#     769   _CheckOpDeprecation(op_type_name, op_def, producer)
# --> 770   _ExtractDefaultTypesAndAllowedTypes(op_def, default_type_attr_map,
#     771                                       allowed_list_attr_map)
#     773 # Requires that op_def has passed validation (using the C++
#     774 # ValidateOpDef() from ../framework/op_def_util.h).
#     775 with g.as_default(), ops.name_scope(name) as scope:
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/framework/op_def_library.py:399, in _ExtractDefaultTypesAndAllowedTypes(op_def, default_type_attr_map, allowed_list_attr_map)
#     394 """Extracts the `default_type_attr_map` and `allowed_list_attr_map`."""
#     395 # TODO(b/31302892): Currently the defaults don't work in the right
#     396 # way if you have two inputs, one of whose type resolution depends
#     397 # on the other.  Handling this will require restructuring this code
#     398 # significantly.
# --> 399 for attr_def in op_def.attr:
#     400   if attr_def.type != "type":
#     401     continue
#
# KeyboardInterrupt:

# %%
# Test the agent
success = 0
crash = 0
for i in range(100):
    state = agent.env.reset()
    goal = agent.env.reset_goal()
    print('Goal:', goal)
    for step in range(30):
        print('State:', state)
        inputt = np.concatenate((state, goal))
        inputt = tf.convert_to_tensor(inputt)
        inputt = tf.expand_dims(inputt, 0)
        action = agent.predict(inputt)
        next_state, reward, done, terminate = agent.env.step(action)
        state = next_state
        if done:
            print('State:', state)
            print('Steps: ', step+1)
            if np.array_equal(agent.env.goal, agent.env.pos):
                print('Reached the goal!')
                success += 1
            break
        if terminate:
            print('Steps: ', step+1)
            print("Crashed into a wall")
            crash += 1
            break

print('Success rate:', success/100)
print('Crash rate:', crash/100)
print('Oscillate rate:', (100 - success - crash)/100)
# Out:
# Goal: [7 4]
# Goal: [7 4]
# State: [6 8]
# State: [6 7]
# State: [6 6]
# State: [6 5]
# State: [6 4]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# Goal: [1 0]
# Goal: [1 0]
# State: [7 5]
# State: [6 5]
# State: [6 4]
# State: [6 3]
# State: [5 3]
# State: [5 2]
# State: [4 2]
# State: [4 1]
# State: [3 1]
# State: [3 0]
# State: [2 0]
# State: [2 0]
# Steps:  11
# Goal: [ 7 10]
# Goal: [ 7 10]
# State: [1 1]
# State: [2 1]
# State: [2 2]
# State: [2 3]
# State: [2 4]
# State: [3 4]
# State: [3 5]
# State: [4 5]
# State: [4 6]
# State: [4 7]
# State: [5 7]
# State: [5 8]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# State: [5 9]
# State: [6 9]
# Goal: [9 3]
# Goal: [9 3]
# State: [10  5]
# State: [10  4]
# State: [9 4]
# State: [9 3]
# Steps:  3
# Reached the goal!
# Goal: [ 4 10]
# Goal: [ 4 10]
# State: [3 4]
# State: [3 5]
# State: [3 6]
# State: [3 7]
# State: [3 8]
# State: [3 9]
# State: [ 3 10]
# State: [ 3 10]
# Steps:  7
# Goal: [1 7]
# Goal: [1 7]
# State: [10  7]
# State: [9 7]
# State: [8 7]
# State: [7 7]
# State: [6 7]
# State: [5 7]
# State: [4 7]
# State: [3 7]
# State: [2 7]
# State: [1 7]
# Steps:  9
# Reached the goal!
# Goal: [1 0]
# Goal: [1 0]
# State: [6 5]
# State: [6 4]
# State: [6 3]
# State: [5 3]
# State: [5 2]
# State: [4 2]
# State: [4 1]
# State: [3 1]
# State: [3 0]
# State: [2 0]
# State: [2 0]
# Steps:  10
# Goal: [10  5]
# Goal: [10  5]
# State: [9 1]
# State: [8 1]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# State: [8 2]
# State: [9 2]
# Goal: [9 7]
# Goal: [9 7]
# State: [9 3]
# State: [8 3]
# State: [8 4]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# State: [7 5]
# State: [8 5]
# Goal: [4 7]
# Goal: [4 7]
# State: [7 9]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [3 9]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# Goal: [3 0]
# Goal: [3 0]
# State: [9 9]
# State: [9 8]
# State: [9 7]
# State: [9 6]
# State: [9 5]
# State: [9 4]
# State: [8 4]
# State: [8 3]
# State: [7 3]
# State: [7 2]
# State: [6 2]
# State: [6 1]
# State: [5 1]
# State: [5 0]
# State: [4 0]
# State: [3 0]
# Steps:  15
# Reached the goal!
# Goal: [6 7]
# Goal: [6 7]
# State: [1 0]
# State: [2 0]
# State: [2 1]
# State: [3 1]
# State: [3 2]
# State: [3 3]
# State: [4 3]
# State: [4 4]
# State: [4 5]
# State: [5 5]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# State: [5 6]
# State: [4 6]
# Goal: [2 6]
# Goal: [2 6]
# State: [10  9]
# State: [9 9]
# State: [8 9]
# State: [7 9]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [3 9]
# State: [2 9]
# State: [2 8]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# State: [2 7]
# State: [1 7]
# Goal: [6 5]
# Goal: [6 5]
# State: [4 9]
# State: [4 8]
# State: [4 7]
# State: [4 6]
# State: [4 5]
# State: [5 5]
# State: [6 5]
# Steps:  6
# Reached the goal!
# Goal: [ 8 10]
# Goal: [ 8 10]
# State: [10  2]
# State: [9 2]
# State: [9 3]
# State: [8 3]
# State: [8 4]
# State: [8 5]
# State: [8 6]
# State: [7 6]
# State: [7 7]
# State: [7 8]
# State: [6 8]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# State: [7 9]
# State: [6 9]
# Goal: [4 8]
# Goal: [4 8]
# State: [0 6]
# State: [1 6]
# State: [2 6]
# State: [3 6]
# State: [3 7]
# State: [3 8]
# State: [4 8]
# Steps:  6
# Reached the goal!
# Goal: [8 0]
# Goal: [8 0]
# State: [1 0]
# State: [2 0]
# State: [3 0]
# State: [3 0]
# Steps:  3
# Goal: [4 5]
# Goal: [4 5]
# State: [6 0]
# State: [5 0]
# State: [5 1]
# State: [4 1]
# State: [4 2]
# State: [4 3]
# State: [3 3]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# State: [4 4]
# State: [3 4]
# Goal: [ 1 10]
# Goal: [ 1 10]
# State: [4 7]
# State: [3 7]
# State: [2 7]
# State: [2 8]
# State: [2 9]
# State: [1 9]
# State: [ 1 10]
# Steps:  6
# Reached the goal!
# Goal: [7 5]
# Goal: [7 5]
# State: [7 1]
# State: [6 1]
# State: [6 2]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# Goal: [3 4]
# Goal: [3 4]
# State: [2 2]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# State: [3 3]
# State: [2 3]
# Goal: [6 4]
# Goal: [6 4]
# State: [3 3]
# State: [4 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# State: [5 3]
# State: [6 3]
# Goal: [4 1]
# Goal: [4 1]
# State: [2 9]
# State: [2 8]
# State: [2 7]
# State: [2 6]
# State: [2 5]
# State: [2 4]
# State: [2 3]
# State: [2 2]
# State: [2 1]
# State: [2 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# Goal: [0 6]
# Goal: [0 6]
# State: [7 4]
# State: [6 4]
# State: [5 4]
# State: [4 4]
# State: [3 4]
# State: [2 4]
# State: [1 4]
# State: [1 5]
# State: [0 5]
# State: [0 6]
# Steps:  9
# Reached the goal!
# Goal: [0 2]
# Goal: [0 2]
# State: [7 6]
# State: [6 6]
# State: [5 6]
# State: [4 6]
# State: [3 6]
# State: [3 5]
# State: [2 5]
# State: [2 4]
# State: [2 3]
# State: [1 3]
# State: [1 2]
# State: [0 2]
# Steps:  11
# Reached the goal!
# Goal: [0 4]
# Goal: [0 4]
# State: [10  4]
# State: [9 4]
# State: [8 4]
# State: [7 4]
# State: [6 4]
# State: [5 4]
# State: [4 4]
# State: [3 4]
# State: [2 4]
# State: [1 4]
# State: [0 4]
# Steps:  10
# Reached the goal!
# Goal: [3 0]
# Goal: [3 0]
# State: [3 9]
# State: [3 8]
# State: [3 7]
# State: [3 6]
# State: [3 5]
# State: [3 4]
# State: [3 3]
# State: [3 2]
# State: [3 1]
# State: [3 0]
# Steps:  9
# Reached the goal!
# Goal: [6 5]
# Goal: [6 5]
# State: [5 7]
# State: [5 6]
# State: [5 5]
# State: [6 5]
# Steps:  3
# Reached the goal!
# Goal: [8 8]
# Goal: [8 8]
# State: [7 3]
# State: [7 4]
# State: [7 5]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# State: [6 6]
# State: [7 6]
# Goal: [10  2]
# Goal: [10  2]
# State: [4 0]
# State: [5 0]
# State: [6 0]
# State: [7 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# State: [8 0]
# State: [9 0]
# Goal: [4 6]
# Goal: [4 6]
# State: [5 3]
# State: [4 3]
# State: [4 4]
# State: [3 4]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# State: [3 5]
# State: [4 5]
# Goal: [8 0]
# Goal: [8 0]
# State: [5 5]
# State: [5 4]
# State: [5 3]
# State: [5 2]
# State: [5 1]
# State: [5 0]
# State: [5 0]
# Steps:  6
# Goal: [9 8]
# Goal: [9 8]
# State: [ 9 10]
# State: [ 8 10]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# Goal: [ 9 10]
# Goal: [ 9 10]
# State: [2 9]
# State: [3 9]
# State: [4 9]
# State: [5 9]
# State: [6 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# Goal: [1 3]
# Goal: [1 3]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [5 8]
# State: [5 7]
# State: [4 7]
# State: [4 6]
# State: [3 6]
# State: [3 5]
# State: [2 5]
# State: [2 4]
# State: [1 4]
# State: [1 3]
# Steps:  13
# Reached the goal!
# Goal: [7 1]
# Goal: [7 1]
# State: [ 3 10]
# State: [3 9]
# State: [3 8]
# State: [3 7]
# State: [3 6]
# State: [3 5]
# State: [3 4]
# State: [3 3]
# State: [3 2]
# State: [3 1]
# State: [3 0]
# State: [4 0]
# State: [5 0]
# State: [5 0]
# Steps:  13
# Goal: [7 7]
# Goal: [7 7]
# State: [10  1]
# State: [9 1]
# State: [8 1]
# State: [7 1]
# State: [7 2]
# State: [7 3]
# State: [6 3]
# State: [6 4]
# State: [6 5]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# State: [5 6]
# State: [6 6]
# Goal: [3 2]
# Goal: [3 2]
# State: [8 4]
# State: [7 4]
# State: [6 4]
# State: [5 4]
# State: [5 3]
# State: [4 3]
# State: [4 2]
# State: [3 2]
# Steps:  7
# Reached the goal!
# Goal: [5 0]
# Goal: [5 0]
# State: [2 5]
# State: [2 4]
# State: [2 3]
# State: [2 2]
# State: [2 1]
# State: [2 0]
# State: [2 0]
# Steps:  6
# Goal: [1 7]
# Goal: [1 7]
# State: [10  3]
# State: [9 3]
# State: [8 3]
# State: [7 3]
# State: [6 3]
# State: [5 3]
# State: [4 3]
# State: [3 3]
# State: [3 4]
# State: [2 4]
# State: [2 5]
# State: [2 6]
# State: [1 6]
# State: [1 7]
# Steps:  13
# Reached the goal!
# Goal: [0 2]
# Goal: [0 2]
# State: [6 6]
# State: [5 6]
# State: [4 6]
# State: [3 6]
# State: [3 5]
# State: [2 5]
# State: [2 4]
# State: [2 3]
# State: [1 3]
# State: [1 2]
# State: [0 2]
# Steps:  10
# Reached the goal!
# Goal: [7 5]
# Goal: [7 5]
# State: [ 1 10]
# State: [1 9]
# State: [1 8]
# State: [1 7]
# State: [2 7]
# State: [3 7]
# State: [3 6]
# State: [4 6]
# State: [5 6]
# State: [5 5]
# State: [6 5]
# State: [7 5]
# Steps:  11
# Reached the goal!
# Goal: [0 3]
# Goal: [0 3]
# State: [9 2]
# State: [8 2]
# State: [7 2]
# State: [6 2]
# State: [5 2]
# State: [4 2]
# State: [3 2]
# State: [2 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# State: [1 2]
# State: [0 2]
# Goal: [8 4]
# Goal: [8 4]
# State: [7 6]
# State: [7 5]
# State: [7 4]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# Goal: [8 9]
# Goal: [8 9]
# State: [10 10]
# State: [ 9 10]
# State: [ 8 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# State: [ 6 10]
# State: [ 7 10]
# Goal: [7 5]
# Goal: [7 5]
# State: [5 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# State: [7 3]
# State: [6 3]
# Goal: [2 7]
# Goal: [2 7]
# State: [7 4]
# State: [6 4]
# State: [5 4]
# State: [4 4]
# State: [3 4]
# State: [3 5]
# State: [2 5]
# State: [2 6]
# State: [2 7]
# Steps:  8
# Reached the goal!
# Goal: [9 4]
# Goal: [9 4]
# State: [10  4]
# State: [9 4]
# Steps:  1
# Reached the goal!
# Goal: [2 9]
# Goal: [2 9]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# State: [ 1 10]
# State: [ 2 10]
# Goal: [7 9]
# Goal: [7 9]
# State: [10  0]
# State: [9 0]
# State: [9 1]
# State: [8 1]
# State: [8 2]
# State: [8 3]
# State: [7 3]
# State: [7 4]
# State: [7 5]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# State: [6 8]
# State: [5 8]
# Goal: [ 3 10]
# Goal: [ 3 10]
# State: [0 1]
# State: [0 2]
# State: [0 3]
# State: [0 4]
# State: [0 5]
# State: [0 6]
# State: [1 6]
# State: [1 7]
# State: [1 8]
# State: [1 9]
# State: [2 9]
# State: [ 2 10]
# State: [ 2 10]
# Steps:  12
# Goal: [1 3]
# Goal: [1 3]
# State: [7 2]
# State: [6 2]
# State: [5 2]
# State: [4 2]
# State: [3 2]
# State: [2 2]
# State: [1 2]
# State: [1 3]
# Steps:  7
# Reached the goal!
# Goal: [5 3]
# Goal: [5 3]
# State: [1 6]
# State: [1 5]
# State: [1 4]
# State: [2 4]
# State: [2 3]
# State: [3 3]
# State: [4 3]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# State: [5 2]
# State: [4 2]
# Goal: [5 8]
# Goal: [5 8]
# State: [7 4]
# State: [6 4]
# State: [5 4]
# State: [5 5]
# State: [5 6]
# State: [4 6]
# State: [4 7]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# State: [3 8]
# State: [4 8]
# Goal: [10  9]
# Goal: [10  9]
# State: [8 0]
# State: [8 1]
# State: [8 2]
# State: [8 3]
# State: [8 4]
# State: [8 5]
# State: [8 6]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# State: [9 7]
# State: [8 7]
# Goal: [5 7]
# Goal: [5 7]
# State: [4 1]
# State: [4 2]
# State: [4 3]
# State: [4 4]
# State: [4 5]
# State: [4 6]
# State: [4 7]
# State: [5 7]
# Steps:  7
# Reached the goal!
# Goal: [1 2]
# Goal: [1 2]
# State: [2 3]
# State: [1 3]
# State: [1 2]
# Steps:  2
# Reached the goal!
# Goal: [9 1]
# Goal: [9 1]
# State: [ 7 10]
# State: [7 9]
# State: [7 8]
# State: [7 7]
# State: [7 6]
# State: [7 5]
# State: [7 4]
# State: [7 3]
# State: [7 2]
# State: [7 1]
# State: [7 0]
# State: [7 0]
# Steps:  11
# Goal: [3 1]
# Goal: [3 1]
# State: [8 3]
# State: [7 3]
# State: [6 3]
# State: [5 3]
# State: [5 2]
# State: [4 2]
# State: [4 1]
# State: [3 1]
# Steps:  7
# Reached the goal!
# Goal: [ 3 10]
# Goal: [ 3 10]
# State: [5 0]
# State: [5 1]
# State: [5 2]
# State: [5 3]
# State: [5 4]
# State: [5 5]
# State: [4 5]
# State: [4 6]
# State: [4 7]
# State: [3 7]
# State: [3 8]
# State: [3 9]
# State: [ 3 10]
# Steps:  12
# Reached the goal!
# Goal: [5 4]
# Goal: [5 4]
# State: [1 9]
# State: [1 8]
# State: [1 7]
# State: [1 6]
# State: [1 5]
# State: [2 5]
# State: [3 5]
# State: [3 4]
# State: [4 4]
# State: [5 4]
# Steps:  9
# Reached the goal!
# Goal: [6 5]
# Goal: [6 5]
# State: [2 6]
# State: [3 6]
# State: [4 6]
# State: [4 5]
# State: [5 5]
# State: [6 5]
# Steps:  5
# Reached the goal!
# Goal: [10  0]
# Goal: [10  0]
# State: [1 4]
# State: [1 3]
# State: [1 2]
# State: [1 1]
# State: [1 0]
# State: [2 0]
# State: [3 0]
# State: [4 0]
# State: [4 0]
# Steps:  8
# Goal: [0 5]
# Goal: [0 5]
# State: [7 1]
# State: [6 1]
# State: [5 1]
# State: [4 1]
# State: [3 1]
# State: [2 1]
# State: [1 1]
# State: [1 2]
# State: [1 3]
# State: [1 4]
# State: [0 4]
# State: [0 5]
# Steps:  11
# Reached the goal!
# Goal: [3 4]
# Goal: [3 4]
# State: [0 8]
# State: [0 7]
# State: [0 6]
# State: [0 5]
# State: [1 5]
# State: [2 5]
# State: [2 4]
# State: [3 4]
# Steps:  7
# Reached the goal!
# Goal: [7 3]
# Goal: [7 3]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# State: [6 1]
# State: [7 1]
# Goal: [2 3]
# Goal: [2 3]
# State: [6 8]
# State: [6 7]
# State: [5 7]
# State: [5 6]
# State: [4 6]
# State: [4 5]
# State: [3 5]
# State: [3 4]
# State: [2 4]
# State: [2 3]
# Steps:  9
# Reached the goal!
# Goal: [9 4]
# Goal: [9 4]
# State: [10  3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# Goal: [1 1]
# Goal: [1 1]
# State: [6 9]
# State: [6 8]
# State: [6 7]
# State: [6 6]
# State: [6 5]
# State: [5 5]
# State: [5 4]
# State: [4 4]
# State: [4 3]
# State: [3 3]
# State: [3 2]
# State: [2 2]
# State: [2 1]
# State: [1 1]
# Steps:  13
# Reached the goal!
# Goal: [5 9]
# Goal: [5 9]
# State: [10  3]
# State: [9 3]
# State: [8 3]
# State: [7 3]
# State: [6 3]
# State: [6 4]
# State: [6 5]
# State: [5 5]
# State: [5 6]
# State: [5 7]
# State: [4 7]
# State: [4 8]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# State: [4 9]
# State: [3 9]
# Goal: [1 7]
# Goal: [1 7]
# State: [8 1]
# State: [7 1]
# State: [6 1]
# State: [5 1]
# State: [4 1]
# State: [3 1]
# State: [3 2]
# State: [3 3]
# State: [3 4]
# State: [2 4]
# State: [2 5]
# State: [2 6]
# State: [1 6]
# State: [1 7]
# Steps:  13
# Reached the goal!
# Goal: [8 9]
# Goal: [8 9]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# State: [6 8]
# State: [7 8]
# Goal: [5 3]
# Goal: [5 3]
# State: [9 8]
# State: [9 7]
# State: [8 7]
# State: [8 6]
# State: [7 6]
# State: [7 5]
# State: [6 5]
# State: [6 4]
# State: [5 4]
# State: [5 3]
# Steps:  9
# Reached the goal!
# Goal: [7 6]
# Goal: [7 6]
# State: [4 3]
# State: [5 3]
# State: [6 3]
# State: [6 4]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# State: [6 5]
# State: [7 5]
# Goal: [8 3]
# Goal: [8 3]
# State: [2 5]
# State: [2 4]
# State: [3 4]
# State: [4 4]
# State: [4 3]
# State: [5 3]
# State: [6 3]
# State: [6 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# State: [7 2]
# State: [8 2]
# Goal: [8 5]
# Goal: [8 5]
# State: [3 2]
# State: [4 2]
# State: [5 2]
# State: [6 2]
# State: [7 2]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# State: [8 3]
# State: [7 3]
# Goal: [2 8]
# Goal: [2 8]
# State: [1 6]
# State: [1 7]
# State: [1 8]
# State: [2 8]
# Steps:  3
# Reached the goal!
# Goal: [6 3]
# Goal: [6 3]
# State: [ 7 10]
# State: [7 9]
# State: [7 8]
# State: [7 7]
# State: [7 6]
# State: [7 5]
# State: [7 4]
# State: [6 4]
# State: [6 3]
# Steps:  8
# Reached the goal!
# Goal: [10  6]
# Goal: [10  6]
# State: [9 6]
# State: [10  6]
# Steps:  1
# Reached the goal!
# Goal: [2 8]
# Goal: [2 8]
# State: [5 4]
# State: [4 4]
# State: [3 4]
# State: [3 5]
# State: [3 6]
# State: [2 6]
# State: [2 7]
# State: [2 8]
# Steps:  7
# Reached the goal!
# Goal: [4 2]
# Goal: [4 2]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# State: [4 0]
# State: [3 0]
# Goal: [1 0]
# Goal: [1 0]
# State: [2 8]
# State: [2 7]
# State: [2 6]
# State: [2 5]
# State: [2 4]
# State: [2 3]
# State: [2 2]
# State: [2 1]
# State: [2 0]
# State: [2 0]
# Steps:  9
# Goal: [5 6]
# Goal: [5 6]
# State: [9 3]
# State: [8 3]
# State: [7 3]
# State: [6 3]
# State: [5 3]
# State: [4 3]
# State: [4 4]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# State: [5 5]
# State: [4 5]
# Goal: [3 7]
# Goal: [3 7]
# State: [6 9]
# State: [5 9]
# State: [4 9]
# State: [3 9]
# State: [2 9]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# State: [3 8]
# State: [2 8]
# Goal: [ 3 10]
# Goal: [ 3 10]
# State: [0 8]
# State: [1 8]
# State: [1 9]
# State: [2 9]
# State: [ 2 10]
# State: [ 2 10]
# Steps:  5
# Goal: [6 2]
# Goal: [6 2]
# State: [1 4]
# State: [1 3]
# State: [2 3]
# State: [2 2]
# State: [3 2]
# State: [4 2]
# State: [4 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# State: [6 1]
# State: [5 1]
# Goal: [6 2]
# Goal: [6 2]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# State: [6 0]
# State: [5 0]
# Goal: [9 4]
# Goal: [9 4]
# State: [2 4]
# State: [3 4]
# State: [4 4]
# State: [5 4]
# State: [6 4]
# State: [7 4]
# State: [7 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# Goal: [ 9 10]
# Goal: [ 9 10]
# State: [1 2]
# State: [2 2]
# State: [3 2]
# State: [4 2]
# State: [4 3]
# State: [4 4]
# State: [5 4]
# State: [5 5]
# State: [6 5]
# State: [6 6]
# State: [6 7]
# State: [7 7]
# State: [7 8]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# State: [8 9]
# State: [7 9]
# Goal: [4 6]
# Goal: [4 6]
# State: [6 8]
# State: [5 8]
# State: [4 8]
# State: [3 8]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# State: [3 7]
# State: [4 7]
# Goal: [9 1]
# Goal: [9 1]
# State: [2 1]
# State: [3 1]
# State: [4 1]
# State: [4 0]
# State: [5 0]
# State: [6 0]
# State: [6 0]
# Steps:  6
# Goal: [8 2]
# Goal: [8 2]
# State: [0 3]
# State: [1 3]
# State: [2 3]
# State: [3 3]
# State: [3 2]
# State: [4 2]
# State: [5 2]
# State: [5 1]
# State: [6 1]
# State: [7 1]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# Goal: [2 4]
# Goal: [2 4]
# State: [10  3]
# State: [9 3]
# State: [8 3]
# State: [7 3]
# State: [6 3]
# State: [5 3]
# State: [4 3]
# State: [3 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# State: [2 3]
# State: [1 3]
# Goal: [2 9]
# Goal: [2 9]
# State: [4 6]
# State: [3 6]
# State: [3 7]
# State: [2 7]
# State: [2 8]
# State: [2 9]
# Steps:  5
# Reached the goal!
# Goal: [3 9]
# Goal: [3 9]
# State: [9 8]
# State: [8 8]
# State: [7 8]
# State: [6 8]
# State: [5 8]
# State: [4 8]
# State: [3 8]
# State: [2 8]
# State: [2 9]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# State: [ 3 10]
# State: [ 2 10]
# Goal: [7 2]
# Goal: [7 2]
# State: [6 1]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# State: [7 0]
# State: [6 0]
# Goal: [ 5 10]
# Goal: [ 5 10]
# State: [8 4]
# State: [7 4]
# State: [6 4]
# State: [6 5]
# State: [6 6]
# State: [5 6]
# State: [5 7]
# State: [5 8]
# State: [4 8]
# State: [4 9]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# State: [ 4 10]
# State: [ 3 10]
# Goal: [9 5]
# Goal: [9 5]
# State: [10  8]
# State: [10  7]
# State: [9 7]
# State: [9 6]
# State: [9 5]
# Steps:  4
# Reached the goal!
# Goal: [10  4]
# Goal: [10  4]
# State: [ 8 10]
# State: [8 9]
# State: [8 8]
# State: [8 7]
# State: [8 6]
# State: [8 5]
# State: [8 4]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# State: [9 3]
# State: [8 3]
# Goal: [1 3]
# Goal: [1 3]
# State: [8 4]
# State: [7 4]
# State: [6 4]
# State: [5 4]
# State: [4 4]
# State: [3 4]
# State: [2 4]
# State: [1 4]
# State: [1 3]
# Steps:  8
# Reached the goal!
# Success rate: 0.38
# Crash rate: 0.0
# Oscillate rate: 0.62

# %%
# testing for custom goal and random start point:
state = agent.env.reset()
goal = agent.env.reset_goal()
# print('Goal:', goal)

for step in range(30):
    print('State:', state)
    inputt = np.concatenate((state, goal))
    inputt = tf.convert_to_tensor(inputt)
    inputt = tf.expand_dims(inputt, 0)
    action = agent.predict(inputt)
    next_state, reward, done, terminate = agent.env.step(action)
    state = next_state
    if done:
        print('State:', state)
        print('Steps: ', step+1)
        if np.array_equal(agent.env.goal, agent.env.pos):
            print('Reached the goal!')
        break
    if terminate:
        print('Steps: ', step+1)
        print("Crashed into a wall")
        break
# Out:
# Goal: [4 7]
# State: [1 2]
# State: [1 3]
# State: [2 3]
# State: [2 4]
# State: [2 5]
# State: [3 5]
# State: [3 6]
# State: [3 7]
# State: [4 7]
# Steps:  8
# Reached the goal!

# %%
import matplotlib.pyplot as plt
plt.plot(reward_lst)
plt.xlabel("Episode")
plt.ylabel("Reward")
# PLot mean line for 10 episodes
mean_lst = []
for i in range(len(reward_lst)):
    if i < 10:
        mean_lst.append(np.mean(reward_lst[:i+1]))
    else:
        mean_lst.append(np.mean(reward_lst[i-10:i+1]))
plt.plot(mean_lst)
plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# #### Test Results:
#
# ![image.png](attachment:image.png)
#
# ##### Hyperparameters:
#
# - Learning rate: 0.0008
# - Discount factor (gamma): 0.7
# - Epsilon: 1.0
# - Epsilon decay: 0.01
# - Epsilon min: 0.01
# - Batch size: 64
# - Memory size: 10000
# - Target update frequency: 1/5 (every 5 episodes)
# - Number of episodes: 250
# - Number of steps per episode: 500
# - Number of hidden layers: 2
# - Number of neurons in hidden layers: 16, 32
# - Activation function: ReLU
# - Optimizer: Adam
# - Loss function: MSE

# %%
agent.model.save('doublenet_dqn_diff_start_diff_goal_300ep_pt2_backup.h5')
