# %% [markdown]
# ### Deep Q Network for navigating through a grid world with different goal locations
# #### Reward system 1: Negative of euclidean distance to goal - Did not converge for 250 episodes
# #### Reward system 2: As per the paper - "Autonomous Navigation of an AMR using Deep Reinforcement Learning in a Warehouse Environment" (Episode terminates if the bot hits the bounds)
#
# ##### Final model name: doublenet_dqn_diff_start_diff_goal_300ep_pt2.h5

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
# Out:
# 2023-07-24 13:58:27.874653: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-24 13:58:28.427946: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-24 13:58:28.430586: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 13:58:30.265996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# print gpu info
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-07-21 23:34:46.577339: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 23:34:46.597394: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 23:34:46.597572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# Create a neural network model
def create_model(input_shape, num_actions):
    model = Sequential([
        Input(shape=input_shape),
        Dense(16, activation='relu'),
        Dense(32, activation='relu'),
        Dense(num_actions, activation='linear')
    ])
    model.compile(loss='mse', optimizer=Adam(learning_rate=0.0008))
    return model

# %%
# Create a class for the environment
class Env():
    def __init__(self, grid_size=6, max_steps=500):
        self.grid_size = grid_size
        self.max_steps = max_steps
        self.goal = np.random.randint(0, grid_size, size=2) # random goal
        print('Goal:', self.goal)

        self.rewards = np.zeros((grid_size, grid_size))
        self.reset()

    def reset(self):
        self.pos = np.random.randint(0, self.grid_size, size=2)
        self.steps = 0
        self.done = False
        return self.pos
    
    def reset_goal(self):
        self.goal = np.random.randint(0, self.grid_size, size=2)
        print('Goal:', self.goal)
        for i in range(self.grid_size):
            for j in range(self.grid_size):
                self.rewards[i, j] = -self.euclidean_distance_from_goal(np.array([i, j]))
        self.rewards[self.goal[0], self.goal[1]] = 100
        return self.goal
    
    # def step(self, action):
    #     self.steps += 1
    #     if action == 0 and self.pos[0] < self.grid_size - 1: # right
    #         self.pos[0] += 1
    #     elif action == 1 and self.pos[0] > 0: # left
    #         self.pos[0] -= 1
    #     elif action == 2 and self.pos[1] > 0: # down
    #         self.pos[1] -= 1
    #     elif action == 3 and self.pos[1] < self.grid_size - 1: # up
    #         self.pos[1] += 1
    #     else:
    #         pass
    #         # raise ValueError('Invalid action')
    #     if np.array_equal(self.pos, self.goal):
    #         self.done = True
    #         reward = 0
    #         # reward = 100
    #     elif self.steps >= self.max_steps:
    #         self.done = True
    #         reward = self.rewards[self.pos[0], self.pos[1]]
    #     else:
    #         reward = self.rewards[self.pos[0], self.pos[1]]
    #     return self.pos, reward, self.done

    def step(self, action): # As per the paper
        # self.steps += 1  [REQUIRED WHILE TRAINING]
        prev_pos = self.pos.copy()
        print("self.pos: ", self.pos)
        if action == 0 and self.pos[0] < self.grid_size - 1: # right
            self.pos[0] += 1
        elif action == 1 and self.pos[0] > 0: # left
            self.pos[0] -= 1
        elif action == 2 and self.pos[1] > 0: # down
            self.pos[1] -= 1
        elif action == 3 and self.pos[1] < self.grid_size - 1: # up
            self.pos[1] += 1
        else: # for crash case 
            reward = -150
            self.done = True
            return self.pos, reward, self.done, True # TODO: The episode is not terminated.
        if np.array_equal(self.pos, self.goal):
            self.done = True
            reward = 500
        elif self.steps >= self.max_steps:
            self.done = True
            reward = self.rewards[self.pos[0], self.pos[1]]
        else:
            if self.euclidean_distance_from_goal(self.pos) < self.euclidean_distance_from_goal(prev_pos):
                reward = 10
            else:
                reward = -10
        return self.pos, reward, self.done, False
        

    def euclidean_distance_from_goal(self, pos):
        dist = np.sqrt(np.sum((pos - self.goal) ** 2))
        return dist

# %%
# Create an agent class
class Agent():
    def __init__(self, env, model, target_model):
        self.env = env
        self.model = model
        self.target_model = target_model
        self.target_model.set_weights(self.model.get_weights())
        self.gamma = 0.7
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.01
        self.batch_size = 64
        self.memory = deque(maxlen=10000)
        

    def add_to_memory(self, state, goal, action, reward, next_state, done):
        self.memory.append((state, goal, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(0, 4)
        else:
            # Pre-process the input
            inputt = np.concatenate((state, self.env.goal))
            inputt = tf.convert_to_tensor(inputt)
            inputt = tf.expand_dims(inputt, 0)

            return np.argmax(self.model.predict(inputt, verbose=0)[0]) # TODO: check the predict output

    def predict(self, inputt):
        return np.argmax(self.model.predict(inputt, verbose=0)[0])
    

    def predict_2(self, inputt):
        a = self.model.predict(inputt, verbose=0)[0][0]
        b = self.model.predict(inputt, verbose=0)[0][1]
        c = self.model.predict(inputt, verbose=0)[0][2]
        d = self.model.predict(inputt, verbose=0)[0][3]

        # Find the second-largest number
        second_largest = max(min(a,b), min(a,c), min(a,d),
                            min(b,c), min(b,d), min(c,d))
        
        if second_largest == a:
            return 0
        
        if second_largest == b:
            return 1
        
        if second_largest == c:
            return 2
        
        if second_largest == d:
            return 3
        
    def predict_random(self, inputt):
        a = self.model.predict(inputt, verbose=0)[0][0]
        b = self.model.predict(inputt, verbose=0)[0][1]
        c = self.model.predict(inputt, verbose=0)[0][2]
        d = self.model.predict(inputt, verbose=0)[0][3]

        ele = random.choice(self.model.predict(inputt, verbose=0)[0])
        largest = max(a,b,c,d)

        while ele == largest:
            ele = random.choice(self.model.predict(inputt, verbose=0)[0])

        if ele == a:
            return 0
        
        if ele == b:
            return 1
        
        if ele == c:
            return 2
        
        if ele == d:
            return 3


        
    

    def replay(self):
        batch = random.sample(self.memory, self.batch_size)
        for state, goal, action, reward, next_state, done in batch:
            
            target = reward

            if not done:
                # Pre-process the next state input
                input_next = np.concatenate((next_state, goal))
                input_next = tf.convert_to_tensor(input_next)
                input_next = tf.expand_dims(input_next, 0)

                target += self.gamma * np.amax(self.target_model.predict(input_next, verbose=0)[0])

            # Pre-process the current state input
            inputt = np.concatenate((state, goal))
            inputt = tf.convert_to_tensor(inputt)
            inputt = tf.expand_dims(inputt, 0)

            cur_q_value = self.model.predict(inputt, verbose=0) # Q-value of current state
            cur_q_value[0][action] = target # TODO: check the predict output
            
            self.model.fit(inputt, cur_q_value, epochs=1, verbose=0)

# %%
# Initialize the agent

try:
    model = tf.keras.models.load_model('doublenet_dqn_diff_start_diff_goal_300ep_pt2.h5')
    print("Loaded model from disk")
    agent = Agent(Env(), model=model, target_model=model)
except:
    print("Creating new model")
    agent = Agent(Env(), model=create_model(input_shape=(4,), num_actions=4), target_model=create_model(input_shape=(4,), num_actions=4))
# Out:
# Loaded model from disk
# Goal: [1 0]

# %%
# Train the agent

num_episodes = 150
# num_episodes = 5
reward_lst = []

file = open('rewards.txt', 'a')

for episode in range(num_episodes):
    state_lst = [] # DEBUG
    ep_reward = 0 # DEBUG
    state = agent.env.reset()
    for step in range(agent.env.max_steps):
        state_lst.append(state.copy()) # DEBUG
        # print('State:', state) # DEBUG
        # print('state_lst:', state_lst) # DEBUG
        action = agent.act(state)
        # print('Action:', action) # DEBUG
        next_state, reward, done, terminate = agent.env.step(action)
        ep_reward += reward # DEBUG
        # print(f"next_state: {next_state}, reward: {reward}, done: {done}") # DEBUG
        # next_state = np.reshape(next_state, [1, 2])
        agent.add_to_memory(state, agent.env.goal, action, reward, next_state, done)
        state = next_state
        if done:
            if np.array_equal(agent.env.goal, agent.env.pos): # Reached the goal
                agent.env.reset_goal()
            if (agent.env.steps >= agent.env.max_steps) or terminate:
                print('Episode: {}/{}, steps: {}, e: {:.2}'.format(episode, num_episodes, step+1, agent.epsilon))
                print('State list:', state_lst) # DEBUG
                break
    if len(agent.memory) > agent.batch_size:
        agent.replay()
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon = (1 - agent.epsilon_min) * np.exp(-agent.epsilon_decay*episode) + agent.epsilon_min
    if episode % 5 == 0:
        agent.model.save('doublenet_dqn_diff_start_diff_goal_300ep_pt2.h5')    
    agent.target_model.set_weights(agent.model.get_weights())

    reward_lst.append(ep_reward) # DEBUG
    file.write(f"{episode},{ep_reward}\n") # DEBUG
    file.flush() # DEBUG
    
print('Average reward:', np.mean(reward_lst))
# Out:
# Episode: 0/150, steps: 2, e: 1.0
# State list: [array([2, 0]), array([3, 0])]
# Episode: 1/150, steps: 18, e: 1.0
# State list: [array([0, 4]), array([0, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 3]), array([2, 3]), array([3, 3]), array([4, 3]), array([3, 3]), array([2, 3]), array([2, 4]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 1]), array([0, 1])]
# Episode: 2/150, steps: 7, e: 0.99
# State list: [array([1, 1]), array([1, 2]), array([0, 2]), array([0, 3]), array([1, 3]), array([1, 2]), array([0, 2])]
# Episode: 3/150, steps: 12, e: 0.98
# State list: [array([0, 3]), array([0, 2]), array([1, 2]), array([0, 2]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0]), array([1, 0]), array([0, 0]), array([0, 1]), array([0, 0])]
# Episode: 4/150, steps: 3, e: 0.97
# State list: [array([4, 3]), array([4, 4]), array([4, 5])]
# Goal: [2 4]
# Episode: 5/150, steps: 10, e: 0.96
# State list: [array([2, 4]), array([2, 3]), array([1, 3]), array([1, 2]), array([2, 2]), array([2, 1]), array([1, 1]), array([0, 1]), array([0, 2]), array([0, 1])]
# Episode: 6/150, steps: 3, e: 0.95
# State list: [array([3, 1]), array([3, 0]), array([2, 0])]
# Episode: 7/150, steps: 13, e: 0.94
# State list: [array([4, 3]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 2]), array([3, 3]), array([2, 3]), array([1, 3]), array([1, 4]), array([0, 4]), array([0, 5]), array([1, 5]), array([0, 5])]
# 2023-07-21 23:34:49.261754: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-07-21 23:34:49.601273: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7015620 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-21 23:34:49.601296: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2023-07-21 23:34:49.604100: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-21 23:34:49.614680: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-21 23:34:49.663293: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-07-21 23:34:49.664602: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2023-07-21 23:34:49.664621: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2023-07-21 23:34:49.676797: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-07-21 23:34:49.728400: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-07-21 23:34:49.792067: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-07-21 23:34:49.854965: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-07-21 23:34:49.928920: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# 2023-07-21 23:34:50.000071: E tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:114] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
# Goal: [0 5]
# Episode: 8/150, steps: 25, e: 0.93
# State list: [array([3, 2]), array([3, 3]), array([3, 2]), array([3, 1]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 0]), array([2, 1]), array([1, 1]), array([1, 0]), array([2, 0]), array([1, 0]), array([0, 0]), array([0, 1]), array([0, 2]), array([0, 3]), array([0, 4]), array([1, 4]), array([1, 5]), array([1, 4]), array([2, 4]), array([1, 4]), array([0, 4]), array([0, 3])]
# Episode: 9/150, steps: 17, e: 0.92
# State list: [array([2, 5]), array([2, 4]), array([2, 5]), array([3, 5]), array([4, 5]), array([4, 4]), array([4, 3]), array([3, 3]), array([3, 4]), array([3, 3]), array([3, 2]), array([4, 2]), array([3, 2]), array([2, 2]), array([2, 1]), array([2, 0]), array([3, 0])]
# Goal: [3 5]
# Episode: 10/150, steps: 1, e: 0.91
# State list: [array([0, 5])]
# Episode: 11/150, steps: 11, e: 0.91
# State list: [array([1, 1]), array([1, 2]), array([1, 1]), array([0, 1]), array([1, 1]), array([1, 0]), array([2, 0]), array([2, 1]), array([1, 1]), array([0, 1]), array([0, 0])]
# Episode: 12/150, steps: 10, e: 0.9
# State list: [array([1, 4]), array([1, 3]), array([2, 3]), array([1, 3]), array([0, 3]), array([0, 4]), array([1, 4]), array([1, 5]), array([1, 4]), array([0, 4])]
# Episode: 13/150, steps: 6, e: 0.89
# State list: [array([1, 4]), array([1, 3]), array([1, 2]), array([1, 3]), array([0, 3]), array([0, 2])]
# Episode: 14/150, steps: 2, e: 0.88
# State list: [array([5, 1]), array([5, 2])]
# Episode: 15/150, steps: 8, e: 0.87
# State list: [array([5, 1]), array([5, 0]), array([5, 1]), array([5, 2]), array([5, 1]), array([4, 1]), array([4, 2]), array([5, 2])]
# Episode: 16/150, steps: 18, e: 0.86
# State list: [array([3, 3]), array([3, 2]), array([2, 2]), array([2, 1]), array([1, 1]), array([1, 0]), array([1, 1]), array([1, 2]), array([2, 2]), array([3, 2]), array([3, 3]), array([3, 2]), array([2, 2]), array([3, 2]), array([3, 3]), array([4, 3]), array([5, 3]), array([5, 4])]
# Episode: 17/150, steps: 20, e: 0.85
# State list: [array([3, 5]), array([2, 5]), array([2, 4]), array([2, 3]), array([1, 3]), array([2, 3]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([4, 2]), array([4, 3]), array([3, 3]), array([3, 2]), array([4, 2]), array([3, 2]), array([4, 2]), array([4, 3]), array([5, 3]), array([5, 2])]
# Episode: 18/150, steps: 2, e: 0.85
# State list: [array([1, 4]), array([0, 4])]
# Episode: 19/150, steps: 3, e: 0.84
# State list: [array([0, 2]), array([1, 2]), array([0, 2])]
# Episode: 20/150, steps: 1, e: 0.83
# State list: [array([4, 0])]
# Episode: 21/150, steps: 8, e: 0.82
# State list: [array([3, 1]), array([3, 0]), array([3, 1]), array([4, 1]), array([4, 0]), array([4, 1]), array([4, 2]), array([5, 2])]
# Goal: [1 3]
# Episode: 22/150, steps: 15, e: 0.81
# State list: [array([2, 5]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([3, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([3, 3]), array([3, 4]), array([3, 5]), array([4, 5]), array([3, 5]), array([2, 5])]
# Episode: 23/150, steps: 3, e: 0.8
# State list: [array([4, 4]), array([5, 4]), array([5, 5])]
# Goal: [3 2]
# Goal: [1 5]
# Episode: 24/150, steps: 60, e: 0.8
# State list: [array([0, 3]), array([0, 4]), array([0, 3]), array([1, 3]), array([2, 3]), array([2, 2]), array([3, 2]), array([3, 3]), array([2, 3]), array([2, 2]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([3, 2]), array([3, 3]), array([4, 3]), array([4, 2]), array([4, 1]), array([4, 0]), array([3, 0]), array([3, 1]), array([4, 1]), array([4, 2]), array([4, 3]), array([4, 2]), array([5, 2]), array([4, 2]), array([5, 2]), array([5, 3]), array([5, 4]), array([5, 3]), array([5, 4]), array([5, 3]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 4]), array([3, 4]), array([4, 4]), array([4, 5]), array([4, 4]), array([4, 3]), array([4, 2]), array([4, 3]), array([5, 3]), array([5, 4]), array([5, 5]), array([5, 4]), array([5, 5]), array([5, 4]), array([5, 3])]
# Episode: 25/150, steps: 2, e: 0.79
# State list: [array([4, 4]), array([4, 5])]
# Episode: 26/150, steps: 12, e: 0.78
# State list: [array([3, 3]), array([2, 3]), array([2, 4]), array([3, 4]), array([3, 3]), array([4, 3]), array([4, 4]), array([3, 4]), array([4, 4]), array([4, 5]), array([3, 5]), array([4, 5])]
# Goal: [0 3]
# Goal: [5 0]
# Episode: 27/150, steps: 64, e: 0.77
# State list: [array([1, 5]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([3, 3]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([3, 4]), array([3, 3]), array([3, 4]), array([4, 4]), array([4, 5]), array([4, 4]), array([5, 4]), array([5, 5]), array([4, 5]), array([4, 4]), array([4, 3]), array([4, 4]), array([3, 4]), array([3, 3]), array([4, 3]), array([3, 3]), array([4, 3]), array([4, 2]), array([3, 2]), array([3, 3]), array([3, 4]), array([3, 3]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([3, 4]), array([2, 4]), array([2, 5]), array([3, 5]), array([3, 4]), array([3, 3]), array([4, 3]), array([4, 4]), array([4, 3]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 4]), array([3, 3]), array([2, 3]), array([2, 4]), array([1, 4]), array([1, 5]), array([0, 5]), array([0, 4]), array([0, 3])]
# Episode: 28/150, steps: 1, e: 0.77
# State list: [array([0, 0])]
# Episode: 29/150, steps: 8, e: 0.76
# State list: [array([1, 1]), array([1, 0]), array([0, 0]), array([0, 1]), array([0, 2]), array([0, 1]), array([0, 0]), array([0, 1])]
# Episode: 30/150, steps: 8, e: 0.75
# State list: [array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([1, 1]), array([1, 2]), array([0, 2])]
# Episode: 31/150, steps: 18, e: 0.74
# State list: [array([2, 4]), array([2, 5]), array([1, 5]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 0]), array([1, 1]), array([1, 0]), array([1, 1]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 2]), array([0, 1])]
# Episode: 32/150, steps: 2, e: 0.74
# State list: [array([0, 3]), array([0, 2])]
# Goal: [0 4]
# Episode: 33/150, steps: 12, e: 0.73
# State list: [array([3, 5]), array([3, 4]), array([4, 4]), array([3, 4]), array([4, 4]), array([4, 5]), array([4, 4]), array([4, 3]), array([4, 2]), array([4, 1]), array([4, 0]), array([5, 0])]
# Goal: [4 3]
# Episode: 34/150, steps: 37, e: 0.72
# State list: [array([2, 2]), array([3, 2]), array([3, 3]), array([4, 3]), array([4, 4]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 2]), array([5, 2]), array([5, 1]), array([5, 0]), array([5, 1]), array([5, 2]), array([4, 2]), array([4, 1]), array([3, 1]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 1]), array([4, 1]), array([3, 1]), array([2, 1]), array([2, 2]), array([1, 2]), array([1, 3]), array([0, 3]), array([0, 4]), array([0, 3]), array([0, 2]), array([0, 3]), array([0, 2])]
# Episode: 35/150, steps: 4, e: 0.71
# State list: [array([1, 2]), array([0, 2]), array([0, 3]), array([0, 4])]
# Episode: 36/150, steps: 13, e: 0.71
# State list: [array([1, 1]), array([2, 1]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 5]), array([1, 4]), array([2, 4]), array([2, 5]), array([1, 5])]
# Episode: 37/150, steps: 4, e: 0.7
# State list: [array([5, 3]), array([5, 4]), array([5, 5]), array([5, 4])]
# Episode: 38/150, steps: 44, e: 0.69
# State list: [array([1, 3]), array([1, 2]), array([1, 1]), array([0, 1]), array([0, 2]), array([0, 1]), array([0, 2]), array([1, 2]), array([0, 2]), array([0, 3]), array([0, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 0]), array([0, 0]), array([1, 0]), array([2, 0]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([1, 1]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 4]), array([2, 4]), array([2, 3]), array([3, 3]), array([3, 2]), array([2, 2]), array([3, 2]), array([3, 3]), array([3, 2]), array([2, 2]), array([2, 1]), array([2, 0]), array([1, 0])]
# Goal: [2 3]
# Goal: [1 0]
# Episode: 39/150, steps: 33, e: 0.69
# State list: [array([4, 1]), array([4, 2]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 4]), array([3, 4]), array([3, 5]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 0]), array([3, 1]), array([3, 0]), array([3, 1]), array([3, 2]), array([3, 1]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 0]), array([3, 0]), array([3, 1]), array([3, 0])]
# Episode: 40/150, steps: 4, e: 0.68
# State list: [array([1, 5]), array([0, 5]), array([0, 4]), array([0, 5])]
# Episode: 41/150, steps: 22, e: 0.67
# State list: [array([4, 2]), array([3, 2]), array([2, 2]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 0]), array([2, 1]), array([3, 1]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 0]), array([3, 1]), array([3, 0])]
# Episode: 42/150, steps: 9, e: 0.67
# State list: [array([5, 3]), array([5, 2]), array([5, 1]), array([5, 2]), array([4, 2]), array([4, 1]), array([5, 1]), array([5, 2]), array([5, 3])]
# Episode: 43/150, steps: 5, e: 0.66
# State list: [array([4, 1]), array([4, 0]), array([3, 0]), array([4, 0]), array([3, 0])]
# Episode: 44/150, steps: 15, e: 0.65
# State list: [array([1, 2]), array([2, 2]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 2]), array([3, 2]), array([4, 2]), array([4, 1]), array([4, 0]), array([4, 1]), array([5, 1]), array([5, 0]), array([4, 0]), array([5, 0])]
# Goal: [2 3]
# Episode: 45/150, steps: 10, e: 0.65
# State list: [array([1, 2]), array([1, 1]), array([1, 0]), array([1, 1]), array([1, 2]), array([1, 3]), array([0, 3]), array([0, 4]), array([0, 3]), array([0, 2])]
# Episode: 46/150, steps: 18, e: 0.64
# State list: [array([5, 1]), array([5, 2]), array([5, 3]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 4]), array([4, 5]), array([4, 4]), array([5, 4]), array([5, 3]), array([4, 3]), array([4, 4]), array([4, 3]), array([3, 3]), array([4, 3]), array([4, 4]), array([4, 5])]
# Episode: 47/150, steps: 7, e: 0.63
# State list: [array([4, 1]), array([3, 1]), array([3, 2]), array([4, 2]), array([4, 1]), array([4, 0]), array([5, 0])]
# Goal: [2 2]
# Episode: 48/150, steps: 21, e: 0.63
# State list: [array([4, 5]), array([4, 4]), array([5, 4]), array([5, 3]), array([5, 2]), array([5, 3]), array([5, 4]), array([4, 4]), array([4, 3]), array([4, 4]), array([3, 4]), array([3, 3]), array([3, 4]), array([3, 3]), array([4, 3]), array([3, 3]), array([2, 3]), array([3, 3]), array([2, 3]), array([1, 3]), array([0, 3])]
# Episode: 49/150, steps: 42, e: 0.62
# State list: [array([1, 4]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 0]), array([1, 1]), array([2, 1]), array([1, 1]), array([1, 0]), array([1, 1]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([0, 2]), array([1, 2]), array([0, 2]), array([1, 2]), array([1, 1]), array([2, 1]), array([3, 1]), array([4, 1]), array([4, 0]), array([3, 0]), array([3, 1]), array([3, 2]), array([4, 2]), array([4, 1]), array([3, 1]), array([3, 0]), array([3, 1]), array([4, 1]), array([4, 2]), array([4, 1]), array([4, 2]), array([4, 1]), array([4, 0])]
# Goal: [2 5]
# Episode: 50/150, steps: 11, e: 0.62
# State list: [array([3, 4]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 2]), array([2, 2]), array([3, 2]), array([4, 2]), array([5, 2]), array([5, 3]), array([5, 4])]
# Episode: 51/150, steps: 2, e: 0.61
# State list: [array([1, 0]), array([0, 0])]
# Episode: 52/150, steps: 3, e: 0.6
# State list: [array([1, 4]), array([0, 4]), array([0, 5])]
# Episode: 53/150, steps: 4, e: 0.6
# State list: [array([3, 4]), array([4, 4]), array([4, 5]), array([3, 5])]
# Episode: 54/150, steps: 6, e: 0.59
# State list: [array([3, 4]), array([4, 4]), array([5, 4]), array([5, 5]), array([5, 4]), array([5, 3])]
# Goal: [5 1]
# Episode: 55/150, steps: 10, e: 0.59
# State list: [array([2, 0]), array([3, 0]), array([3, 1]), array([3, 2]), array([3, 3]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 5])]
# Goal: [0 4]
# Episode: 56/150, steps: 11, e: 0.58
# State list: [array([4, 0]), array([4, 1]), array([4, 2]), array([4, 1]), array([4, 0]), array([4, 1]), array([4, 2]), array([4, 1]), array([4, 2]), array([4, 1]), array([5, 1])]
# Episode: 57/150, steps: 55, e: 0.58
# State list: [array([2, 3]), array([2, 4]), array([1, 4]), array([1, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 4]), array([3, 4]), array([2, 4]), array([2, 5]), array([3, 5]), array([3, 4]), array([2, 4]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([3, 4]), array([3, 5]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([0, 3])]
# Goal: [3 2]
# Goal: [0 2]
# Goal: [0 2]
# Goal: [5 0]
# Episode: 58/150, steps: 69, e: 0.57
# State list: [array([3, 5]), array([3, 4]), array([2, 4]), array([3, 4]), array([3, 5]), array([2, 5]), array([2, 4]), array([1, 4]), array([1, 3]), array([1, 4]), array([0, 4]), array([0, 3]), array([0, 4]), array([0, 3]), array([0, 2]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 3]), array([1, 2]), array([2, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([2, 1]), array([3, 1]), array([3, 2]), array([2, 2]), array([3, 2]), array([4, 2]), array([3, 2]), array([2, 2]), array([1, 2]), array([0, 2]), array([0, 1]), array([1, 1]), array([1, 2]), array([2, 2]), array([1, 2]), array([2, 2]), array([1, 2]), array([2, 2]), array([3, 2]), array([2, 2]), array([2, 3]), array([3, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([1, 1]), array([1, 2]), array([2, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 0]), array([1, 1]), array([1, 2]), array([0, 2])]
# Episode: 59/150, steps: 8, e: 0.56
# State list: [array([1, 0]), array([1, 1]), array([1, 0]), array([1, 1]), array([1, 2]), array([1, 1]), array([0, 1]), array([0, 0])]
# Goal: [3 0]
# Episode: 60/150, steps: 17, e: 0.56
# State list: [array([3, 2]), array([3, 1]), array([3, 0]), array([4, 0]), array([4, 1]), array([4, 2]), array([4, 1]), array([4, 0]), array([4, 1]), array([4, 0]), array([4, 1]), array([5, 1]), array([5, 2]), array([5, 1]), array([5, 0]), array([5, 1]), array([5, 2])]
# Episode: 61/150, steps: 21, e: 0.55
# State list: [array([1, 5]), array([0, 5]), array([0, 4]), array([0, 3]), array([0, 2]), array([0, 1]), array([0, 2]), array([0, 1]), array([0, 2]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0])]
# Goal: [2 0]
# Episode: 62/150, steps: 15, e: 0.55
# State list: [array([5, 4]), array([4, 4]), array([5, 4]), array([5, 5]), array([4, 5]), array([3, 5]), array([3, 4]), array([3, 3]), array([2, 3]), array([3, 3]), array([2, 3]), array([2, 2]), array([3, 2]), array([3, 1]), array([3, 0])]
# Goal: [0 4]
# Episode: 63/150, steps: 11, e: 0.54
# State list: [array([4, 3]), array([4, 2]), array([3, 2]), array([3, 1]), array([3, 2]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 0]), array([1, 0])]
# Goal: [4 0]
# Episode: 64/150, steps: 9, e: 0.54
# State list: [array([3, 0]), array([3, 1]), array([3, 2]), array([2, 2]), array([1, 2]), array([1, 3]), array([1, 4]), array([0, 4]), array([0, 3])]
# Episode: 65/150, steps: 20, e: 0.53
# State list: [array([2, 5]), array([2, 4]), array([1, 4]), array([1, 5]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([2, 3]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([0, 2]), array([0, 1]), array([0, 2]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 0])]
# Episode: 66/150, steps: 3, e: 0.53
# State list: [array([5, 2]), array([5, 1]), array([5, 0])]
# Episode: 67/150, steps: 6, e: 0.52
# State list: [array([5, 1]), array([5, 0]), array([5, 1]), array([5, 2]), array([5, 1]), array([5, 0])]
# Episode: 68/150, steps: 5, e: 0.52
# State list: [array([0, 3]), array([0, 2]), array([0, 1]), array([0, 2]), array([0, 1])]
# Episode: 69/150, steps: 11, e: 0.51
# State list: [array([2, 5]), array([2, 4]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 0]), array([3, 0])]
# Episode: 70/150, steps: 1, e: 0.51
# State list: [array([5, 5])]
# Goal: [5 5]
# Episode: 71/150, steps: 32, e: 0.5
# State list: [array([4, 3]), array([4, 2]), array([4, 1]), array([4, 2]), array([4, 1]), array([4, 0]), array([4, 1]), array([3, 1]), array([3, 2]), array([3, 3]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([0, 3]), array([0, 4]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 4]), array([0, 4]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 4]), array([0, 4])]
# Episode: 72/150, steps: 2, e: 0.5
# State list: [array([0, 1]), array([0, 2])]
# Episode: 73/150, steps: 98, e: 0.49
# State list: [array([0, 2]), array([0, 3]), array([0, 4]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([3, 3]), array([3, 4]), array([3, 3]), array([3, 4]), array([3, 3]), array([2, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 4]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 5]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([1, 4]), array([1, 5]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 5]), array([2, 4]), array([2, 3]), array([3, 3]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 3]), array([5, 3]), array([4, 3]), array([5, 3]), array([5, 4]), array([5, 3]), array([5, 2]), array([5, 3]), array([5, 4]), array([5, 3]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([5, 4]), array([5, 3]), array([5, 4]), array([4, 4]), array([4, 5]), array([4, 4]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 4]), array([3, 4]), array([3, 3]), array([2, 3]), array([2, 4]), array([2, 5])]
# Episode: 74/150, steps: 63, e: 0.49
# State list: [array([0, 0]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 2]), array([0, 3]), array([0, 2]), array([0, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 3]), array([0, 3]), array([0, 2]), array([0, 3]), array([1, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([3, 3]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 5]), array([1, 5]), array([1, 4]), array([0, 4]), array([0, 3]), array([0, 4]), array([0, 5]), array([0, 4]), array([0, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([2, 3]), array([3, 3]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 4]), array([1, 4]), array([1, 3]), array([0, 3]), array([1, 3]), array([1, 4]), array([1, 5]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([3, 3]), array([4, 3]), array([5, 3]), array([5, 2]), array([5, 3]), array([5, 4]), array([5, 3])]
# Episode: 75/150, steps: 35, e: 0.48
# State list: [array([2, 1]), array([3, 1]), array([3, 2]), array([4, 2]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 5]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([3, 4]), array([3, 3]), array([2, 3]), array([2, 4]), array([3, 4]), array([3, 3]), array([3, 4]), array([3, 3]), array([4, 3]), array([4, 4]), array([4, 5]), array([4, 4]), array([5, 4]), array([5, 3]), array([5, 2])]
# Episode: 76/150, steps: 16, e: 0.48
# State list: [array([3, 4]), array([3, 3]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 3]), array([3, 2]), array([4, 2]), array([5, 2]), array([5, 1]), array([4, 1]), array([4, 0]), array([4, 1]), array([5, 1]), array([5, 2]), array([5, 3])]
# Episode: 77/150, steps: 58, e: 0.47
# State list: [array([0, 3]), array([1, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 5]), array([1, 5]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([1, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([3, 1]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([3, 3]), array([3, 4]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([4, 3]), array([4, 2]), array([4, 3]), array([5, 3]), array([5, 2]), array([5, 3])]
# Episode: 78/150, steps: 7, e: 0.47
# State list: [array([5, 3]), array([5, 2]), array([5, 1]), array([5, 2]), array([5, 3]), array([5, 2]), array([5, 3])]
# Episode: 79/150, steps: 2, e: 0.46
# State list: [array([1, 2]), array([0, 2])]
# Episode: 80/150, steps: 14, e: 0.46
# State list: [array([1, 1]), array([1, 2]), array([1, 3]), array([1, 4]), array([2, 4]), array([1, 4]), array([2, 4]), array([3, 4]), array([2, 4]), array([1, 4]), array([1, 3]), array([1, 4]), array([2, 4]), array([2, 5])]
# Goal: [4 1]
# Episode: 81/150, steps: 13, e: 0.45
# State list: [array([0, 0]), array([0, 1]), array([0, 2]), array([0, 3]), array([0, 4]), array([1, 4]), array([2, 4]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 5]), array([5, 5])]
# Goal: [2 3]
# Goal: [3 4]
# Goal: [4 1]
# Goal: [2 0]
# Goal: [3 3]
# Goal: [1 0]
# Episode: 82/150, steps: 72, e: 0.45
# State list: [array([5, 0]), array([5, 1]), array([5, 2]), array([5, 1]), array([5, 0]), array([5, 1]), array([5, 0]), array([5, 1]), array([4, 1]), array([3, 1]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 5]), array([2, 4]), array([1, 4]), array([2, 4]), array([3, 4]), array([3, 3]), array([3, 2]), array([3, 1]), array([4, 1]), array([5, 1]), array([4, 1]), array([4, 0]), array([3, 0]), array([4, 0]), array([3, 0]), array([2, 0]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([2, 2]), array([1, 2]), array([2, 2]), array([2, 3]), array([3, 3]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 4]), array([4, 3]), array([4, 2]), array([3, 2]), array([3, 1]), array([3, 2]), array([2, 2]), array([2, 1]), array([2, 0])]
# Episode: 83/150, steps: 16, e: 0.45
# State list: [array([5, 2]), array([4, 2]), array([3, 2]), array([3, 3]), array([4, 3]), array([4, 2]), array([5, 2]), array([4, 2]), array([5, 2]), array([4, 2]), array([4, 1]), array([5, 1]), array([4, 1]), array([4, 0]), array([3, 0]), array([2, 0])]
# Episode: 84/150, steps: 8, e: 0.44
# State list: [array([3, 4]), array([3, 3]), array([3, 2]), array([3, 1]), array([4, 1]), array([3, 1]), array([3, 0]), array([2, 0])]
# Goal: [4 1]
# Episode: 85/150, steps: 9, e: 0.44
# State list: [array([5, 1]), array([5, 2]), array([4, 2]), array([3, 2]), array([3, 1]), array([2, 1]), array([2, 0]), array([1, 0]), array([0, 0])]
# Goal: [0 0]
# Episode: 86/150, steps: 7, e: 0.43
# State list: [array([4, 1]), array([4, 0]), array([4, 1]), array([3, 1]), array([4, 1]), array([3, 1]), array([3, 0])]
# Episode: 87/150, steps: 8, e: 0.43
# State list: [array([3, 1]), array([2, 1]), array([3, 1]), array([4, 1]), array([3, 1]), array([2, 1]), array([1, 1]), array([1, 0])]
# Goal: [1 1]
# Episode: 88/150, steps: 6, e: 0.42
# State list: [array([3, 1]), array([2, 1]), array([2, 0]), array([1, 0]), array([0, 0]), array([1, 0])]
# Goal: [2 0]
# Goal: [0 3]
# Episode: 89/150, steps: 17, e: 0.42
# State list: [array([0, 1]), array([0, 2]), array([0, 1]), array([0, 0]), array([0, 1]), array([1, 1]), array([1, 0]), array([0, 0]), array([1, 0]), array([2, 0]), array([1, 0]), array([1, 1]), array([0, 1]), array([0, 0]), array([1, 0]), array([1, 1]), array([0, 1])]
# Goal: [2 2]
# Goal: [5 5]
# Episode: 90/150, steps: 36, e: 0.42
# State list: [array([3, 1]), array([3, 0]), array([2, 0]), array([1, 0]), array([2, 0]), array([1, 0]), array([1, 1]), array([1, 0]), array([1, 1]), array([0, 1]), array([0, 2]), array([0, 3]), array([0, 2]), array([1, 2]), array([1, 1]), array([0, 1]), array([1, 1]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 5]), array([2, 4]), array([2, 5]), array([3, 5]), array([4, 5]), array([3, 5]), array([4, 5]), array([4, 4]), array([4, 3]), array([4, 2]), array([5, 2]), array([5, 3]), array([5, 4])]
# Episode: 91/150, steps: 10, e: 0.41
# State list: [array([1, 2]), array([1, 3]), array([1, 4]), array([1, 5]), array([2, 5]), array([3, 5]), array([2, 5]), array([3, 5]), array([3, 4]), array([3, 5])]
# Episode: 92/150, steps: 4, e: 0.41
# State list: [array([3, 0]), array([4, 0]), array([4, 1]), array([5, 1])]
# Goal: [2 0]
# Episode: 93/150, steps: 14, e: 0.4
# State list: [array([4, 0]), array([4, 1]), array([4, 2]), array([4, 3]), array([5, 3]), array([5, 4]), array([5, 3]), array([5, 2]), array([5, 3]), array([5, 4]), array([5, 5]), array([5, 4]), array([5, 3]), array([5, 2])]
# Goal: [2 1]
# Goal: [2 3]
# Episode: 94/150, steps: 7, e: 0.4
# State list: [array([3, 3]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 0])]
# Goal: [5 3]
# Episode: 95/150, steps: 21, e: 0.4
# State list: [array([5, 2]), array([4, 2]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 4]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 5]), array([3, 4]), array([4, 4]), array([3, 4]), array([3, 3]), array([3, 4]), array([2, 4]), array([2, 3]), array([1, 3]), array([2, 3]), array([2, 4]), array([2, 5])]
# Episode: 96/150, steps: 63, e: 0.39
# State list: [array([1, 0]), array([1, 1]), array([1, 2]), array([0, 2]), array([1, 2]), array([1, 3]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([1, 3]), array([0, 3]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([2, 2]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([0, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([3, 2]), array([3, 1]), array([3, 0])]
# Goal: [0 5]
# Episode: 97/150, steps: 194, e: 0.39
# State list: [array([4, 2]), array([4, 3]), array([4, 2]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([3, 2]), array([3, 3]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([2, 2]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([2, 3]), array([2, 4]), array([2, 3]), array([3, 3]), array([3, 2]), array([3, 3]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 2]), array([4, 3]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([4, 2]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 2]), array([4, 1]), array([4, 2]), array([4, 3]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([2, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([1, 2]), array([0, 2]), array([1, 2]), array([0, 2]), array([1, 2]), array([2, 2]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([2, 3]), array([2, 2]), array([1, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([1, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 3]), array([1, 3]), array([2, 3]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 3]), array([4, 3]), array([4, 2]), array([4, 3]), array([4, 2]), array([3, 2]), array([3, 3]), array([3, 4]), array([3, 3]), array([4, 3]), array([5, 3]), array([5, 4]), array([4, 4]), array([3, 4]), array([3, 3]), array([2, 3]), array([1, 3]), array([0, 3])]
# Episode: 98/150, steps: 8, e: 0.39
# State list: [array([5, 3]), array([4, 3]), array([5, 3]), array([5, 2]), array([5, 1]), array([4, 1]), array([4, 0]), array([3, 0])]
# Episode: 99/150, steps: 1, e: 0.38
# State list: [array([0, 3])]
# Episode: 100/150, steps: 1, e: 0.38
# State list: [array([1, 0])]
# Episode: 101/150, steps: 2, e: 0.37
# State list: [array([0, 4]), array([0, 3])]
# Episode: 102/150, steps: 9, e: 0.37
# State list: [array([1, 1]), array([2, 1]), array([1, 1]), array([1, 2]), array([0, 2]), array([0, 1]), array([0, 0]), array([0, 1]), array([0, 2])]
# Episode: 103/150, steps: 11, e: 0.37
# State list: [array([4, 0]), array([3, 0]), array([4, 0]), array([3, 0]), array([2, 0]), array([2, 1]), array([3, 1]), array([2, 1]), array([1, 1]), array([0, 1]), array([0, 2])]
# Episode: 104/150, steps: 9, e: 0.36
# State list: [array([5, 3]), array([4, 3]), array([4, 4]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([1, 4]), array([0, 4])]
# Episode: 105/150, steps: 10, e: 0.36
# State list: [array([5, 4]), array([4, 4]), array([3, 4]), array([4, 4]), array([3, 4]), array([2, 4]), array([3, 4]), array([2, 4]), array([1, 4]), array([0, 4])]
# Goal: [2 2]
# Goal: [1 0]
# Episode: 106/150, steps: 22, e: 0.36
# State list: [array([3, 2]), array([2, 2]), array([2, 3]), array([1, 3]), array([1, 4]), array([1, 5]), array([0, 5]), array([0, 4]), array([1, 4]), array([2, 4]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([1, 3]), array([1, 2]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 0])]
# Goal: [3 0]
# Episode: 107/150, steps: 2, e: 0.35
# State list: [array([1, 1]), array([1, 0])]
# Episode: 108/150, steps: 13, e: 0.35
# State list: [array([5, 2]), array([5, 3]), array([5, 2]), array([5, 1]), array([4, 1]), array([4, 0]), array([4, 1]), array([4, 0]), array([5, 0]), array([4, 0]), array([5, 0]), array([4, 0]), array([5, 0])]
# Episode: 109/150, steps: 8, e: 0.35
# State list: [array([3, 5]), array([3, 4]), array([3, 3]), array([4, 3]), array([4, 2]), array([4, 1]), array([4, 0]), array([5, 0])]
# Episode: 110/150, steps: 1, e: 0.34
# State list: [array([3, 5])]
# Episode: 111/150, steps: 4, e: 0.34
# State list: [array([5, 5]), array([5, 4]), array([5, 3]), array([5, 2])]
# Goal: [2 0]
# Episode: 112/150, steps: 2, e: 0.34
# State list: [array([2, 0]), array([3, 0])]
# Goal: [4 5]
# Episode: 113/150, steps: 5, e: 0.33
# State list: [array([0, 2]), array([0, 1]), array([1, 1]), array([1, 0]), array([2, 0])]
# Goal: [0 2]
# Goal: [1 2]
# Episode: 114/150, steps: 20, e: 0.33
# State list: [array([4, 0]), array([4, 1]), array([5, 1]), array([5, 2]), array([5, 3]), array([5, 4]), array([5, 5]), array([4, 5]), array([3, 5]), array([2, 5]), array([2, 4]), array([1, 4]), array([1, 3]), array([0, 3]), array([1, 3]), array([0, 3]), array([0, 2]), array([0, 3]), array([0, 2]), array([0, 3])]
# Goal: [2 4]
# Episode: 115/150, steps: 20, e: 0.33
# State list: [array([4, 3]), array([3, 3]), array([2, 3]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 4]), array([1, 5]), array([1, 4]), array([1, 5]), array([1, 4]), array([1, 3]), array([1, 4]), array([0, 4]), array([0, 5]), array([0, 4]), array([0, 5]), array([0, 4]), array([0, 5]), array([0, 4])]
# Goal: [2 0]
# Goal: [1 2]
# Goal: [5 1]
# Goal: [1 0]
# Episode: 116/150, steps: 38, e: 0.32
# State list: [array([0, 3]), array([0, 4]), array([1, 4]), array([0, 4]), array([1, 4]), array([1, 5]), array([2, 5]), array([2, 4]), array([2, 3]), array([2, 2]), array([2, 1]), array([2, 0]), array([2, 1]), array([3, 1]), array([2, 1]), array([2, 0]), array([2, 1]), array([1, 1]), array([0, 1]), array([0, 2]), array([1, 2]), array([2, 2]), array([1, 2]), array([2, 2]), array([2, 1]), array([3, 1]), array([4, 1]), array([4, 0]), array([5, 0]), array([5, 1]), array([5, 0]), array([4, 0]), array([4, 1]), array([4, 0]), array([3, 0]), array([2, 0]), array([3, 0]), array([2, 0])]
# Episode: 117/150, steps: 14, e: 0.32
# State list: [array([3, 4]), array([3, 5]), array([3, 4]), array([3, 3]), array([3, 4]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 0]), array([2, 0]), array([3, 0]), array([4, 0]), array([3, 0]), array([2, 0])]
# Episode: 118/150, steps: 10, e: 0.32
# State list: [array([4, 3]), array([5, 3]), array([4, 3]), array([4, 2]), array([5, 2]), array([4, 2]), array([3, 2]), array([3, 1]), array([3, 0]), array([2, 0])]
# Episode: 119/150, steps: 15, e: 0.31
# State list: [array([5, 2]), array([4, 2]), array([4, 1]), array([3, 1]), array([2, 1]), array([2, 2]), array([3, 2]), array([3, 1]), array([3, 2]), array([3, 1]), array([3, 2]), array([2, 2]), array([2, 1]), array([2, 0]), array([3, 0])]
# Goal: [0 2]
# Goal: [2 1]
# Goal: [4 2]
# Goal: [3 3]
# Episode: 120/150, steps: 85, e: 0.31
# State list: [array([3, 0]), array([2, 0]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 2]), array([2, 1]), array([1, 1]), array([1, 0]), array([1, 1]), array([2, 1]), array([2, 0]), array([1, 0]), array([0, 0]), array([0, 1]), array([0, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([0, 1]), array([0, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([0, 2]), array([0, 1]), array([0, 2]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([0, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([0, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 3]), array([2, 4]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 3]), array([3, 4]), array([3, 5]), array([3, 4]), array([3, 3]), array([3, 4]), array([4, 4]), array([3, 4]), array([3, 3]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 2]), array([4, 3]), array([5, 3]), array([5, 4])]
# Goal: [5 0]
# Goal: [2 1]
# Goal: [3 1]
# Goal: [5 5]
# Episode: 121/150, steps: 44, e: 0.31
# State list: [array([3, 5]), array([3, 4]), array([3, 3]), array([3, 4]), array([2, 4]), array([1, 4]), array([1, 3]), array([1, 2]), array([2, 2]), array([3, 2]), array([3, 1]), array([4, 1]), array([5, 1]), array([5, 0]), array([4, 0]), array([4, 1]), array([3, 1]), array([3, 2]), array([2, 2]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([2, 1]), array([2, 2]), array([1, 2]), array([2, 2]), array([2, 1]), array([2, 0]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 2]), array([2, 1]), array([3, 1]), array([2, 1]), array([2, 2]), array([2, 3]), array([2, 4]), array([2, 5])]
# Episode: 122/150, steps: 4, e: 0.31
# State list: [array([0, 5]), array([1, 5]), array([2, 5]), array([3, 5])]
# Episode: 123/150, steps: 2, e: 0.3
# State list: [array([4, 4]), array([4, 5])]
# Episode: 124/150, steps: 5, e: 0.3
# State list: [array([1, 1]), array([1, 2]), array([1, 3]), array([1, 4]), array([1, 5])]
# Episode: 125/150, steps: 3, e: 0.3
# State list: [array([2, 5]), array([1, 5]), array([2, 5])]
# Episode: 126/150, steps: 9, e: 0.29
# State list: [array([0, 0]), array([0, 1]), array([0, 2]), array([0, 3]), array([0, 4]), array([0, 5]), array([1, 5]), array([2, 5]), array([3, 5])]
# Episode: 127/150, steps: 4, e: 0.29
# State list: [array([2, 2]), array([2, 3]), array([2, 4]), array([2, 5])]
# Goal: [0 2]
# Goal: [4 1]
# Goal: [3 3]
# Goal: [5 0]
# Episode: 128/150, steps: 28, e: 0.29
# State list: [array([3, 4]), array([3, 5]), array([4, 5]), array([5, 5]), array([5, 4]), array([5, 3]), array([4, 3]), array([3, 3]), array([2, 3]), array([1, 3]), array([0, 3]), array([0, 2]), array([1, 2]), array([2, 2]), array([2, 1]), array([3, 1]), array([2, 1]), array([2, 2]), array([3, 2]), array([3, 1]), array([4, 1]), array([4, 2]), array([4, 3]), array([3, 3]), array([3, 2]), array([4, 2]), array([5, 2]), array([5, 1])]
# Episode: 129/150, steps: 7, e: 0.29
# State list: [array([4, 4]), array([5, 4]), array([5, 3]), array([4, 3]), array([4, 2]), array([4, 1]), array([5, 1])]
# Goal: [5 3]
# Episode: 130/150, steps: 4, e: 0.28
# State list: [array([4, 0]), array([5, 0]), array([5, 1]), array([5, 2])]
# Episode: 131/150, steps: 8, e: 0.28
# State list: [array([1, 5]), array([1, 4]), array([2, 4]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 2]), array([5, 2])]
# Episode: 132/150, steps: 2, e: 0.28
# State list: [array([5, 1]), array([5, 2])]
# Goal: [2 0]
# Episode: 133/150, steps: 18, e: 0.27
# State list: [array([1, 4]), array([0, 4]), array([1, 4]), array([0, 4]), array([1, 4]), array([1, 5]), array([2, 5]), array([2, 4]), array([2, 3]), array([1, 3]), array([2, 3]), array([3, 3]), array([4, 3]), array([5, 3]), array([5, 2]), array([5, 1]), array([5, 0]), array([4, 0])]
# Episode: 134/150, steps: 1, e: 0.27
# State list: [array([3, 0])]
# Episode: 135/150, steps: 9, e: 0.27
# State list: [array([1, 5]), array([1, 4]), array([2, 4]), array([2, 3]), array([2, 2]), array([3, 2]), array([4, 2]), array([4, 1]), array([4, 0])]
# Episode: 136/150, steps: 9, e: 0.27
# State list: [array([4, 4]), array([4, 5]), array([4, 4]), array([4, 3]), array([5, 3]), array([5, 2]), array([5, 3]), array([5, 2]), array([5, 1])]
# Episode: 137/150, steps: 1, e: 0.26
# State list: [array([4, 0])]
# Episode: 138/150, steps: 8, e: 0.26
# State list: [array([3, 5]), array([3, 4]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 0]), array([4, 0]), array([3, 0])]
# Episode: 139/150, steps: 9, e: 0.26
# State list: [array([2, 4]), array([1, 4]), array([0, 4]), array([0, 3]), array([0, 2]), array([0, 3]), array([0, 4]), array([0, 3]), array([0, 2])]
# Episode: 140/150, steps: 4, e: 0.26
# State list: [array([4, 3]), array([4, 2]), array([4, 1]), array([4, 0])]
# Episode: 141/150, steps: 7, e: 0.25
# State list: [array([5, 5]), array([5, 4]), array([4, 4]), array([4, 3]), array([4, 2]), array([4, 1]), array([4, 0])]
# Goal: [1 0]
# Episode: 142/150, steps: 3, e: 0.25
# State list: [array([0, 0]), array([1, 0]), array([2, 0])]
# Episode: 143/150, steps: 6, e: 0.25
# State list: [array([5, 0]), array([4, 0]), array([3, 0]), array([2, 0]), array([3, 0]), array([2, 0])]
# Goal: [0 1]
# Goal: [4 3]
# Episode: 144/150, steps: 18, e: 0.25
# State list: [array([0, 4]), array([0, 3]), array([0, 2]), array([0, 1]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 2]), array([1, 1]), array([1, 0]), array([0, 0]), array([0, 1]), array([1, 1]), array([2, 1]), array([3, 1]), array([4, 1]), array([4, 2]), array([5, 2])]
# Episode: 145/150, steps: 6, e: 0.24
# State list: [array([2, 0]), array([2, 1]), array([3, 1]), array([4, 1]), array([4, 2]), array([5, 2])]
# Goal: [1 4]
# Goal: [5 3]
# Episode: 146/150, steps: 16, e: 0.24
# State list: [array([2, 0]), array([2, 1]), array([3, 1]), array([3, 2]), array([4, 2]), array([4, 3]), array([3, 3]), array([2, 3]), array([1, 3]), array([1, 4]), array([2, 4]), array([3, 4]), array([4, 4]), array([4, 3]), array([4, 2]), array([5, 2])]
# Episode: 147/150, steps: 7, e: 0.24
# State list: [array([4, 2]), array([4, 3]), array([4, 4]), array([5, 4]), array([5, 5]), array([5, 4]), array([5, 5])]
# Goal: [2 5]
# Goal: [4 3]
# Goal: [1 2]
# Goal: [2 0]
# Goal: [0 5]
# Goal: [1 4]
# Goal: [3 2]
# Goal: [3 3]
# Goal: [1 0]
# Episode: 148/150, steps: 60, e: 0.24
# State list: [array([2, 1]), array([2, 2]), array([3, 2]), array([4, 2]), array([4, 3]), array([5, 3]), array([4, 3]), array([3, 3]), array([3, 4]), array([2, 4]), array([3, 4]), array([2, 4]), array([2, 3]), array([2, 4]), array([2, 5]), array([2, 4]), array([3, 4]), array([3, 3]), array([4, 3]), array([3, 3]), array([2, 3]), array([1, 3]), array([1, 2]), array([0, 2]), array([1, 2]), array([1, 1]), array([2, 1]), array([2, 2]), array([2, 1]), array([2, 0]), array([2, 1]), array([1, 1]), array([1, 2]), array([1, 3]), array([0, 3]), array([1, 3]), array([2, 3]), array([2, 4]), array([1, 4]), array([0, 4]), array([0, 5]), array([0, 4]), array([0, 5]), array([0, 4]), array([0, 5]), array([0, 4]), array([0, 3]), array([0, 4]), array([1, 4]), array([1, 3]), array([2, 3]), array([2, 2]), array([3, 2]), array([3, 3]), array([3, 2]), array([3, 1]), array([3, 2]), array([3, 1]), array([2, 1]), array([2, 0])]
# Goal: [4 1]
# Goal: [4 3]
# Goal: [2 3]
# Goal: [5 1]
# Goal: [4 0]
# Episode: 149/150, steps: 29, e: 0.24
# State list: [array([2, 5]), array([2, 4]), array([1, 4]), array([1, 3]), array([1, 4]), array([1, 3]), array([1, 2]), array([1, 3]), array([1, 2]), array([1, 1]), array([1, 0]), array([2, 0]), array([3, 0]), array([2, 0]), array([2, 1]), array([3, 1]), array([4, 1]), array([4, 2]), array([4, 3]), array([4, 2]), array([3, 2]), array([2, 2]), array([2, 3]), array([2, 2]), array([3, 2]), array([4, 2]), array([4, 1]), array([5, 1]), array([5, 0])]
# Average reward: 174.06666666666666

# %%
# Test the agent
success = 0
crash = 0
total_step = []
for i in range(100):
    state = agent.env.reset()
    goal = agent.env.reset_goal()
    print('Goal:', goal)
    osci = state.copy()
    for step in range(30):
        print('State:', state)
        inputt = np.concatenate((state, goal))
        inputt = tf.convert_to_tensor(inputt)
        inputt = tf.expand_dims(inputt, 0)
        action = agent.predict(inputt)
        next_state, reward, done, terminate = agent.env.step(action)
        print("action b4 resolving: ", action)
        print("next_state b4 osci resolve: ", next_state)
        print("osci: ", osci)
        print("current state: ", state)


        # CRASHING 
        if terminate:
            print("PREVENTING CRASH")
            agent.env.pos = state.copy()
            action = agent.predict_random(inputt) # gives the second optimal action
            next_state, reward, done, terminate = agent.env.step(action)
            continue


        # OSILLATIONS
        if osci[0] == next_state[0] and osci[1] == next_state[1] and terminate != True:
            print("RESOLVING OSCI")
            print("inputt being sent to predict inside RESOLVE BLOCK: ",inputt)
            agent.env.pos = state.copy()
            action = agent.predict_random(inputt) # gives random action
            next_state, reward, done, terminate = agent.env.step(action)
            print("terminate b4 while loop: ", terminate)
            while terminate: # for crash case
                action = agent.predict_random(inputt) # gives random action
                next_state, reward, done, terminate = agent.env.step(action)

            print("action after resolving: ", action)
            print("next_state after osci resolve: ", next_state)
            print("done after resolve: ", done)
            
                
        osci = state.copy()
        state = next_state.copy()
        if done:
            print('State:', state)
            print('Steps: ', step+1)
            if np.array_equal(agent.env.goal, agent.env.pos):
                print('Reached the goal!')
                success += 1
                break
            elif terminate:
                print('Steps: ', step+1)
                print("Crashed into a wall")
                crash += 1
                break
            else:
                print("in loop no more episodes left: ")
                break
    if step >= 29 :
        print("more than 30 steps: ")
    print("\n\n\n")
    total_step.append(step)

sum = 0
for i in total_step:
    sum+=i
print('Success rate:', success/100)
print('Crash rate:', crash/100)
print('Oscillate rate:', (100 - success - crash)/100)
print("average no.of steps taken: ", sum/100)
# Out:
# Goal: [4 2]
# Goal: [4 2]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 3]
# osci:  [4 4]
# current state:  [4 3]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 2]
# osci:  [4 3]
# current state:  [4 3]
# State: [4 2]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [4 4]
# Goal: [4 4]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 1]
# osci:  [3 0]
# current state:  [3 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 2]
# osci:  [3 1]
# current state:  [3 1]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 3]
# osci:  [3 1]
# current state:  [3 2]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 3]
# osci:  [3 2]
# current state:  [3 3]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 3]
# osci:  [3 3]
# current state:  [4 3]
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [5 4]
# osci:  [4 3]
# current state:  [5 3]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 3]
# osci:  [5 3]
# current state:  [5 4]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 4 4 4]], shape=(1, 4), dtype=int64)
# self.pos:  [5 4]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [4 4]
# done after resolve:  True
# State: [4 4]
# Steps:  7
# Reached the goal!
#
#
#
#
# Goal: [2 4]
# Goal: [2 4]
# State: [5 1]
# self.pos:  [5 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 1]
# osci:  [5 1]
# current state:  [4 1]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 1]
# osci:  [4 1]
# current state:  [4 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 2]
# osci:  [4 1]
# current state:  [3 1]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 3]
# osci:  [3 1]
# current state:  [3 2]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 3]
# osci:  [3 2]
# current state:  [3 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 4]
# osci:  [3 3]
# current state:  [2 3]
# State: [2 4]
# Steps:  6
# Reached the goal!
#
#
#
#
# Goal: [4 0]
# Goal: [4 0]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 1]
# osci:  [2 1]
# current state:  [3 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 1]
# osci:  [3 1]
# current state:  [3 1]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 0]
# osci:  [3 1]
# current state:  [4 1]
# State: [4 0]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [3 3]
# Goal: [3 3]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 1]
# osci:  [3 0]
# current state:  [3 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 2]
# osci:  [3 1]
# current state:  [3 1]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 3]
# osci:  [3 1]
# current state:  [3 2]
# State: [3 3]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [3 0]
# Goal: [3 0]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 3]
# osci:  [2 4]
# current state:  [2 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 2]
# osci:  [2 3]
# current state:  [2 3]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 1]
# osci:  [2 3]
# current state:  [2 2]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 1]
# osci:  [2 2]
# current state:  [2 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 0]
# osci:  [2 1]
# current state:  [3 1]
# State: [3 0]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [3 3]
# Goal: [3 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 3]
# osci:  [2 3]
# current state:  [3 3]
# State: [3 3]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [1 5]
# Goal: [1 5]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 4]
# osci:  [5 4]
# current state:  [4 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 4]
# osci:  [4 4]
# current state:  [4 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 4]
# osci:  [4 4]
# current state:  [3 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 4]
# osci:  [3 4]
# current state:  [2 4]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [2 4]
# current state:  [1 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 5]
# osci:  [1 4]
# current state:  [0 4]
# State: [0 5]
# self.pos:  [0 5]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 5]
# osci:  [0 4]
# current state:  [0 5]
# State: [1 5]
# Steps:  7
# Reached the goal!
#
#
#
#
# Goal: [5 1]
# Goal: [5 1]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 4]
# osci:  [1 4]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 4]
# osci:  [2 4]
# current state:  [2 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 3]
# osci:  [2 4]
# current state:  [3 4]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 3]
# osci:  [3 4]
# current state:  [3 3]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 2]
# osci:  [3 3]
# current state:  [4 3]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 2]
# osci:  [4 3]
# current state:  [4 2]
# State: [5 2]
# self.pos:  [5 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 1]
# osci:  [4 2]
# current state:  [5 2]
# State: [5 1]
# Steps:  7
# Reached the goal!
#
#
#
#
# Goal: [5 3]
# Goal: [5 3]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 3]
# osci:  [4 3]
# current state:  [5 3]
# State: [5 3]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [1 0]
# Goal: [1 0]
# State: [0 3]
# self.pos:  [0 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 2]
# osci:  [0 3]
# current state:  [0 2]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 1]
# osci:  [0 2]
# current state:  [0 2]
# State: [0 1]
# self.pos:  [0 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 1]
# osci:  [0 2]
# current state:  [0 1]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 0]
# osci:  [0 1]
# current state:  [1 1]
# State: [1 0]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [0 2]
# Goal: [0 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 2]
# current state:  [1 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 2]
# osci:  [1 2]
# current state:  [1 2]
# State: [0 2]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [0 5]
# Goal: [0 5]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 0]
# osci:  [3 0]
# current state:  [2 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 1]
# osci:  [2 0]
# current state:  [2 0]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 1]
# osci:  [2 0]
# current state:  [2 1]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 2]
# osci:  [2 1]
# current state:  [1 1]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 2]
# osci:  [1 1]
# current state:  [1 2]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 3]
# osci:  [1 2]
# current state:  [0 2]
# State: [0 3]
# self.pos:  [0 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 4]
# osci:  [0 2]
# current state:  [0 3]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [0 3]
# current state:  [0 4]
# PREVENTING CRASH
# self.pos:  [0 4]
# State: [0 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [0 3]
# current state:  [0 4]
# State: [0 4]
# Steps:  9
# in loop no more episodes left:
#
#
#
#
# Goal: [5 3]
# Goal: [5 3]
# State: [5 2]
# self.pos:  [5 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 2]
# osci:  [5 2]
# current state:  [5 2]
# PREVENTING CRASH
# self.pos:  [5 2]
# State: [5 2]
# self.pos:  [5 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 3]
# osci:  [5 2]
# current state:  [5 2]
# PREVENTING CRASH
# self.pos:  [5 2]
# State: [5 2]
# self.pos:  [4 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 2]
# osci:  [5 2]
# current state:  [5 2]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 2 5 3]], shape=(1, 4), dtype=int64)
# self.pos:  [5 2]
# terminate b4 while loop:  False
# action after resolving:  2
# next_state after osci resolve:  [5 1]
# done after resolve:  True
# State: [5 1]
# Steps:  3
# in loop no more episodes left:
#
#
#
#
# Goal: [5 0]
# Goal: [5 0]
# State: [0 0]
# self.pos:  [0 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 0]
# osci:  [0 0]
# current state:  [1 0]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 0]
# osci:  [1 0]
# current state:  [1 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 0]
# osci:  [1 0]
# current state:  [2 0]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 0]
# osci:  [2 0]
# current state:  [3 0]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 0]
# osci:  [3 0]
# current state:  [4 0]
# State: [5 0]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [3 4]
# Goal: [3 4]
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 4]
# osci:  [4 5]
# current state:  [4 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 3]
# osci:  [4 4]
# current state:  [4 4]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 3]
# osci:  [4 4]
# current state:  [4 3]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 4]
# osci:  [4 3]
# current state:  [3 3]
# State: [3 4]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [1 2]
# Goal: [1 2]
# State: [0 5]
# self.pos:  [0 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 4]
# osci:  [0 5]
# current state:  [0 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 3]
# osci:  [0 4]
# current state:  [0 4]
# State: [0 3]
# self.pos:  [0 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 2]
# osci:  [0 4]
# current state:  [0 3]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 2]
# osci:  [0 3]
# current state:  [0 2]
# State: [1 2]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [2 5]
# Goal: [2 5]
# State: [2 5]
# self.pos:  [2 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 4]
# osci:  [2 5]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 5]
# osci:  [2 4]
# current state:  [2 4]
# State: [2 5]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [3 4]
# Goal: [3 4]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 3]
# osci:  [1 2]
# current state:  [1 3]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 3]
# osci:  [1 3]
# current state:  [1 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 3]
# osci:  [1 3]
# current state:  [2 3]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 4]
# osci:  [2 3]
# current state:  [3 3]
# State: [3 4]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [1 3]
# Goal: [1 3]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 4]
# osci:  [5 4]
# current state:  [4 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 4]
# osci:  [4 4]
# current state:  [4 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 4]
# osci:  [4 4]
# current state:  [3 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 3]
# osci:  [3 4]
# current state:  [2 4]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 3]
# osci:  [2 4]
# current state:  [2 3]
# State: [1 3]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [1 2]
# Goal: [1 2]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 4]
# osci:  [4 4]
# current state:  [3 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 3]
# osci:  [3 4]
# current state:  [3 4]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 3]
# osci:  [3 4]
# current state:  [3 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 2]
# osci:  [3 3]
# current state:  [2 3]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 3]
# current state:  [2 2]
# State: [1 2]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [4 4]
# Goal: [4 4]
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [5 4]
# osci:  [5 3]
# current state:  [5 4]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 3]
# osci:  [5 4]
# current state:  [5 4]
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [5 4]
# osci:  [5 4]
# current state:  [5 3]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 3 4 4]], shape=(1, 4), dtype=int64)
# self.pos:  [5 3]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [4 3]
# done after resolve:  False
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 3]
# osci:  [5 3]
# current state:  [4 3]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 3 4 4]], shape=(1, 4), dtype=int64)
# self.pos:  [4 3]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [3 3]
# done after resolve:  False
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 3]
# osci:  [4 3]
# current state:  [3 3]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[3 3 4 4]], shape=(1, 4), dtype=int64)
# self.pos:  [3 3]
# terminate b4 while loop:  False
# action after resolving:  3
# next_state after osci resolve:  [3 4]
# done after resolve:  False
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 4]
# osci:  [3 3]
# current state:  [3 4]
# State: [4 4]
# Steps:  6
# Reached the goal!
#
#
#
#
# Goal: [0 2]
# Goal: [0 2]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 3]
# osci:  [0 4]
# current state:  [0 3]
# State: [0 3]
# self.pos:  [0 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 2]
# osci:  [0 3]
# current state:  [0 3]
# State: [0 2]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [0 2]
# Goal: [0 2]
# State: [5 0]
# self.pos:  [5 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 0]
# osci:  [5 0]
# current state:  [4 0]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 0]
# osci:  [4 0]
# current state:  [4 0]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 0]
# osci:  [4 0]
# current state:  [3 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 0]
# osci:  [3 0]
# current state:  [2 0]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 1]
# osci:  [2 0]
# current state:  [1 0]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 1]
# osci:  [1 0]
# current state:  [1 1]
# State: [0 1]
# self.pos:  [0 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 2]
# osci:  [1 1]
# current state:  [0 1]
# State: [0 2]
# Steps:  7
# Reached the goal!
#
#
#
#
# Goal: [1 3]
# Goal: [1 3]
# State: [5 0]
# self.pos:  [5 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 0]
# osci:  [5 0]
# current state:  [4 0]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 0]
# osci:  [4 0]
# current state:  [4 0]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 0]
# osci:  [4 0]
# current state:  [3 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 1]
# osci:  [3 0]
# current state:  [2 0]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 2]
# osci:  [2 0]
# current state:  [2 1]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 1]
# current state:  [2 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 3]
# osci:  [2 2]
# current state:  [1 2]
# State: [1 3]
# Steps:  7
# Reached the goal!
#
#
#
#
# Goal: [4 1]
# Goal: [4 1]
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 4]
# osci:  [4 5]
# current state:  [4 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 3]
# osci:  [4 4]
# current state:  [4 4]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 2]
# osci:  [4 4]
# current state:  [4 3]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [4 3]
# current state:  [4 2]
# State: [4 1]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [4 5]
# Goal: [4 5]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 2]
# osci:  [2 1]
# current state:  [2 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 3]
# osci:  [2 2]
# current state:  [2 2]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 3]
# osci:  [2 2]
# current state:  [2 3]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 4]
# osci:  [2 3]
# current state:  [3 3]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 4]
# osci:  [3 3]
# current state:  [3 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 4]
# osci:  [3 4]
# current state:  [4 4]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 4]
# osci:  [4 4]
# current state:  [5 4]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 4 4 5]], shape=(1, 4), dtype=int64)
# self.pos:  [5 4]
# terminate b4 while loop:  True
# self.pos:  [5 4]
# action after resolving:  3
# next_state after osci resolve:  [5 5]
# done after resolve:  True
# State: [5 5]
# Steps:  7
# in loop no more episodes left:
#
#
#
#
# Goal: [5 5]
# Goal: [5 5]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 4]
# osci:  [5 4]
# current state:  [5 4]
# PREVENTING CRASH
# self.pos:  [5 4]
# State: [5 4]
# self.pos:  [4 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 4]
# osci:  [5 4]
# current state:  [5 4]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 4 5 5]], shape=(1, 4), dtype=int64)
# self.pos:  [5 4]
# terminate b4 while loop:  False
# action after resolving:  3
# next_state after osci resolve:  [5 5]
# done after resolve:  True
# State: [5 5]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [5 0]
# Goal: [5 0]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 0]
# osci:  [4 0]
# current state:  [5 0]
# State: [5 0]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [0 2]
# Goal: [0 2]
# State: [0 0]
# self.pos:  [0 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 1]
# osci:  [0 0]
# current state:  [0 1]
# State: [0 1]
# self.pos:  [0 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 2]
# osci:  [0 1]
# current state:  [0 1]
# State: [0 2]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [5 5]
# Goal: [5 5]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [4 1]
# current state:  [4 2]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 3]
# osci:  [4 2]
# current state:  [4 2]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 4]
# osci:  [4 2]
# current state:  [4 3]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 4]
# osci:  [4 3]
# current state:  [4 4]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 4]
# osci:  [4 4]
# current state:  [5 4]
# PREVENTING CRASH
# self.pos:  [5 4]
# State: [5 4]
# self.pos:  [4 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 4]
# osci:  [4 4]
# current state:  [5 4]
# State: [5 4]
# Steps:  6
# in loop no more episodes left:
#
#
#
#
# Goal: [1 2]
# Goal: [1 2]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 3]
# osci:  [3 3]
# current state:  [2 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 2]
# osci:  [2 3]
# current state:  [2 3]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 3]
# current state:  [2 2]
# State: [1 2]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [0 5]
# Goal: [0 5]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 4]
# osci:  [3 4]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 4]
# osci:  [2 4]
# current state:  [2 4]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [2 4]
# current state:  [1 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 4]
# current state:  [0 4]
# PREVENTING CRASH
# self.pos:  [0 4]
# State: [0 4]
# self.pos:  [0 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 3]
# osci:  [1 4]
# current state:  [0 4]
# PREVENTING CRASH
# self.pos:  [0 4]
# State: [0 4]
# self.pos:  [0 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 3]
# osci:  [1 4]
# current state:  [0 4]
# PREVENTING CRASH
# self.pos:  [0 4]
# State: [0 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 4]
# current state:  [0 4]
# State: [0 4]
# Steps:  7
# in loop no more episodes left:
#
#
#
#
# Goal: [2 5]
# Goal: [2 5]
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 5]
# osci:  [4 5]
# current state:  [3 5]
# State: [3 5]
# self.pos:  [3 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 5]
# osci:  [3 5]
# current state:  [3 5]
# State: [2 5]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [4 1]
# Goal: [4 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 1]
# osci:  [3 1]
# current state:  [4 1]
# State: [4 1]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [0 3]
# Goal: [0 3]
# State: [5 0]
# self.pos:  [5 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 0]
# osci:  [5 0]
# current state:  [4 0]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 0]
# osci:  [4 0]
# current state:  [4 0]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 0]
# osci:  [4 0]
# current state:  [3 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 0]
# osci:  [3 0]
# current state:  [2 0]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 1]
# osci:  [2 0]
# current state:  [1 0]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 1]
# osci:  [1 0]
# current state:  [1 1]
# State: [0 1]
# self.pos:  [0 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 2]
# osci:  [1 1]
# current state:  [0 1]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 3]
# osci:  [0 1]
# current state:  [0 2]
# State: [0 3]
# Steps:  8
# Reached the goal!
#
#
#
#
# Goal: [1 1]
# Goal: [1 1]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 1]
# osci:  [1 0]
# current state:  [1 1]
# State: [1 1]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [4 3]
# Goal: [4 3]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 4]
# osci:  [1 4]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 4]
# osci:  [2 4]
# current state:  [2 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 3]
# osci:  [2 4]
# current state:  [3 4]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 3]
# osci:  [3 4]
# current state:  [3 3]
# State: [4 3]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [2 4]
# Goal: [2 4]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 1]
# osci:  [4 1]
# current state:  [3 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 2]
# osci:  [3 1]
# current state:  [3 1]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 3]
# osci:  [3 1]
# current state:  [3 2]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 3]
# osci:  [3 2]
# current state:  [3 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 4]
# osci:  [3 3]
# current state:  [2 3]
# State: [2 4]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [1 5]
# Goal: [1 5]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 4]
# current state:  [0 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 5]
# osci:  [0 4]
# current state:  [0 4]
# State: [0 5]
# self.pos:  [0 5]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 5]
# osci:  [0 4]
# current state:  [0 5]
# State: [1 5]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [1 3]
# Goal: [1 3]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 2]
# osci:  [3 2]
# current state:  [2 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 2]
# current state:  [2 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 3]
# osci:  [2 2]
# current state:  [1 2]
# State: [1 3]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [3 2]
# Goal: [3 2]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 2]
# osci:  [3 2]
# current state:  [4 2]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [4 2]
# current state:  [4 2]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [4 2]
# current state:  [4 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 1]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [3 1]
# done after resolve:  False
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 1]
# osci:  [4 1]
# current state:  [3 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[3 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [3 1]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [2 1]
# done after resolve:  False
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 1]
# osci:  [3 1]
# current state:  [2 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[2 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [2 1]
# terminate b4 while loop:  False
# action after resolving:  2
# next_state after osci resolve:  [2 0]
# done after resolve:  False
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 1]
# osci:  [2 1]
# current state:  [2 0]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[2 0 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [2 0]
# terminate b4 while loop:  False
# action after resolving:  0
# next_state after osci resolve:  [3 0]
# done after resolve:  False
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 1]
# osci:  [2 0]
# current state:  [3 0]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 1]
# osci:  [3 0]
# current state:  [3 1]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [3 1]
# current state:  [4 1]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [4 1]
# current state:  [4 2]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 2 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 2]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [3 2]
# done after resolve:  True
# State: [3 2]
# Steps:  10
# Reached the goal!
#
#
#
#
# Goal: [1 3]
# Goal: [1 3]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 3]
# osci:  [1 2]
# current state:  [1 3]
# State: [1 3]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [3 1]
# Goal: [3 1]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 3]
# osci:  [3 4]
# current state:  [3 3]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 2]
# osci:  [3 3]
# current state:  [3 3]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 1]
# osci:  [3 3]
# current state:  [3 2]
# State: [3 1]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [2 0]
# Goal: [2 0]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 1]
# osci:  [1 2]
# current state:  [1 1]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 1]
# osci:  [1 1]
# current state:  [1 1]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 0]
# osci:  [1 1]
# current state:  [2 1]
# State: [2 0]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [2 5]
# Goal: [2 5]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 3]
# osci:  [3 3]
# current state:  [2 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 4]
# osci:  [2 3]
# current state:  [2 3]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 5]
# osci:  [2 3]
# current state:  [2 4]
# State: [2 5]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [1 5]
# Goal: [1 5]
# State: [5 1]
# self.pos:  [5 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 1]
# osci:  [5 1]
# current state:  [4 1]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 1]
# osci:  [4 1]
# current state:  [4 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 1]
# osci:  [4 1]
# current state:  [3 1]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 2]
# osci:  [3 1]
# current state:  [2 1]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 3]
# osci:  [2 1]
# current state:  [2 2]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 3]
# osci:  [2 2]
# current state:  [2 3]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 4]
# osci:  [2 3]
# current state:  [1 3]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 3]
# current state:  [1 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  3
# next_state b4 osci resolve:  [0 5]
# osci:  [1 4]
# current state:  [0 4]
# State: [0 5]
# self.pos:  [0 5]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 5]
# osci:  [0 4]
# current state:  [0 5]
# State: [1 5]
# Steps:  10
# Reached the goal!
#
#
#
#
# Goal: [5 1]
# Goal: [5 1]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 0]
# osci:  [2 0]
# current state:  [3 0]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 0]
# osci:  [3 0]
# current state:  [3 0]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 0]
# osci:  [3 0]
# current state:  [4 0]
# State: [5 0]
# self.pos:  [5 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 0]
# osci:  [4 0]
# current state:  [5 0]
# PREVENTING CRASH
# self.pos:  [5 0]
# State: [5 0]
# self.pos:  [4 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 0]
# osci:  [4 0]
# current state:  [5 0]
# State: [5 0]
# Steps:  5
# in loop no more episodes left:
#
#
#
#
# Goal: [3 4]
# Goal: [3 4]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 3]
# osci:  [2 2]
# current state:  [2 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 3]
# osci:  [2 3]
# current state:  [2 3]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 4]
# osci:  [2 3]
# current state:  [3 3]
# State: [3 4]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [0 3]
# Goal: [0 3]
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 5]
# osci:  [4 5]
# current state:  [3 5]
# State: [3 5]
# self.pos:  [3 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 5]
# osci:  [3 5]
# current state:  [3 5]
# State: [2 5]
# self.pos:  [2 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 5]
# osci:  [3 5]
# current state:  [2 5]
# State: [1 5]
# self.pos:  [1 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 4]
# osci:  [2 5]
# current state:  [1 5]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 5]
# current state:  [1 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 3]
# osci:  [1 4]
# current state:  [0 4]
# State: [0 3]
# Steps:  6
# Reached the goal!
#
#
#
#
# Goal: [2 3]
# Goal: [2 3]
# State: [4 0]
# self.pos:  [4 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 1]
# osci:  [4 0]
# current state:  [4 1]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 1]
# osci:  [4 1]
# current state:  [4 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 2]
# osci:  [4 1]
# current state:  [3 1]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 2]
# osci:  [3 1]
# current state:  [3 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 3]
# osci:  [3 2]
# current state:  [2 2]
# State: [2 3]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [4 2]
# Goal: [4 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 2]
# osci:  [2 2]
# current state:  [3 2]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 2]
# osci:  [3 2]
# current state:  [3 2]
# State: [4 2]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [0 0]
# Goal: [0 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 0]
# osci:  [2 0]
# current state:  [1 0]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 0]
# osci:  [1 0]
# current state:  [1 0]
# State: [0 0]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [0 2]
# Goal: [0 2]
# State: [2 5]
# self.pos:  [2 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 4]
# osci:  [2 5]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 3]
# osci:  [2 4]
# current state:  [2 4]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 3]
# osci:  [2 4]
# current state:  [2 3]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 3]
# osci:  [2 3]
# current state:  [1 3]
# State: [0 3]
# self.pos:  [0 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 2]
# osci:  [1 3]
# current state:  [0 3]
# State: [0 2]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [1 4]
# Goal: [1 4]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [1 4]
# osci:  [1 3]
# current state:  [1 4]
# State: [1 4]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [2 1]
# Goal: [2 1]
# State: [5 5]
# self.pos:  [5 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 4]
# osci:  [5 5]
# current state:  [5 4]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 3]
# osci:  [5 4]
# current state:  [5 4]
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 2]
# osci:  [5 4]
# current state:  [5 3]
# State: [5 2]
# self.pos:  [5 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 2]
# osci:  [5 3]
# current state:  [5 2]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [5 2]
# current state:  [4 2]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 1]
# osci:  [4 2]
# current state:  [4 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 0]
# osci:  [4 1]
# current state:  [3 1]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 1]
# osci:  [3 1]
# current state:  [3 0]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[3 0 2 1]], shape=(1, 4), dtype=int64)
# self.pos:  [3 0]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [2 0]
# done after resolve:  False
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 1]
# osci:  [3 0]
# current state:  [2 0]
# State: [2 1]
# Steps:  9
# Reached the goal!
#
#
#
#
# Goal: [2 1]
# Goal: [2 1]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 1]
# osci:  [2 1]
# current state:  [3 1]
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 0]
# osci:  [3 1]
# current state:  [3 1]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 1]
# osci:  [3 1]
# current state:  [3 0]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[3 0 2 1]], shape=(1, 4), dtype=int64)
# self.pos:  [3 0]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [2 0]
# done after resolve:  False
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 1]
# osci:  [3 0]
# current state:  [2 0]
# State: [2 1]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [0 3]
# Goal: [0 3]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 3]
# osci:  [1 3]
# current state:  [0 3]
# State: [0 3]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [1 1]
# Goal: [1 1]
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 4]
# osci:  [4 5]
# current state:  [4 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 3]
# osci:  [4 4]
# current state:  [4 4]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 3]
# osci:  [4 4]
# current state:  [4 3]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 2]
# osci:  [4 3]
# current state:  [3 3]
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 2]
# osci:  [3 3]
# current state:  [3 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 1]
# osci:  [3 2]
# current state:  [2 2]
# State: [2 1]
# self.pos:  [2 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 1]
# osci:  [2 2]
# current state:  [2 1]
# State: [1 1]
# Steps:  7
# Reached the goal!
#
#
#
#
# Goal: [2 1]
# Goal: [2 1]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 2]
# osci:  [1 3]
# current state:  [1 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 1]
# osci:  [1 2]
# current state:  [1 2]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 1]
# osci:  [1 2]
# current state:  [1 1]
# State: [2 1]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [2 3]
# Goal: [2 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 2]
# osci:  [2 3]
# current state:  [2 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 3]
# osci:  [2 2]
# current state:  [2 2]
# State: [2 3]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [3 0]
# Goal: [3 0]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 0]
# osci:  [1 0]
# current state:  [2 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 0]
# osci:  [2 0]
# current state:  [2 0]
# State: [3 0]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [1 2]
# Goal: [1 2]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 2]
# osci:  [2 3]
# current state:  [2 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 2]
# current state:  [2 2]
# State: [1 2]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [1 2]
# Goal: [1 2]
# State: [0 5]
# self.pos:  [0 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 4]
# osci:  [0 5]
# current state:  [0 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 3]
# osci:  [0 4]
# current state:  [0 4]
# State: [0 3]
# self.pos:  [0 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [0 2]
# osci:  [0 4]
# current state:  [0 3]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 2]
# osci:  [0 3]
# current state:  [0 2]
# State: [1 2]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [2 4]
# Goal: [2 4]
# State: [5 5]
# self.pos:  [5 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 5]
# osci:  [5 5]
# current state:  [4 5]
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 5]
# osci:  [4 5]
# current state:  [4 5]
# State: [3 5]
# self.pos:  [3 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 4]
# osci:  [4 5]
# current state:  [3 5]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 4]
# osci:  [3 5]
# current state:  [3 4]
# State: [2 4]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [3 2]
# Goal: [3 2]
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 2]
# osci:  [5 3]
# current state:  [5 2]
# State: [5 2]
# self.pos:  [5 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 2]
# osci:  [5 2]
# current state:  [5 2]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [5 2]
# current state:  [4 2]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [4 2]
# current state:  [4 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 1]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [3 1]
# done after resolve:  False
# State: [3 1]
# self.pos:  [3 1]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 1]
# osci:  [4 1]
# current state:  [3 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[3 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [3 1]
# terminate b4 while loop:  False
# action after resolving:  2
# next_state after osci resolve:  [3 0]
# done after resolve:  False
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 1]
# osci:  [3 1]
# current state:  [3 0]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[3 0 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [3 0]
# terminate b4 while loop:  True
# self.pos:  [3 0]
# action after resolving:  1
# next_state after osci resolve:  [2 0]
# done after resolve:  True
# State: [2 0]
# Steps:  6
# in loop no more episodes left:
#
#
#
#
# Goal: [4 0]
# Goal: [4 0]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 0]
# osci:  [1 0]
# current state:  [2 0]
# State: [2 0]
# self.pos:  [2 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 0]
# osci:  [2 0]
# current state:  [2 0]
# State: [3 0]
# self.pos:  [3 0]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 0]
# osci:  [2 0]
# current state:  [3 0]
# State: [4 0]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [2 4]
# Goal: [2 4]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 4]
# osci:  [1 4]
# current state:  [2 4]
# State: [2 4]
# Steps:  1
# Reached the goal!
#
#
#
#
# Goal: [2 3]
# Goal: [2 3]
# State: [2 5]
# self.pos:  [2 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 4]
# osci:  [2 5]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 3]
# osci:  [2 4]
# current state:  [2 4]
# State: [2 3]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [4 4]
# Goal: [4 4]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [4 3]
# osci:  [3 3]
# current state:  [4 3]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  0
# next_state b4 osci resolve:  [5 3]
# osci:  [4 3]
# current state:  [4 3]
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  3
# next_state b4 osci resolve:  [5 4]
# osci:  [4 3]
# current state:  [5 3]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 3]
# osci:  [5 3]
# current state:  [5 4]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 4 4 4]], shape=(1, 4), dtype=int64)
# self.pos:  [5 4]
# terminate b4 while loop:  False
# action after resolving:  3
# next_state after osci resolve:  [5 5]
# done after resolve:  False
# State: [5 5]
# self.pos:  [5 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 4]
# osci:  [5 4]
# current state:  [5 5]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 5 4 4]], shape=(1, 4), dtype=int64)
# self.pos:  [5 5]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [4 5]
# done after resolve:  False
# State: [4 5]
# self.pos:  [4 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 4]
# osci:  [5 5]
# current state:  [4 5]
# State: [4 4]
# Steps:  6
# Reached the goal!
#
#
#
#
# Goal: [5 3]
# Goal: [5 3]
# State: [5 5]
# self.pos:  [5 5]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 4]
# osci:  [5 5]
# current state:  [5 4]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 3]
# osci:  [5 4]
# current state:  [5 4]
# State: [5 3]
# Steps:  2
# Reached the goal!
#
#
#
#
# Goal: [2 5]
# Goal: [2 5]
# State: [5 4]
# self.pos:  [5 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 4]
# osci:  [5 4]
# current state:  [4 4]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 4]
# osci:  [4 4]
# current state:  [4 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 4]
# osci:  [4 4]
# current state:  [3 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  3
# next_state b4 osci resolve:  [2 5]
# osci:  [3 4]
# current state:  [2 4]
# State: [2 5]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [0 0]
# Goal: [0 0]
# State: [1 3]
# self.pos:  [1 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 2]
# osci:  [1 3]
# current state:  [1 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 1]
# osci:  [1 2]
# current state:  [1 2]
# State: [1 1]
# self.pos:  [1 1]
# action b4 resolving:  2
# next_state b4 osci resolve:  [1 0]
# osci:  [1 2]
# current state:  [1 1]
# State: [1 0]
# self.pos:  [1 0]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 0]
# osci:  [1 1]
# current state:  [1 0]
# State: [0 0]
# Steps:  4
# Reached the goal!
#
#
#
#
# Goal: [1 2]
# Goal: [1 2]
# State: [4 4]
# self.pos:  [4 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [3 4]
# osci:  [4 4]
# current state:  [3 4]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  2
# next_state b4 osci resolve:  [3 3]
# osci:  [3 4]
# current state:  [3 4]
# State: [3 3]
# self.pos:  [3 3]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 3]
# osci:  [3 4]
# current state:  [3 3]
# State: [2 3]
# self.pos:  [2 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [2 2]
# osci:  [3 3]
# current state:  [2 3]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 2]
# osci:  [2 3]
# current state:  [2 2]
# State: [1 2]
# Steps:  5
# Reached the goal!
#
#
#
#
# Goal: [5 3]
# Goal: [5 3]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 2]
# osci:  [0 2]
# current state:  [1 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 2]
# osci:  [1 2]
# current state:  [1 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  0
# ...
# osci:  [4 3]
# current state:  [4 2]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 2 3 3]], shape=(1, 4), dtype=int64)
# self.pos:  [4 2]
# terminate b4 while loop:  False
# action after resolving:  1
# next_state after osci resolve:  [3 2]
# done after resolve:  False
# State: [3 2]
# self.pos:  [3 2]
# action b4 resolving:  3
# next_state b4 osci resolve:  [3 3]
# osci:  [4 2]
# current state:  [3 2]
# State: [3 3]
# Steps:  19
# Reached the goal!
#
#
#
#
# Goal: [3 2]
# Goal: [3 2]
# State: [0 2]
# self.pos:  [0 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [1 2]
# osci:  [0 2]
# current state:  [1 2]
# State: [1 2]
# self.pos:  [1 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [2 2]
# osci:  [1 2]
# current state:  [1 2]
# State: [2 2]
# self.pos:  [2 2]
# action b4 resolving:  0
# next_state b4 osci resolve:  [3 2]
# osci:  [1 2]
# current state:  [2 2]
# State: [3 2]
# Steps:  3
# Reached the goal!
#
#
#
#
# Goal: [3 2]
# Goal: [3 2]
# State: [5 0]
# self.pos:  [5 0]
# action b4 resolving:  3
# next_state b4 osci resolve:  [5 1]
# osci:  [5 0]
# current state:  [5 1]
# State: [5 1]
# self.pos:  [5 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 1]
# osci:  [5 1]
# current state:  [5 1]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [5 1]
# current state:  [4 1]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [4 1]
# current state:  [4 2]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 2 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 2]
# terminate b4 while loop:  False
# action after resolving:  3
# next_state after osci resolve:  [4 3]
# done after resolve:  False
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 2]
# osci:  [4 2]
# current state:  [4 3]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 3 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 3]
# terminate b4 while loop:  False
# action after resolving:  0
# next_state after osci resolve:  [5 3]
# done after resolve:  False
# State: [5 3]
# self.pos:  [5 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [5 2]
# osci:  [4 3]
# current state:  [5 3]
# State: [5 2]
# self.pos:  [5 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 2]
# osci:  [5 3]
# current state:  [5 2]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [5 2]
# current state:  [4 2]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [4 2]
# current state:  [4 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 1]
# terminate b4 while loop:  False
# action after resolving:  0
# next_state after osci resolve:  [5 1]
# done after resolve:  False
# State: [5 1]
# self.pos:  [5 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 1]
# osci:  [4 1]
# current state:  [5 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [5 1]
# terminate b4 while loop:  False
# action after resolving:  3
# next_state after osci resolve:  [5 2]
# done after resolve:  False
# State: [5 2]
# self.pos:  [5 2]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 2]
# osci:  [5 1]
# current state:  [5 2]
# State: [4 2]
# self.pos:  [4 2]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 1]
# osci:  [5 2]
# current state:  [4 2]
# State: [4 1]
# self.pos:  [4 1]
# action b4 resolving:  3
# next_state b4 osci resolve:  [4 2]
# osci:  [4 2]
# current state:  [4 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[4 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [4 1]
# terminate b4 while loop:  False
# action after resolving:  0
# next_state after osci resolve:  [5 1]
# done after resolve:  False
# State: [5 1]
# self.pos:  [5 1]
# action b4 resolving:  1
# next_state b4 osci resolve:  [4 1]
# osci:  [4 1]
# current state:  [5 1]
# RESOLVING OSCI
# inputt being sent to predict inside RESOLVE BLOCK:  tf.Tensor([[5 1 3 2]], shape=(1, 4), dtype=int64)
# self.pos:  [5 1]
# terminate b4 while loop:  True
# self.pos:  [5 1]
# action after resolving:  3
# next_state after osci resolve:  [5 2]
# done after resolve:  True
# State: [5 2]
# Steps:  14
# in loop no more episodes left:
#
#
#
#
# Goal: [0 5]
# Goal: [0 5]
# State: [3 4]
# self.pos:  [3 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [2 4]
# osci:  [3 4]
# current state:  [2 4]
# State: [2 4]
# self.pos:  [2 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [1 4]
# osci:  [2 4]
# current state:  [2 4]
# State: [1 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [2 4]
# current state:  [1 4]
# State: [0 4]
# self.pos:  [0 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 4]
# current state:  [0 4]
# PREVENTING CRASH
# self.pos:  [0 4]
# State: [0 4]
# self.pos:  [0 5]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 5]
# osci:  [1 4]
# current state:  [0 4]
# PREVENTING CRASH
# self.pos:  [0 4]
# State: [0 4]
# self.pos:  [1 4]
# action b4 resolving:  1
# next_state b4 osci resolve:  [0 4]
# osci:  [1 4]
# current state:  [0 4]
# State: [0 4]
# Steps:  6
# in loop no more episodes left:
#
#
#
#
# Goal: [2 0]
# Goal: [2 0]
# State: [4 3]
# self.pos:  [4 3]
# action b4 resolving:  2
# next_state b4 osci resolve:  [4 2]
# osci:  [4 3]
# current state:  [4 2]
# State: [4 2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 15
#      13 inputt = tf.convert_to_tensor(inputt)
#      14 inputt = tf.expand_dims(inputt, 0)
# ---> 15 action = agent.predict(inputt)
#      16 next_state, reward, done, terminate = agent.env.step(action)
#      17 print("action b4 resolving: ", action)
#
# Cell In[20], line 31, in Agent.predict(self, inputt)
#      30 def predict(self, inputt):
# ---> 31     return np.argmax(self.model.predict(inputt, verbose=0)[0])
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/training.py:2349, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2340     except ValueError:
#    2341         warnings.warn(
#    2342             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2343             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2346             stacklevel=2,
#    2347         )
# -> 2349 data_handler = data_adapter.get_data_handler(
#    2350     x=x,
#    2351     batch_size=batch_size,
#    2352     steps_per_epoch=steps,
#    2353     initial_epoch=0,
#    2354     epochs=1,
#    2355     max_queue_size=max_queue_size,
#    2356     workers=workers,
#    2357     use_multiprocessing=use_multiprocessing,
#    2358     model=self,
#    2359     steps_per_execution=self._steps_per_execution,
#    2360 )
#    2362 # Container that configures and calls `tf.keras.Callback`s.
#    2363 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:1583, in get_data_handler(*args, **kwargs)
#    1581 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1582     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1583 return DataHandler(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:1260, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1257     self._steps_per_execution = steps_per_execution
#    1259 adapter_cls = select_data_adapter(x, y)
# -> 1260 self._adapter = adapter_cls(
#    1261     x,
#    1262     y,
#    1263     batch_size=batch_size,
#    1264     steps=steps_per_epoch,
#    1265     epochs=epochs - initial_epoch,
#    1266     sample_weights=sample_weight,
#    1267     shuffle=shuffle,
#    1268     max_queue_size=max_queue_size,
#    1269     workers=workers,
#    1270     use_multiprocessing=use_multiprocessing,
#    1271     distribution_strategy=tf.distribute.get_strategy(),
#    1272     model=model,
#    1273 )
#    1275 strategy = tf.distribute.get_strategy()
#    1277 self._current_step = 0
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/data_adapter.py:307, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     300     return indices
#     302 # We prefetch a single element. Computing large permutations can take
#     303 # quite a while so we don't want to wait for prefetching over an epoch
#     304 # boundary to trigger the next permutation. On the other hand, too many
#     305 # simultaneous shuffles can contend on a hardware level and degrade all
#     306 # performance.
# --> 307 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     309 def slice_batch_indices(indices):
#     310     """Convert a Tensor of indices into a dataset of batched indices.
#     311
#     312     This step can be accomplished in several ways. The most natural is
#    (...)
#     324       A Dataset of batched indices.
#     325     """
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py:2240, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2236 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2237 # dataset_ops).
#    2238 # pylint: disable=g-import-not-at-top,protected-access
#    2239 from tensorflow.python.data.ops import map_op
# -> 2240 return map_op._map_v2(
#    2241     self,
#    2242     map_func,
#    2243     num_parallel_calls=num_parallel_calls,
#    2244     deterministic=deterministic,
#    2245     name=name)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/map_op.py:37, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      34   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      35     warnings.warn("The `deterministic` argument has no effect unless the "
#      36                   "`num_parallel_calls` argument is specified.")
# ---> 37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
#      40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#    (...)
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/map_op.py:107, in _MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     105 self._use_inter_op_parallelism = use_inter_op_parallelism
#     106 self._preserve_cardinality = preserve_cardinality
# --> 107 self._map_func = structured_function.StructuredFunctionWrapper(
#     108     map_func,
#     109     self._transformation_name(),
#     110     dataset=input_dataset,
#     111     use_legacy_function=use_legacy_function)
#     112 self._name = name
#     113 variant_tensor = gen_dataset_ops.map_dataset(
#     114     input_dataset._variant_tensor,  # pylint: disable=protected-access
#     115     self._map_func.function.captured_inputs,
#    (...)
#     118     preserve_cardinality=self._preserve_cardinality,
#     119     **self._common_args)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/structured_function.py:259, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     253     if def_function.functions_run_eagerly():
#     254       warnings.warn(
#     255           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     256           "option is set, this option does not apply to tf.data functions. "
#     257           "To force eager execution of tf.data functions, please use "
#     258           "`tf.data.experimental.enable_debug_mode()`.")
# --> 259     fn_factory = trace_tf_function(defun_kwargs)
#     261 self._function = fn_factory()
#     262 # There is no graph to add in eager mode.
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/structured_function.py:237, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function(defun_kwargs)
#     230 def trace_tf_function(defun_kwargs):
#     231   # Note: wrapper_helper will apply autograph based on context.
#     232   @eager_function.defun_with_attributes(
#     233       input_signature=structure.get_flat_tensor_specs(
#     234           self._input_structure),
#     235       autograph=False,
#     236       attributes=defun_kwargs)
# --> 237   def wrapped_fn(*args):  # pylint: disable=missing-docstring
#     238     ret = wrapper_helper(*args)
#     239     ret = structure.to_tensor_list(self._output_structure, ret)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/quarantine.py:72, in defun_with_attributes.<locals>.decorated(function)
#      68 except AttributeError:
#      69   name = "function"
#      70 return tf_decorator.make_decorator(
#      71     function,
# ---> 72     tracing_compiler.TracingCompiler(
#      73         function,
#      74         name,
#      75         input_signature=input_signature,
#      76         attributes=attributes,
#      77         autograph=autograph,
#      78         autograph_options=experimental_autograph_options,
#      79         jit_compile=jit_compile,
#      80         reduce_retracing=reduce_retracing))
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:111, in TracingCompiler.__init__(self, python_function, name, input_signature, attributes, autograph, autograph_options, reduce_retracing, capture_by_value, jit_compile)
#     109 self._python_function = python_function
#     110 pure_function = attributes and attributes_lib.IMPLEMENTS in attributes
# --> 111 self._function_spec = function_spec.FunctionSpec.from_function_and_signature(
#     112     python_function, input_signature, is_pure=pure_function)
#     113 self._name = name
#     114 self._autograph = autograph
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/function_spec.py:220, in FunctionSpec.from_function_and_signature(cls, python_function, input_signature, is_pure, jit_compile)
#     217   python_function = python_function.func
#     218 name = getattr(python_function, "__name__", "f")
# --> 220 return FunctionSpec(
#     221     function_type,
#     222     default_values,
#     223     is_bound_method,
#     224     is_pure=is_pure,
#     225     jit_compile=jit_compile,
#     226     name=name)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/function_spec.py:276, in FunctionSpec.__init__(self, function_type, default_values, is_bound_method, is_pure, name, jit_compile)
#     274 # TODO(edloper): Include name when serializing for SavedModel?
#     275 self._name = name or "f"
# --> 276 self._input_signature = to_input_signature(function_type)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/function_spec.py:162, in to_input_signature(function_type)
#     157 if parameter.type_constraint:
#     158   # Generate legacy constraint representation.
#     159   constraint = parameter.type_constraint.placeholder_value(
#     160       trace_type.InternalPlaceholderContext(unnest_only=True)
#     161   )
# --> 162   if any(
#     163       not isinstance(arg, tensor_spec.TensorSpec)
#     164       for arg in nest.flatten([constraint], expand_composites=True)):
#     165     # input_signature only supports contiguous TensorSpec composites
#     166     is_auto_constrained = True
#     167     break
#
# KeyboardInterrupt:

# %%
# testing for custom goal and random start point:
state = agent.env.reset()
goal = agent.env.reset_goal()
# print('Goal:', goal)

for step in range(30):
    print('State:', state)
    inputt = np.concatenate((state, goal))
    inputt = tf.convert_to_tensor(inputt)
    inputt = tf.expand_dims(inputt, 0)
    action = agent.predict(inputt)
    next_state, reward, done, terminate = agent.env.step(action)
    state = next_state
    if done:
        print('State:', state)
        print('Steps: ', step+1)
        if np.array_equal(agent.env.goal, agent.env.pos):
            print('Reached the goal!')
        break
    if terminate:
        print('Steps: ', step+1)
        print("Crashed into a wall")
        break
# Out:
# Goal: [5 4]
# State: [4 3]
# State: [5 3]
# State: [5 3]
# Steps:  2

# %%
import matplotlib.pyplot as plt
plt.plot(reward_lst)
plt.xlabel("Episode")
plt.ylabel("Reward")
# PLot mean line for 10 episodes
mean_lst = []
for i in range(len(reward_lst)):
    if i < 10:
        mean_lst.append(np.mean(reward_lst[:i+1]))
    else:
        mean_lst.append(np.mean(reward_lst[i-10:i+1]))
plt.plot(mean_lst)
plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# #### Test Results:
#
# ![image.png](attachment:image.png)
#
# ##### Hyperparameters:
#
# - Learning rate: 0.0008
# - Discount factor (gamma): 0.7
# - Epsilon: 1.0
# - Epsilon decay: 0.01
# - Epsilon min: 0.01
# - Batch size: 64
# - Memory size: 10000
# - Target update frequency: 1/5 (every 5 episodes)
# - Number of episodes: 250
# - Number of steps per episode: 500
# - Number of hidden layers: 2
# - Number of neurons in hidden layers: 16, 32
# - Activation function: ReLU
# - Optimizer: Adam
# - Loss function: MSE

# %%
agent.model.save('doublenet_dqn_diff_start_diff_goal_300ep_pt2_backup.h5')
