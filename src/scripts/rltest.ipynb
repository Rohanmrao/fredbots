# %%
#!/usr/bin/env python

# Rohan's laptop
import numpy as np

# %%
# Define states, actions, and rewards
states = np.array([[2, 3, 5]])
actions = np.array([[0, 1, 2]])  # 0: decrement, 1: no change, 2: increment
rewards = np.array([[0, 0, 1]])  # Rewards for each action in the final state

# Initialize Q-table with zeros
num_states = states.shape[0]
num_actions = actions.shape[1]
Q = np.zeros((num_states, num_actions))

# Define hyperparameters
learning_rate = 0.1
discount_factor = 0.9
num_episodes = 10

# %%
# Q-learning algorithm
for episode in range(num_episodes):
    state = states[0]
    
    while True:
        # Choose action using epsilon-greedy policy
        if np.random.uniform(0, 1) < 0.5:
            action = np.argmax(Q[0])
        else:
            action = np.random.choice(actions[0])
        
        # Perform action and observe new state
        if action == 0:
            new_state = state - 1
        elif action == 1:
            new_state = state
        else:
            new_state = state + 1
        
        # Calculate TD error and update Q-table
        td_target = rewards[0, action] + discount_factor * np.max(Q[0])
        td_error = td_target - Q[0, action]
        Q[0, action] += learning_rate * td_error
        
        # Check if goal state reached
        if np.array_equal(new_state, [1, 0, 0.5]):
            break
        
        state = new_state
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#      23 Q[0, action] += learning_rate * td_error
#      25 # Check if goal state reached
# ---> 26 if np.array_equal(new_state, [1, 0, 0.5]):
#      27     break
#      29 state = new_state
#
# File <__array_function__ internals>:200, in array_equal(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/numeric.py:2461, in array_equal(a1, a2, equal_nan)
#    2407 @array_function_dispatch(_array_equal_dispatcher)
#    2408 def array_equal(a1, a2, equal_nan=False):
#    2409     """
#    2410     True if two arrays have the same shape and elements, False otherwise.
#    2411
#    (...)
#    2459     True
#    2460     """
# -> 2461     try:
#    2462         a1, a2 = asarray(a1), asarray(a2)
#    2463     except Exception:
#
# KeyboardInterrupt:

# %%
# Print the Q-table
print("Q-table:")
print(Q)
